# %% [markdown]
# # EM casing response dipole source

# %%
import numpy as np
import os
import scipy.sparse as sp
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, LinearSegmentedColormap, Normalize
from matplotlib import cm as colormap
import time
from string import ascii_lowercase
import pickle
from multiprocessing import Pool

# SimPEG, discretize/
import discretize
from discretize import utils
from simpeg.electromagnetics import frequency_domain as fdem
from simpeg import(
    maps, Report, data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils
)
from pymatsolver import Pardiso

from utils import pad_for_casing_and_data

# %%
from matplotlib import rcParams
rcParams["font.size"] = 16

# %%
directory_path = "/t40array/lheagy/casing-upscaling-casing-conductivity"

# %%
def ensure_directory_exists(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# Example usage
ensure_directory_exists(directory_path)
# Out:
# Directory '/t40array/lheagy/casing-upscaling-casing-conductivity' already exists.

# %%
save_figures = False
fig_dir_high = "figures"
fig_dir_low = "low-rez-figures"

dpi_high=400
dpi_low=150

# %% [markdown]
# ## Simulation parameters

# %%
# # conductivities
sigma_air = 1e-4
sigma_back = 1e-1
casing_l = 500
sigma_casing = np.r_[1e5, 5e5, 1e6, 5e6, 1e7]
mur_casing = np.r_[1]

# # casing geometry
casing_b = 20e-2  
casing_t = 2e-2 #np.r_[5e-3, 7.5e-3, 10e-3, 12.5e-3, 15e-3, 20e-3]
casing_a = casing_b - casing_t

# %%
src_dz = 10
src_z = -515 #np.r_[-100, -250, -400, -495, -500, -550, -600]

# %%
# generate a mesh
hx = pad_for_casing_and_data(
   casing_outer_radius = casing_b,
    csx1 = casing_t/8, 
    csx2 = 25, 
    pfx1 = 1.3,
    pfx2 = 1.5, 
    domain_x = 1000, 
    npadx = 10
)

pfz = 1.3
npad_z = 28
csz = 1
n_core_extra = 10
ncore_z = int(np.max(np.r_[np.abs(casing_l), np.abs(src_z)]) / csz) + n_core_extra
hz = discretize.utils.unpack_widths(
    [(csz, npad_z, -pfz), (csz, ncore_z), (csz, npad_z, pfz)]
)

# %%
mesh = discretize.CylindricalMesh(
    [hx, np.r_[2*np.pi], hz], origin=np.r_[0, 0, -np.sum(hz[:npad_z + int(ncore_z)])],
)

fig, ax = plt.subplots(1, 1)
mesh.plot_grid(ax=ax)
# ax.set_xlim([0, 5])
# ax.set_ylim(-50, 10)
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
mesh.n_cells
# Out:
# 97027

# %%
def get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sigma_casing, sigma_air=1e-4, mur_casing=1):

    model = np.ones(mesh.n_cells)*sigma_air
    model[mesh.cell_centers[:, 2] < 0] = sigma_back

    mur = np.ones(mesh.n_cells)

    inds_casing_x = (
        (mesh.cell_centers[:, 0] > casing_a) & 
        (mesh.cell_centers[:, 0] < casing_b)
    )
    inds_casing_z = (
        (mesh.cell_centers[:, 2] < 0) &
        (mesh.cell_centers[:, 2] > -casing_l)
    )
    inds_casing = inds_casing_x & inds_casing_z

    model[inds_casing] = sigma_casing
    mur[inds_casing] = mur_casing

    return model, mur

# %%
sigma_back
# Out:
# 0.1

# %%
models = {}
for sig in sigma_casing:
    for mur in mur_casing:
        key = f"casing_sig{sig:1.0e}_mur{mur:1.0f}"
        sig_model, mur_model = get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sig)
        models[key] = {
            "sigma": sig_model, 
            "mur": mur_model
        }
keys = list(models.keys())

# %%
keys
# Out:
# ['casing_sig1e+05_mur1',
#  'casing_sig5e+05_mur1',
#  'casing_sig1e+06_mur1',
#  'casing_sig5e+06_mur1',
#  'casing_sig1e+07_mur1']

# %%
def plot_casing(model, xlim=None, zlim=None, vmin=None, vmax=None, ax=None, cb_label=None): 
    if ax is None: 
        fig, ax = plt.subplots(1, 1)
    pcolor_opts={"norm":LogNorm(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    out = mesh.plot_image(
        model, pcolor_opts=pcolor_opts, ax=ax, mirror=True
    )

    cb = plt.colorbar(out[-1])
    cb.set_label(cb_label)

    if xlim is not None: 
        ax.set_xlim(xlim)
    if zlim is not None: 
        ax.set_ylim(zlim)

    ax.set_xlabel("x (m)")
    ax.set_ylabel("z (m)")
    return ax

# %%
plot_keys = keys
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 0.2*np.r_[-1, 1]
zlim = np.r_[-600, 10]
vmin = sigma_air
vmax = np.max(sigma_casing)

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i])
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %% [markdown]
# ## set up the simulations

# %%
frequencies = 10**np.linspace(-1, 4, 36)
frequencies
# Out:
# array([1.00000000e-01, 1.38949549e-01, 1.93069773e-01, 2.68269580e-01,
#        3.72759372e-01, 5.17947468e-01, 7.19685673e-01, 1.00000000e+00,
#        1.38949549e+00, 1.93069773e+00, 2.68269580e+00, 3.72759372e+00,
#        5.17947468e+00, 7.19685673e+00, 1.00000000e+01, 1.38949549e+01,
#        1.93069773e+01, 2.68269580e+01, 3.72759372e+01, 5.17947468e+01,
#        7.19685673e+01, 1.00000000e+02, 1.38949549e+02, 1.93069773e+02,
#        2.68269580e+02, 3.72759372e+02, 5.17947468e+02, 7.19685673e+02,
#        1.00000000e+03, 1.38949549e+03, 1.93069773e+03, 2.68269580e+03,
#        3.72759372e+03, 5.17947468e+03, 7.19685673e+03, 1.00000000e+04])

# %%
src_list = []
src_locations = np.array([
    [0, 0, src_z+src_dz/2.],
    [0, 0, src_z-src_dz/2.]
])
for f in frequencies: 
    src = fdem.sources.LineCurrent([], location=src_locations, frequency=f)
    src_list.append(src)
    
survey = fdem.Survey(src_list)
sim = fdem.simulation.Simulation3DMagneticField(
    mesh=mesh, sigmaMap=maps.IdentityMap(mesh),
    survey=survey, solver=Pardiso, #mu=mur * mu_0
#     verbose=True
)

# %%
def run_simulation(key):
    
    filename = os.path.sep.join([directory_path, key])

    t = time.time()
    print(f"starting {key}..., saving to {filename}")
    fields = sim.fields(models[key]["sigma"])
    print(f" ... done. {time.time()-t:1.2e} \n")
    
    np.save(filename, fields[:, "hSolution"])

    return fields

# %%
fields = {}

# %%
for key in keys: 
    if key not in fields: 
        fields[key] = run_simulation(key)
# Out:
# starting casing_sig1e+05_mur1..., saving to /t40array/lheagy/casing-upscaling-casing-conductivity/casing_sig1e+05_mur1
#  ... done. 1.91e+01
#
# starting casing_sig5e+05_mur1..., saving to /t40array/lheagy/casing-upscaling-casing-conductivity/casing_sig5e+05_mur1
#  ... done. 1.69e+01
#
# starting casing_sig1e+06_mur1..., saving to /t40array/lheagy/casing-upscaling-casing-conductivity/casing_sig1e+06_mur1
#  ... done. 1.64e+01
#
# starting casing_sig5e+06_mur1..., saving to /t40array/lheagy/casing-upscaling-casing-conductivity/casing_sig5e+06_mur1
#  ... done. 1.55e+01
#
# starting casing_sig1e+07_mur1..., saving to /t40array/lheagy/casing-upscaling-casing-conductivity/casing_sig1e+07_mur1
#  ... done. 1.62e+01

# %%
fields
# Out:
# {'casing_sig1e+05_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7f066140e3d0>,
#  'casing_sig5e+05_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7f0660c4b8d0>,
#  'casing_sig1e+06_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7f06614b9910>,
#  'casing_sig5e+06_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7f0660c48e10>,
#  'casing_sig1e+07_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7f06619a2690>}

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

key = keys[0]
freq_ind = 0
xlim = 500*np.r_[-1, 1]
zlim = np.r_[-1000, 10]

field_plot = (mesh.average_face_to_cell_vector * fields[key][sim.survey.source_list[freq_ind], "e"])

for i, component in enumerate(["real", "imag"]): 
    out = mesh.plot_image(
        getattr(field_plot, component), "CCv", view="vec", 
        range_x = xlim, range_y = zlim,
        sample_grid = np.r_[10, 10],
        mirror=True, #mirror_data=field_mirror,
        ax=ax[i], 
        pcolor_opts={"norm":LogNorm(vmin=1e-7, vmax=1e-2)}
    )
    cb = plt.colorbar(out[0], ax=ax[i])
    cb.set_label("Electric Field (V/m)")
    ax[i].set_aspect(1)
    ax[i].set_title(f"{frequencies[freq_ind]} Hz, {component}")
plt.tight_layout()

# %%
# def load_fields(name, conductivity, mur):
#     solution = np.load(f"{directory}/fields_{name}.npy")
#     sim = generate_simulation(mur)
#     sim.model = conductivity
#     f = sim.fieldsPair(sim)
#     f[:, sim._solutionType] = solution
#     return f

# %%
len(frequencies)
# Out:
# 36

# %%
# casing_t_inv = np.r_[5e-3]
# mur_inv = np.r_[1, 50, 100, 150, 200]
# freq_inds_inv = np.arange(0, 31, 1)
# src_ind_inv = 5

# inv_keys = []
# for t in casing_t_inv:
#     for mur in mur_inv:
#         inv_keys.append(f"casing_{mur}_{t:1.2e}")
# inv_keys

# %%
# frequencies[freq_inds_inv]

# %%
# fields = {}
# for key in inv_keys:
#     # if key not in fields.keys():
#     fields[key] = load_fields(key, models[key]["sigma"], models[key]["mur"])

# %%
rcParams["font.size"] = 12

# %%
fields.keys()
# Out:
# dict_keys(['casing_sig1e+05_mur1', 'casing_sig5e+05_mur1', 'casing_sig1e+06_mur1', 'casing_sig5e+06_mur1', 'casing_sig1e+07_mur1'])

# %%
def skin_depth(f, sigma, mur):
    return np.sqrt(2/(2*np.pi*f*sigma*mur*mu_0))

# %%
rx_x = np.linspace(25, 500, 20)
rx_z = -np.linspace(0, 600, 25) - csz/2
rx_z
# Out:
# array([-5.000e-01, -2.550e+01, -5.050e+01, -7.550e+01, -1.005e+02,
#        -1.255e+02, -1.505e+02, -1.755e+02, -2.005e+02, -2.255e+02,
#        -2.505e+02, -2.755e+02, -3.005e+02, -3.255e+02, -3.505e+02,
#        -3.755e+02, -4.005e+02, -4.255e+02, -4.505e+02, -4.755e+02,
#        -5.005e+02, -5.255e+02, -5.505e+02, -5.755e+02, -6.005e+02])

# %%
def create_receivers():
    rx_ex_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="real",
    )
    rx_ex_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="imag",
    )
    rx_ez_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="real",
    )
    rx_ez_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="imag",
    )
    return rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im

# %%
rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
Px = rx_ex_re.getP(mesh, "Fx")
Pz = rx_ez_re.getP(mesh, "Fz")

# %%
frequencies
# Out:
# array([1.00000000e-01, 1.38949549e-01, 1.93069773e-01, 2.68269580e-01,
#        3.72759372e-01, 5.17947468e-01, 7.19685673e-01, 1.00000000e+00,
#        1.38949549e+00, 1.93069773e+00, 2.68269580e+00, 3.72759372e+00,
#        5.17947468e+00, 7.19685673e+00, 1.00000000e+01, 1.38949549e+01,
#        1.93069773e+01, 2.68269580e+01, 3.72759372e+01, 5.17947468e+01,
#        7.19685673e+01, 1.00000000e+02, 1.38949549e+02, 1.93069773e+02,
#        2.68269580e+02, 3.72759372e+02, 5.17947468e+02, 7.19685673e+02,
#        1.00000000e+03, 1.38949549e+03, 1.93069773e+03, 2.68269580e+03,
#        3.72759372e+03, 5.17947468e+03, 7.19685673e+03, 1.00000000e+04])

# %%
range(len(frequencies))
# Out:
# range(0, 36)

# %%
# get data_vectors
dobs_dict = {}

for k in keys:
    tmp_dict = {}
    for si in range(len(frequencies)):
        src = sim.survey.source_list[si]
        e = fields[k][src, "e"]
        edatax = (Px * e).squeeze()
        edataz = (Pz * e).squeeze()
        tmp_dict[frequencies[si]] = {
            "real_x": edatax.real,
            "imag_x": edatax.imag,
            "real_z": edataz.real,
            "imag_z": edataz.imag
        }
    dobs_dict[k] = tmp_dict

# %%
fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

key_ind = 0
key = keys[key_ind]

for i, freq in enumerate(frequencies): 
    # ax.plot(rx_x, dobs_dict[key][freq]["real"].reshape((len(rx_x), len(rx_z)), order="F"), "o" );
    for j, component in enumerate(["real_z", "imag_z"]): 
        plt.colorbar(
            ax[i, j].contourf(
                rx_x, rx_z, np.log10(np.abs(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T)), 30,
                # vmin=-7, vmax=-2
                # norm=LogNorm()
            ), ax=ax[i, j]
        )
        
        ax[i, j].plot(rx_ex_re.locations[:, 0], rx_ex_re.locations[:, 2], "w.", ms=1)
        ax[i, j].set_aspect(1)
        ax[i, j].set_title(f"{freq} Hz {component}")

plt.tight_layout()

# %%
def get_amplitude_phase(real, imag):
    # real = f.real
    # imag = f.imag
    amplitude = np.sqrt(real**2 + imag**2)
    phase = 180/np.pi*np.arctan2(imag, real)
    return amplitude, phase

# %%
# fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

# key_ind = 0
# key = keys[key_ind]

# for i, freq in enumerate(frequencies): 
#     amp, phase = get_amplitude_phase(*(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T for component in ["real", "imag"]))
#     for j, plotme in enumerate([np.log10(np.abs(amp)), phase]): 
#         plt.colorbar(
#             ax[i, j].contourf(
#                 rx_x, rx_z, plotme, 30,
#                 # vmin=-7, vmax=-2
#                 # norm=LogNorm()
#                 cmap = "twilight" if j == 1 else "viridis"
#             ), ax=ax[i, j]
#         )
        
#         ax[i, j].plot(rx_e_re.locations[:, 0], rx_e_re.locations[:, 2], "w.", ms=1)
#         ax[i, j].set_aspect(1)
#         ax[i, j].set_title(f"{freq} Hz {'amplitude' if j==0 else 'phase'}")

# plt.tight_layout()

# %% [markdown]
# # set up mappings and simulation

# %%
def create_maps(key, true_inds=False, casing_t_ind=0):
    indsx = (mesh.cell_centers[:, 0] < casing_b)
    if true_inds is True: 
        indsx = indsx & (mesh.cell_centers[:, 0] > casing_b - casing_t[casing_t_ind])
    
    inds_interior = (
        indsx &
        (mesh.cell_centers[:, 2] <= 0) &
        (mesh.cell_centers[:, 2] >= -casing_l)
    )

    active_inds_sigma = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=np.log(models[key]["sigma"][~inds_interior])
    )

    active_inds_mur = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=models[key]["mur"][~inds_interior]
    )

    projection_sigma = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])
    projection_mu = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])

    exp_map = maps.ExpMap(mesh)
    mur_map = maps.MuRelative(mesh)

    sigma_map = exp_map * active_inds_sigma * projection_sigma
    mu_map = mur_map * active_inds_mur * projection_mu

    return sigma_map, mu_map

# %%
src_locations
# Out:
# array([[   0.,    0., -510.],
#        [   0.,    0., -520.]])

# %%
def create_survey(freq, components=["x"]): 
    rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
    rx_list = []
    if "x" in components: 
        rx_list.append([rx_ex_re, rx_ex_im])
    if "z" in components: 
        rx_list.append([rx_ez_re, rx_ez_im])
    src = fdem.sources.LineCurrent(list(np.hstack(rx_list)), location=src_locations, frequency=freq)
    return fdem.Survey([src])

# %%
# create the simulation
def create_simulation(key, survey, invert_mu=False, true_inds=False):
    sigma_map, mu_map = create_maps(key, true_inds)

    if invert_mu is True: 
        wires = maps.Wires(("sigma", 1), ("mu", 1))
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map * wires.sigma,
            muMap=mu_map * wires.mu 
        )
    else: 
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map
        )
    return sim

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)

data0 = {}
res0 = {}
rms0 = {}

components = ["x", "z"]

for i, key in enumerate(keys): 
    data_tmp = {}
    res_tmp = {}
    rms_tmp = {}
    
    for freq in frequencies: 
        survey = create_survey(freq, components)
    
        receivers = []
        if "x" in components: 
            receivers.append(["real_x", "imag_x"])
        if "z" in components: 
            receivers.append(["real_z", "imag_z"])
        dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])
    
        sim = create_simulation(key, survey, invert_mu=False)
        dpred = sim.dpred(np.log(sigdc[i]))

        data_tmp[freq] = dpred
        res_tmp[freq] = dpred - dobsvec
        rms_tmp[freq] = np.sqrt(np.sum(res_tmp[freq]**2) / len(res_tmp[freq]))
    data0[key] = data_tmp
    res0[key] = res_tmp
    rms0[key] = rms_tmp

# %%
fig, ax = plt.subplots(2, 1)

freq = frequencies[14]
print(freq)
for i, key in enumerate(keys): 
    dobs = dobs_dict[key][freq]["real_x"][:len(rx_x)]
    d0 = data0[key][freq][:len(rx_x)]
    ax[0].semilogy(rx_x, np.abs(dobs), color=f"C{i}", label=key)
    ax[0].semilogy(rx_x, np.abs(d0), f"--C{i}")
    ax[0].semilogy(rx_x, np.abs(d0-dobs), f":C{i}")

    ax[1].plot(rx_x, np.abs(d0-dobs)/np.abs(dobs)*100, f"C{i}")
# Out:
# 10.0

# %% [markdown]
# # set up inversions

# %%
class SaveInversionProgress(directives.InversionDirective):
    """
    A custom directive to save items of interest during the course of an inversion
    """
    
    results_file = None
    
    def initialize(self):
        """
        This is called when we first start running an inversion
        """
        # initialize an empty dictionary for storing results 
        self.inversion_results = {
            "iteration":[],
            "phi_d":[],
            "dpred":[],
            "logsigma":[],
            "residual":[],
            "rms":[],
            # "mur":[]
        }

    def endIter(self):
        """
        This is run at the end of every iteration. So here, we just append 
        the new values to our dictionary
        """
        
        # Save the data
        self.inversion_results["iteration"].append(self.opt.iter)
        self.inversion_results["phi_d"].append(self.invProb.phi_d)
        self.inversion_results["dpred"].append(self.invProb.dpred)
        
        dobs = self.invProb._dmisfit.objfcts[0].data.dobs
        
        self.inversion_results["residual"].append((dobs - self.invProb.dpred))
        self.inversion_results["rms"].append(np.sqrt(np.sum(self.inversion_results["residual"][-1]**2)/len(dobs)))
        self.inversion_results["logsigma"].append(self.invProb.model[0])
        # self.inversion_results["mur"].append(self.invProb.model[0])
        
        if self.results_file is not None: 
            with open(f"{self.results_file}", "wb") as fp:
                pickle.dump(self.inversion_results, fp)

# %%
tmp = []
tmp.append(["a", "b"])
np.hstack(tmp)
# Out:
# array(['a', 'b'], dtype='<U1')

# %%
def create_inversion(
    key, freq, invert_mu=False, relative_error=None, noise_floor=None,
    maxIter=10, maxIterCG=50, maxIterLS=10, true_casing_inds=False, components=["x"]
):
    # create the simulation
    survey = create_survey(freq, components)

    receivers = []
    if "x" in components: 
        receivers.append(["real_x", "imag_x"])
    if "z" in components: 
        receivers.append(["real_z", "imag_z"])
    dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])
    dobs = data.Data(
        survey=survey, dobs=dobsvec, relative_error=relative_error, noise_floor=noise_floor
    )

    sim = create_simulation(key, survey, invert_mu, true_casing_inds)
    dmis = data_misfit.L2DataMisfit(data=dobs, simulation=sim)

    if invert_mu is True: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([2]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )
        # opt = optimization.InexactGaussNewton(
        #     maxIter=maxIter, #lower=np.r_[-np.inf, 1], 
        #     maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        #     aggressive_stepping=True
        #     # tolF=1e-3, tolX=1e-3,
        # )
    else: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([1]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )
        # opt = optimization.InexactGaussNewton(
        #     maxIter=maxIter, #lower=np.r_[-np.inf, 1], 
        #     maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        #     aggressive_stepping=True
        #     # tolF=1e-3, tolX=1e-3,
        # )

    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=0)

    # directives
    target_misfit = directives.TargetMisfit(chifact=0.5)
    
    if true_casing_inds:
        filename_save = f"inv_{key}_{freq:1.0f}_true_casing.pkl"
    else: 
        filename_save = f"inv_{key}_{freq:1.0f}.pkl"
    inversion_progress = SaveInversionProgress(results_file=f"{directory_path}/{filename_save}")
    
    # inversion 
    inv = inversion.BaseInversion(inv_prob, [target_misfit, inversion_progress])
    
    return inv

# %% [markdown]
# # experiment 2: invert for solid cylinder conductivity, permeability

# %%
keys
# Out:
# ['casing_sig1e+05_mur1',
#  'casing_sig5e+05_mur1',
#  'casing_sig1e+06_mur1',
#  'casing_sig5e+06_mur1',
#  'casing_sig1e+07_mur1']

# %%
models.keys()
# Out:
# dict_keys(['casing_sig1e+05_mur1', 'casing_sig5e+05_mur1', 'casing_sig1e+06_mur1', 'casing_sig5e+06_mur1', 'casing_sig1e+07_mur1'])

# %%
inv_dict = {}
relative_error = 0.005
noise_floor = 1e-8

for key in keys:
    if key not in inv_dict: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = create_inversion(
                    key, freq, invert_mu=False, relative_error=relative_error, noise_floor=noise_floor,
                    components=["x", "z"]
                )
        inv_dict[key] = tmp

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)
# starting_models = {
#     True: np.r_[np.log(sigstart), 1],
#     False: np.r_[np.log(sigstart)]
# }
sigdc
# Out:
# array([  19000.,   95000.,  190000.,  950000., 1900000.])

# %%
mrec_dict = {}

for i, key in enumerate(keys):
    if key not in mrec_dict: 
        tmp = {}
        for freq in frequencies:
            print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
            tmp[freq] = inv_dict[key][freq].run(np.log(sigdc[i])) 
            print(f"recovered conductivity: {np.exp(inv_dict[key][freq].m[0]):1.2e} \n")
        mrec_dict[key] = tmp
# Out:
# ------------------------ casing_sig1e+05_mur1 : 0.1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.56e+01  0.00e+00  1.56e+01    2.45e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6575e+00
# 1 : |xc-x_last| = 2.8490e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4472e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4472e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.13894954943731375 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.56e+01  0.00e+00  1.56e+01    2.45e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6585e+00
# 1 : |xc-x_last| = 2.8495e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4476e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4476e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.193069772888325 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.56e+01  0.00e+00  1.56e+01    2.45e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6605e+00
# 1 : |xc-x_last| = 2.8504e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4485e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4485e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.2682695795279726 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.56e+01  0.00e+00  1.56e+01    2.45e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6643e+00
# 1 : |xc-x_last| = 2.8522e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4502e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4502e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.372759372031494 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.57e+01  0.00e+00  1.57e+01    2.45e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6717e+00
# 1 : |xc-x_last| = 2.8556e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4534e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4534e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.517947467923121 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.59e+01  0.00e+00  1.59e+01    2.46e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6859e+00
# 1 : |xc-x_last| = 2.8622e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4597e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4597e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 0.7196856730011519 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.61e+01  0.00e+00  1.61e+01    2.47e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7133e+00
# 1 : |xc-x_last| = 2.8750e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4719e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4719e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.67e+01  0.00e+00  1.67e+01    2.50e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7662e+00
# 1 : |xc-x_last| = 2.8994e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.4952e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4952e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1.3894954943731375 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.77e+01  0.00e+00  1.77e+01    2.54e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.8679e+00
# 1 : |xc-x_last| = 2.9463e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.5400e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.5400e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1.9306977288832496 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.96e+01  0.00e+00  1.96e+01    2.63e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0626e+00
# 1 : |xc-x_last| = 3.0354e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.6256e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6256e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 2.6826957952797246 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.33e+01  0.00e+00  2.33e+01    2.79e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4333e+00
# 1 : |xc-x_last| = 3.2025e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 2.7878e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7878e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 3.72759372031494 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.03e+01  0.00e+00  3.03e+01    3.09e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.1303e+00
# 1 : |xc-x_last| = 3.5088e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 3.0902e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0902e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 5.17947467923121 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.31e+01  0.00e+00  4.31e+01    3.64e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.4143e+00
# 1 : |xc-x_last| = 4.0472e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 3.6398e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.6398e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 7.196856730011517 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.60e+01  0.00e+00  6.60e+01    4.60e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.7025e+00
# 1 : |xc-x_last| = 4.9318e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 4.5960e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.5960e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 10.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.05e+02  0.00e+00  1.05e+02    6.15e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0583e+01
# 1 : |xc-x_last| = 6.2381e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 6.1473e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.1473e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 13.894954943731374 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.66e+02  0.00e+00  1.66e+02    8.40e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6722e+01
# 1 : |xc-x_last| = 7.8852e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 8.3970e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.3970e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 19.306977288832496 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+02  0.00e+00  2.55e+02    1.11e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5637e+01
# 1 : |xc-x_last| = 9.5309e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.1095e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.1095e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.88e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 26.826957952797247 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.75e+02  0.00e+00  3.75e+02    1.33e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.7590e+01
# 1 : |xc-x_last| = 1.0627e-02 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.3307e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3307e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.88e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 37.27593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.34e+02  0.00e+00  5.34e+02    1.36e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.3530e+01
# 1 : |xc-x_last| = 1.0711e-02 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.3601e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3601e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.88e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 51.794746792312075 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.70e+02  0.00e+00  7.70e+02    1.16e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.7098e+01
# 1 : |xc-x_last| = 9.9148e-03 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.1604e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.1604e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.88e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 71.96856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.11e+03  0.00e+00  1.11e+03    8.65e+03      0
#    1  0.00e+00  1.07e+03  7.80e-05  1.07e+03    1.04e+02      0
#    2  0.00e+00  1.07e+03  7.61e-05  1.07e+03    1.09e+00      0
#    3  0.00e+00  1.07e+03  7.62e-05  1.07e+03    1.09e+00      0
#    4  0.00e+00  1.07e+03  7.62e-05  1.07e+03    1.09e+00      9   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.0723e+03 <= alp*descent     = 1.0723e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.88e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 100.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.53e+03  0.00e+00  1.53e+03    4.82e+03      0
#    1  0.00e+00  1.51e+03  4.21e-05  1.51e+03    8.48e+01      0
#    2  0.00e+00  1.51e+03  4.07e-05  1.51e+03    1.35e+00      0
#    3  0.00e+00  1.51e+03  4.07e-05  1.51e+03    1.35e+00      0
#    4  0.00e+00  1.51e+03  4.07e-05  1.51e+03    1.35e+00      1   Skip BFGS
#    5  0.00e+00  1.51e+03  4.07e-05  1.51e+03    1.35e+00      7
# ------------------------------------------------------------------
# 0 :    ft     = 1.5148e+03 <= alp*descent     = 1.5148e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 138.94954943731375 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.05e+03  0.00e+00  2.05e+03    1.59e+03      0
#    1  0.00e+00  2.04e+03  9.80e-06  2.04e+03    3.72e+01      0
#    2  0.00e+00  2.04e+03  9.35e-06  2.04e+03    3.72e+01      0
#    3  0.00e+00  2.04e+03  8.91e-06  2.04e+03    3.72e+01      0
# ------------------------------------------------------------------
# 0 :    ft     = 2.0450e+03 <= alp*descent     = 2.0450e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.89e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 193.06977288832496 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.66e+03  0.00e+00  2.66e+03    4.90e+02      0
#    1  0.00e+00  2.66e+03  2.24e-06  2.66e+03    1.43e+01      0
#    2  0.00e+00  2.66e+03  2.11e-06  2.66e+03    1.43e+01      0
# ------------------------------------------------------------------
# 0 :    ft     = 2.6576e+03 <= alp*descent     = 2.6576e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.90e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 268.26957952797244 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.30e+03  0.00e+00  3.30e+03    4.71e+02      0
#    1  0.00e+00  3.30e+03  4.49e-06  3.30e+03    1.47e+01      0
#    2  0.00e+00  3.30e+03  4.21e-06  3.30e+03    1.47e+01      0
#    3  0.00e+00  3.30e+03  3.95e-06  3.30e+03    1.47e+01      0
#    4  0.00e+00  3.30e+03  3.93e-06  3.30e+03    1.47e+01      4   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 3.3033e+03 <= alp*descent     = 3.3033e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.90e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 372.7593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.58e+03  0.00e+00  3.58e+03    5.08e+02      0
#    1  0.00e+00  3.58e+03  1.89e-05  3.58e+03    1.63e+01      0
#    2  0.00e+00  3.58e+03  1.77e-05  3.58e+03    5.60e-01      0
#    3  0.00e+00  3.58e+03  1.77e-05  3.58e+03    5.60e-01      1
#    4  0.00e+00  3.58e+03  1.78e-05  3.58e+03    5.60e-01      0   Skip BFGS
#    5  0.00e+00  3.58e+03  1.78e-05  3.58e+03    5.60e-01      2
#    6  0.00e+00  3.58e+03  1.78e-05  3.58e+03    5.60e-01      7
# ------------------------------------------------------------------
# 0 :    ft     = 3.5751e+03 <= alp*descent     = 3.5751e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.91e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 517.9474679231207 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.67e+03  0.00e+00  3.67e+03    1.10e+03      0
#    1  0.00e+00  3.66e+03  4.26e-04  3.66e+03    1.90e+01      0
#    2  0.00e+00  3.66e+03  4.11e-04  3.66e+03    5.11e-01      0
#    3  0.00e+00  3.66e+03  4.11e-04  3.66e+03    5.11e-01      4
#    4  0.00e+00  3.66e+03  4.11e-04  3.66e+03    5.11e-01      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 3.6627e+03 <= alp*descent     = 3.6627e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.94e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 719.6856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.68e+03  0.00e+00  3.68e+03    7.51e+02      0
#    1  0.00e+00  3.66e+03  1.09e-03  3.66e+03    3.84e+01      0
#    2  0.00e+00  3.66e+03  1.21e-03  3.66e+03    1.69e+00      0   Skip BFGS
#    3  0.00e+00  3.66e+03  1.21e-03  3.66e+03    1.69e+00      3   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 3.6634e+03 <= alp*descent     = 3.6634e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.97e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.14e+03  0.00e+00  3.14e+03    1.41e+03      0
#    1  0.00e+00  3.02e+03  1.81e-02  3.02e+03    4.10e+02      0
#    2  0.00e+00  3.01e+03  3.49e-02  3.01e+03    1.61e+02      0   Skip BFGS
#    3  0.00e+00  3.00e+03  4.40e-02  3.00e+03    7.20e+01      0   Skip BFGS
#    4  0.00e+00  3.00e+03  4.86e-02  3.00e+03    3.40e+01      0   Skip BFGS
#    5  0.00e+00  3.00e+03  5.10e-02  3.00e+03    1.65e+01      0   Skip BFGS
#    6  0.00e+00  3.00e+03  5.21e-02  3.00e+03    8.07e+00      0   Skip BFGS
#    7  0.00e+00  3.00e+03  5.27e-02  3.00e+03    3.98e+00      0   Skip BFGS
#    8  0.00e+00  3.00e+03  5.30e-02  3.00e+03    1.97e+00      0   Skip BFGS
#    9  0.00e+00  3.00e+03  5.31e-02  3.00e+03    9.77e-01      0   Skip BFGS
#   10  0.00e+00  3.00e+03  5.32e-02  3.00e+03    4.85e-01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.1249e-04 <= tolF*(1+|f0|) = 3.1375e+02
# 1 : |xc-x_last| = 1.5230e-04 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 4.8492e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.8492e-01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.39e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1389.4954943731361 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.78e+03  0.00e+00  2.78e+03    1.99e+03      0
#    1  0.00e+00  2.10e+03  1.96e-01  2.10e+03    1.22e+03      0
#    2  0.00e+00  1.69e+03  8.50e-01  1.69e+03    4.54e+02      0   Skip BFGS
#    3  0.00e+00  1.63e+03  1.36e+00  1.63e+03    5.01e+01      0   Skip BFGS
#    4  0.00e+00  1.63e+03  1.44e+00  1.63e+03    2.80e+00      0   Skip BFGS
#    5  0.00e+00  1.63e+03  1.45e+00  1.63e+03    1.39e-01      0   Skip BFGS
#    6  0.00e+00  1.63e+03  1.45e+00  1.63e+03    1.39e-01      4   Skip BFGS
#    7  0.00e+00  1.63e+03  1.45e+00  1.63e+03    1.39e-01      2   Skip BFGS
#    8  0.00e+00  1.63e+03  1.45e+00  1.63e+03    1.39e-01      0
# ------------------------------------------------------------------
# 0 :    ft     = 1.6271e+03 <= alp*descent     = 1.6271e+03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 6.33e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1930.6977288832495 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.66e+03  0.00e+00  1.66e+03    1.61e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6659e+02
# 1 : |xc-x_last| = 7.4873e-01 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.6142e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6142e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.02e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 2682.695795279722 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  9.78e+02  0.00e+00  9.78e+02    1.35e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.7912e+01
# 1 : |xc-x_last| = 1.0712e+00 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 1.3481e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3481e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.55e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 3727.593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.61e+02  0.00e+00  5.61e+02    8.95e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.6249e+01
# 0 : |xc-x_last| = 1.0922e+00 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 8.9480e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.9480e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.66e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 5179.474679231213 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.55e+02  0.00e+00  2.55e+02    4.15e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5564e+01
# 0 : |xc-x_last| = 1.1197e+00 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 4.1485e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.1485e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.82e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 7196.856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.23e+02  0.00e+00  2.23e+02    4.11e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2407e+01
# 1 : |xc-x_last| = 1.0727e+00 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 4.1062e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.1062e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.55e+04
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 10000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.14e+01  0.00e+00  4.14e+01    7.51e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.2392e+00
# 0 : |xc-x_last| = 1.0872e+00 <= tolX*(1+|x0|) = 1.0852e+00
# 0 : |proj(x-g)-x|    = 7.5133e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.5133e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.64e+04
#
#
#
# ------------------------ casing_sig5e+05_mur1 : 0.1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.35e+01  0.00e+00  2.35e+01    1.64e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4509e+00
# 1 : |xc-x_last| = 7.5681e-03 <= tolX*(1+|x0|) = 1.2462e+00
# 0 : |proj(x-g)-x|    = 1.6438e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6438e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.43e+04
#
#
#
# ------------------------ casing_sig5e+05_mur1 : 0.13894954943731375 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.36e+01  0.00e+00  2.36e+01    1.64e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4572e+00
# 1 : |xc-x_last| = 7.5726e-03 <= tolX*(1+|x0|) = 1.2462e+00
# 0 : |proj(x-g)-x|    = 1.6449e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6449e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.43e+04
#
#
# ...
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.7796e+01
# 1 : |xc-x_last| = 1.0100e+00 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 7.0985e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.0985e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 5.22e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 193.06977288832496 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.63e+02  0.00e+00  2.63e+02    5.19e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6447e+01
# 1 : |xc-x_last| = 9.5026e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 5.1866e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1866e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.91e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 268.26957952797244 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.69e+02  0.00e+00  1.69e+02    3.46e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7027e+01
# 1 : |xc-x_last| = 8.6349e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 3.4590e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4590e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.51e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 372.7593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.14e+02  0.00e+00  1.14e+02    2.30e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1517e+01
# 1 : |xc-x_last| = 7.9351e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 2.3011e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3011e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.20e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 517.9474679231207 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.99e+01  0.00e+00  6.99e+01    1.56e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.0948e+00
# 1 : |xc-x_last| = 7.9274e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 1.5616e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.5616e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.20e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 719.6856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.97e+01  0.00e+00  3.97e+01    8.92e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.0723e+00
# 1 : |xc-x_last| = 7.8476e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 8.9225e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.9225e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.16e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 1000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.27e+01  0.00e+00  2.27e+01    5.11e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3749e+00
# 1 : |xc-x_last| = 7.0322e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 5.1127e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1127e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.84e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 1389.4954943731361 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.25e+01  0.00e+00  1.25e+01    2.81e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3546e+00
# 1 : |xc-x_last| = 6.0170e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 2.8071e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8071e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.47e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 1930.6977288832495 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.46e+00  0.00e+00  7.46e+00    1.43e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.4622e-01
# 1 : |xc-x_last| = 5.8696e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 1.4258e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4258e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.42e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 2682.695795279722 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.13e+00  0.00e+00  6.13e+00    4.79e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.1301e-01
# 1 : |xc-x_last| = 3.4542e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 4.7890e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.7890e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.68e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 3727.593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.73e+00  0.00e+00  1.73e+00    2.93e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.7262e-01
# 1 : |xc-x_last| = 3.6671e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 2.9302e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9302e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.74e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 5179.474679231213 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.83e+00  0.00e+00  1.83e+00    1.39e-01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.8346e-01
# 1 : |xc-x_last| = 3.9451e-02 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 1.3928e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3928e-01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.98e+06
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 7196.856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.12e+00  0.00e+00  7.12e+00    4.89e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.1151e-01
# 1 : |xc-x_last| = 1.3482e+00 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 4.8929e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.8929e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.93e+05
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 10000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.92e-01  0.00e+00  4.92e-01    1.18e-01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.4918e-01
# 1 : |xc-x_last| = 1.7965e-01 <= tolX*(1+|x0|) = 1.5457e+00
# 0 : |proj(x-g)-x|    = 1.1777e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.1777e-01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.59e+06

# %%
inv_results = {}

for key in keys:
    if key not in inv_results: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = inv_dict[key][freq].directiveList.dList[1].inversion_results
        inv_results[key] = tmp

# %%
tmp = inv_results[keys[0]][frequencies[0]]

# %%
tmp = inv_dict[keys[0]][frequencies[0]]

# %%
phi_d_final = {}
chifact_final = {}
phid_star = len(rx_x)*len(rx_z)*2

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            phid_tmp[i] = phid[-1]
    phi_d_final[key] = phid_tmp
    chifact_final[key] = phi_d_final[key] / phid_star

# %%
phid_min = {}
chifact_min = {}
mrec_min = {}
rms_min = {}

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    mrec_tmp = np.ones(len(frequencies)) * np.nan
    rms_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            ind_min = np.argmin(phid)
            phid_tmp[i] = phid[ind_min]
            mrec_tmp[i] = inv_results[key][freq]["logsigma"][ind_min]
            rms_tmp[i] = inv_results[key][freq]["rms"][ind_min]
    phid_min[key] = phid_tmp
    mrec_min[key] = mrec_tmp
    rms_min[key] = rms_tmp

# %%
inv_results[key][freq]["rms"]
# Out:
# [1.4104200352682834e-09]

# %%
fig, ax = plt.subplots(2, 1, figsize=(6, 8), sharex=True) 

for key in keys: 
    ax[0].loglog(frequencies, phi_d_final[key], "o", label=key)
    ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
    ax[1].loglog(frequencies, np.exp(np.hstack(mrec_dict[key].values())), "o", label=key)
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
ax[1].legend()
# Out:
# /tmp/ipykernel_2284918/3641268160.py:6: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   ax[1].loglog(frequencies, np.exp(np.hstack(mrec_dict[key].values())), "o", label=key)

# %% [markdown]
# <!-- ![image.png](attachment:ed16e814-577d-4508-b493-db3d23be7ee1.png) -->

# %%
markers = ["s", "v", "o", "D", "p", "D", "h"]
colors = ["C5", "C6", "k", "C9"]

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 6), sharex=True, dpi=dpi_high) 

for i, key in enumerate(keys[1:]): 
    label = f"{sigma_casing[i+1]:1.0e} S/m"
    ax[0].loglog(frequencies, rms_min[key], f"-{markers[i]}", color=colors[i], lw=0.75, ms=4, label=label)
    ax[1].loglog(frequencies, np.exp(mrec_min[key]), f"-{markers[i]}", color=colors[i], lw=0.75, ms=4, label=label)

sig_t = 500**2 / ((casing_b/4)**2 * frequencies)
ax[1].loglog(frequencies, sig_t, ":k", alpha=0.2)

sig_b = 500**2 / ((casing_b/2)**2 * frequencies)
ax[1].loglog(frequencies, sig_b, ":k", alpha=0.2)

ax[1].text(6, 1.2e7, "$\delta\sim b/2$", alpha=0.7)
# ax[1].text(2.3e2, 1.2e7, "$\delta\sim t$", alpha=0.7)
ax[0].legend()

ax[0].set_ylabel("RMS Misfit (V/m)")
ax[1].set_ylabel("Recovered $\sigma$ (S/m)")
ax[1].set_xlabel("frequency (Hz)")
ax[1].set_ylim(6e4, 2e7)

ax[0].set_title("(a)")
ax[1].set_title("(b)")
for a in ax:
    a.grid()

plt.tight_layout()

# %% [markdown]
# <!-- ![image.png](attachment:63ca319b-3e3c-49be-b9e0-c265ed4a4f3e.png) -->

# %%
casing_b

# %%
len(rx_x)

# %%
fig, ax = plt.subplots(1, 1) 
for key in keys: 
    max_diff = np.hstack([np.max(np.abs(res0[key][f]))for f in frequencies])
    ax.loglog(frequencies, max_diff, "o", label=key)

# %%
500/np.sqrt(sigma_casing * 2)

# %%
casing_t

# %%
skin_depths_casing = 500/np.sqrt(np.outer(sigma_casing,frequencies)).T

fig, ax = plt.subplots(1, 1) 
ax.loglog(frequencies, skin_depths_casing)
ax.loglog(frequencies, np.ones_like(frequencies)*casing_t, "--k")
ax.loglog(frequencies, np.ones_like(frequencies)*csz, ":k")

# %%
# fig, ax = plt.subplots(1,1) 

# for i, key in enumerate(mrec_dict.keys()):
#     for f, val in mrec_dict[key].items():
#         ax.loglog(
#             f, np.exp(val[False]), f"C{i}o", 
#             label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
#         )

# %%
# key = "casing_1_1.00e-02"
# freq = frequencies[freq_inds_inv[0]]

# plot_obs_pred(key, freq, False);
