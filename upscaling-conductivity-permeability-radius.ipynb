# %% [markdown]
# # upscaling when the thickness changes

# %%
import numpy as np
import os
import scipy.sparse as sp
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, LinearSegmentedColormap, Normalize
from matplotlib import cm as colormap
import time
from string import ascii_lowercase
import pickle
from multiprocessing import Pool
from sklearn import linear_model

# SimPEG, discretize/
import discretize
from discretize import utils
from simpeg.electromagnetics import frequency_domain as fdem
from simpeg import(
    maps, Report, data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils
)
from pymatsolver import Pardiso

from utils import pad_for_casing_and_data

# %%
from matplotlib import rcParams
rcParams["font.size"] = 16

# %%
directory_path = "/t40array/lheagy/casing-upscaling-permeable-vary-radius"

# %%
def ensure_directory_exists(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# Example usage
ensure_directory_exists(directory_path)
# Out:
# Directory '/t40array/lheagy/casing-upscaling-permeable-vary-radius' already exists.

# %%
save_figures = False
fig_dir_high = "figures"
fig_dir_low = "low-rez-figures"

dpi_high=400
dpi_low=150

# %% [markdown]
# ## Simulation parameters

# %%
# # conductivities
sigma_air = 1e-4
sigma_back = 1e-1
casing_l = 500
sigma_casing = 5e6
mur_casing = np.r_[1, 10, 25, 50, 100, 150, 200]

# # casing geometry
casing_b = np.r_[2.5e-2, 5e-2, 1e-1, 2e-1, 4e-1]
casing_t = 1e-2 #np.r_[5e-3, 1e-2, 1.5e-2, 2e-2, 2.5e-2, 3e-2]  #np.r_[5e-3, 7.5e-3, 10e-3, 12.5e-3, 15e-3, 20e-3]
casing_a = casing_b - casing_t

# %%
src_dz = 10
src_z = -515 #np.r_[-100, -250, -400, -495, -500, -550, -600]

# %%
# generate a mesh
hx = pad_for_casing_and_data(
   casing_outer_radius = casing_b.max(),
    csx1 = casing_t/4, 
    csx2 = 25, 
    pfx1 = 1.3,
    pfx2 = 1.5, 
    domain_x = 1000, 
    npadx = 10
)

pfz = 1.3
npad_z = 28
csz = 1
n_core_extra = 10
ncore_z = int(np.max(np.r_[np.abs(casing_l), np.abs(src_z)]) / csz) + n_core_extra
hz = discretize.utils.unpack_widths(
    [(csz, npad_z, -pfz), (csz, ncore_z), (csz, npad_z, pfz)]
)

# %%
mesh = discretize.CylindricalMesh(
    [hx, np.r_[2*np.pi], hz], origin=np.r_[0, 0, -np.sum(hz[:npad_z + int(ncore_z)])],
)

fig, ax = plt.subplots(1, 1)
mesh.plot_grid(ax=ax)
# ax.set_xlim([0, 5])
# ax.set_ylim(-50, 10)
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
mesh.n_cells
# Out:
# 143507

# %%
def get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sigma_casing, sigma_air=1e-4, mur_casing=1):

    model = np.ones(mesh.n_cells)*sigma_air
    model[mesh.cell_centers[:, 2] < 0] = sigma_back

    mur = np.ones(mesh.n_cells)

    inds_casing_x = (
        (mesh.cell_centers[:, 0] > casing_a) & 
        (mesh.cell_centers[:, 0] < casing_b)
    )
    inds_casing_z = (
        (mesh.cell_centers[:, 2] < 0) &
        (mesh.cell_centers[:, 2] > -casing_l)
    )
    inds_casing = inds_casing_x & inds_casing_z

    model[inds_casing] = sigma_casing
    mur[inds_casing] = mur_casing

    return model, mur

# %%
models = {}
for b in casing_b: 
    for mur in mur_casing:
        key = f"casing_mur{mur:1.0f}_b{b:1.1e}"
        sig_model, mur_model = get_physical_property_model(mesh, b - casing_t, b, casing_l, sigma_back, sigma_casing, mur_casing=mur)
        models[key] = {
            "sigma": sig_model, 
            "mur": mur_model
        }
keys = list(models.keys())

# %%
keys
# Out:
# ['casing_mur1_b2.5e-02',
#  'casing_mur10_b2.5e-02',
#  'casing_mur25_b2.5e-02',
#  'casing_mur50_b2.5e-02',
#  'casing_mur100_b2.5e-02',
#  'casing_mur150_b2.5e-02',
#  'casing_mur200_b2.5e-02',
#  'casing_mur1_b5.0e-02',
#  'casing_mur10_b5.0e-02',
#  'casing_mur25_b5.0e-02',
#  'casing_mur50_b5.0e-02',
#  'casing_mur100_b5.0e-02',
#  'casing_mur150_b5.0e-02',
#  'casing_mur200_b5.0e-02',
#  'casing_mur1_b1.0e-01',
#  'casing_mur10_b1.0e-01',
#  'casing_mur25_b1.0e-01',
#  'casing_mur50_b1.0e-01',
#  'casing_mur100_b1.0e-01',
#  'casing_mur150_b1.0e-01',
#  'casing_mur200_b1.0e-01',
#  'casing_mur1_b2.0e-01',
#  'casing_mur10_b2.0e-01',
#  'casing_mur25_b2.0e-01',
#  'casing_mur50_b2.0e-01',
#  'casing_mur100_b2.0e-01',
#  'casing_mur150_b2.0e-01',
#  'casing_mur200_b2.0e-01',
#  'casing_mur1_b4.0e-01',
#  'casing_mur10_b4.0e-01',
#  'casing_mur25_b4.0e-01',
#  'casing_mur50_b4.0e-01',
#  'casing_mur100_b4.0e-01',
#  'casing_mur150_b4.0e-01',
#  'casing_mur200_b4.0e-01']

# %%
def plot_casing(model, xlim=None, zlim=None, vmin=None, vmax=None, ax=None, cb_label=None, logscale=True, show_cb=False): 
    if ax is None: 
        fig, ax = plt.subplots(1, 1)
    if logscale is True: 
        pcolor_opts={"norm":LogNorm(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    else: 
        pcolor_opts={"norm":Normalize(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    out = mesh.plot_image(
        model, pcolor_opts=pcolor_opts, ax=ax, mirror=True
    )

    if show_cb is True: 
        cb = plt.colorbar(out[-1], shrink=0.5)
        cb.set_label(cb_label)

    if xlim is not None: 
        ax.set_xlim(xlim)
    if zlim is not None: 
        ax.set_ylim(zlim)

    ax.set_xlabel("x (m)")
    ax.set_ylabel("z (m)")
    return ax, out

# %%
# fig, ax = plt.subplots(1, 2, figsize=(2*4.5, 6.5), dpi=dpi_high, sharey=True)

# xlim = 0.3*np.r_[-1, 1]
# zlim = np.r_[-590, 20]
# vmin = sigma_air
# vmax = sigma_casing

# sigma_map, mu_map = create_maps(key)

# _, out = plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[0])
# _, out = plot_casing(sigma_map * np.r_[np.log(1e5)], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[1])
# # cb.set_label("conductivity (S/m)")

# for i, a in enumerate(ax): 
#     a.plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok", ms=4)
#     a.text(0.01, src_z, "10m dipole", va="center", fontsize=14)
#     for sign in np.r_[-1, 1]: 
#         if i == 0: 
#             a.arrow(
#                 0, -casing_l+120, casing_a*sign, 0, length_includes_head=True, shape="full", width=1e-2,
#                 head_length=1e-2, head_width=10, color="k"
#             ) 
#             a.text(0, -casing_l+100, f"{casing_a*1e2*2:1.0f} cm", ha="center", fontsize=10)
#             a.text(0.06, -200, "$\sigma$: 5e6 S/m \n$\mu>\mu_0$", fontsize=14)
#         else: 
#             a.text(0.06, -200, "$\sigma$: ? \n$\mu:?$", fontsize=14)
        
#         a.arrow(
#             0, -casing_l+80, casing_b*sign, 0, length_includes_head=True, shape="full", width=1e-2,
#             head_length=1e-2, head_width=10, color="k"
#         )
#         a.text(0, -casing_l+55, f"{casing_b*1e2*2:1.0f} cm", ha="center", fontsize=10)
#         a.text(-0.29, zlim.min()+10, f"{(1./sigma_back[0]):1.0f} $\Omega$m", fontsize=14)

# ax[1].set_ylabel("")

# ax[0].set_title("(a) true cased well")
# ax[1].set_title("(b) solid cylinder")

# %%
plot_keys = keys[:5]
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 1*np.r_[-1, 1]
zlim = np.r_[-600, 10]
vmin = sigma_air
vmax = np.max(sigma_casing)

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i])
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %%
# plot_keys = keys
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 0.2*np.r_[-1, 1]
zlim = np.r_[-600, 10]
vmin = 1
vmax = mur_casing.max()

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["mur"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i], logscale=False)
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %% [markdown]
# ## set up the simulations

# %%
frequencies = np.r_[1] #10**np.linspace(-1, 4, 36)
frequencies
# Out:
# array([1])

# %%
src_list = []
src_locations = np.array([
    [0, 0, src_z+src_dz/2.],
    [0, 0, src_z-src_dz/2.]
])
for f in frequencies: 
    src = fdem.sources.LineCurrent([], location=src_locations, frequency=f)
    src_list.append(src)

wires = maps.Wires(("sigma", mesh.n_cells), ("mur", mesh.n_cells))
permeability_map = maps.MuRelative(mesh)

survey = fdem.Survey(src_list)

sim = fdem.simulation.Simulation3DMagneticField(
    mesh=mesh, sigmaMap=wires.sigma, muMap=permeability_map * wires.mur,
    survey=survey, solver=Pardiso, #mu=mur * mu_0
#     verbose=True
)

# %%
def run_simulation(key):
    
    filename = os.path.sep.join([directory_path, key])

    t = time.time()
    print(f"starting {key}..., saving to {filename}")
    fields = sim.fields(np.r_[models[key]["sigma"], models[key]["mur"]])
    print(f" ... done. {time.time()-t:1.2e} \n")
    
    np.save(filename, fields[:, "hSolution"])

    return fields

# %%
fields = {}

# %%
for key in keys: 
    if key not in fields: 
        fields[key] = run_simulation(key)
# Out:
# starting casing_mur1_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur1_b2.5e-02
#  ... done. 1.33e+00
#
# starting casing_mur10_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur10_b2.5e-02
#  ... done. 8.51e-01
#
# starting casing_mur25_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur25_b2.5e-02
#  ... done. 7.16e-01
#
# starting casing_mur50_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur50_b2.5e-02
#  ... done. 6.47e-01
#
# starting casing_mur100_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur100_b2.5e-02
#  ... done. 5.92e-01
#
# starting casing_mur150_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur150_b2.5e-02
#  ... done. 6.06e-01
#
# starting casing_mur200_b2.5e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur200_b2.5e-02
#  ... done. 6.20e-01
#
# starting casing_mur1_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur1_b5.0e-02
#  ... done. 5.97e-01
#
# starting casing_mur10_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur10_b5.0e-02
#  ... done. 8.48e-01
#
# starting casing_mur25_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur25_b5.0e-02
#  ... done. 7.30e-01
#
# starting casing_mur50_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur50_b5.0e-02
#  ... done. 5.96e-01
#
# starting casing_mur100_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur100_b5.0e-02
#  ... done. 6.34e-01
#
# starting casing_mur150_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur150_b5.0e-02
#  ... done. 6.63e-01
#
# starting casing_mur200_b5.0e-02..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur200_b5.0e-02
#  ... done. 6.55e-01
#
# starting casing_mur1_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur1_b1.0e-01
#  ... done. 6.25e-01
#
# starting casing_mur10_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur10_b1.0e-01
#  ... done. 6.21e-01
#
# starting casing_mur25_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur25_b1.0e-01
#  ... done. 6.00e-01
#
# starting casing_mur50_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur50_b1.0e-01
#  ... done. 5.83e-01
#
# starting casing_mur100_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur100_b1.0e-01
#  ... done. 6.27e-01
#
# starting casing_mur150_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur150_b1.0e-01
#  ... done. 5.94e-01
#
# starting casing_mur200_b1.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur200_b1.0e-01
#  ... done. 5.74e-01
#
# starting casing_mur1_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur1_b2.0e-01
#  ... done. 6.19e-01
#
# starting casing_mur10_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur10_b2.0e-01
#  ... done. 5.99e-01
#
# starting casing_mur25_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur25_b2.0e-01
#  ... done. 6.05e-01
#
# starting casing_mur50_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur50_b2.0e-01
#  ... done. 6.03e-01
#
# starting casing_mur100_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur100_b2.0e-01
#  ... done. 6.76e-01
#
# starting casing_mur150_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur150_b2.0e-01
#  ... done. 6.39e-01
#
# starting casing_mur200_b2.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur200_b2.0e-01
#  ... done. 6.25e-01
#
# starting casing_mur1_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur1_b4.0e-01
#  ... done. 6.62e-01
#
# starting casing_mur10_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur10_b4.0e-01
#  ... done. 6.68e-01
#
# starting casing_mur25_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur25_b4.0e-01
#  ... done. 6.60e-01
#
# starting casing_mur50_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur50_b4.0e-01
#  ... done. 6.79e-01
#
# starting casing_mur100_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur100_b4.0e-01
#  ... done. 6.65e-01
#
# starting casing_mur150_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur150_b4.0e-01
#  ... done. 6.32e-01
#
# starting casing_mur200_b4.0e-01..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-radius/casing_mur200_b4.0e-01
#  ... done. 6.31e-01

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

key = keys[0]
freq_ind = 0
xlim = 500*np.r_[-1, 1]
zlim = np.r_[-1000, 10]

field_plot = (mesh.average_face_to_cell_vector * fields[key][sim.survey.source_list[freq_ind], "e"])

for i, component in enumerate(["real", "imag"]): 
    out = mesh.plot_image(
        getattr(field_plot, component), "CCv", view="vec", 
        range_x = xlim, range_y = zlim,
        sample_grid = np.r_[10, 10],
        mirror=True, #mirror_data=field_mirror,
        ax=ax[i], 
        pcolor_opts={"norm":LogNorm(vmin=1e-7, vmax=1e-2)}
    )
    cb = plt.colorbar(out[0], ax=ax[i])
    cb.set_label("Electric Field (V/m)")
    ax[i].set_aspect(1)
    ax[i].set_title(f"{frequencies[freq_ind]} Hz, {component}")
plt.tight_layout()

# %%
fields.keys()
# Out:
# dict_keys(['casing_mur1_b2.5e-02', 'casing_mur10_b2.5e-02', 'casing_mur25_b2.5e-02', 'casing_mur50_b2.5e-02', 'casing_mur100_b2.5e-02', 'casing_mur150_b2.5e-02', 'casing_mur200_b2.5e-02', 'casing_mur1_b5.0e-02', 'casing_mur10_b5.0e-02', 'casing_mur25_b5.0e-02', 'casing_mur50_b5.0e-02', 'casing_mur100_b5.0e-02', 'casing_mur150_b5.0e-02', 'casing_mur200_b5.0e-02', 'casing_mur1_b1.0e-01', 'casing_mur10_b1.0e-01', 'casing_mur25_b1.0e-01', 'casing_mur50_b1.0e-01', 'casing_mur100_b1.0e-01', 'casing_mur150_b1.0e-01', 'casing_mur200_b1.0e-01', 'casing_mur1_b2.0e-01', 'casing_mur10_b2.0e-01', 'casing_mur25_b2.0e-01', 'casing_mur50_b2.0e-01', 'casing_mur100_b2.0e-01', 'casing_mur150_b2.0e-01', 'casing_mur200_b2.0e-01', 'casing_mur1_b4.0e-01', 'casing_mur10_b4.0e-01', 'casing_mur25_b4.0e-01', 'casing_mur50_b4.0e-01', 'casing_mur100_b4.0e-01', 'casing_mur150_b4.0e-01', 'casing_mur200_b4.0e-01'])

# %%
def skin_depth(f, sigma, mur):
    return np.sqrt(2/(2*np.pi*f*sigma*mur*mu_0))

# %%
rx_x = np.linspace(25, 500, 20)
rx_z = -np.linspace(0, 600, 25) - csz/2
rx_z
# Out:
# array([-5.000e-01, -2.550e+01, -5.050e+01, -7.550e+01, -1.005e+02,
#        -1.255e+02, -1.505e+02, -1.755e+02, -2.005e+02, -2.255e+02,
#        -2.505e+02, -2.755e+02, -3.005e+02, -3.255e+02, -3.505e+02,
#        -3.755e+02, -4.005e+02, -4.255e+02, -4.505e+02, -4.755e+02,
#        -5.005e+02, -5.255e+02, -5.505e+02, -5.755e+02, -6.005e+02])

# %%
def create_receivers():
    rx_ex_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="real",
    )
    rx_ex_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="imag",
    )
    rx_ez_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="real",
    )
    rx_ez_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="imag",
    )
    return rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im

# %%
rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
Px = rx_ex_re.getP(mesh, "Fx")
Pz = rx_ez_re.getP(mesh, "Fz")

# %%
frequencies
# Out:
# array([1])

# %%
range(len(frequencies))
# Out:
# range(0, 1)

# %%
# get data_vectors
dobs_dict = {}

for k in keys:
    tmp_dict = {}
    for si in range(len(frequencies)):
        src = sim.survey.source_list[si]
        e = fields[k][src, "e"]
        edatax = (Px * e).squeeze()
        edataz = (Pz * e).squeeze()
        tmp_dict[frequencies[si]] = {
            "real_x": edatax.real,
            "imag_x": edatax.imag,
            "real_z": edataz.real,
            "imag_z": edataz.imag
        }
    dobs_dict[k] = tmp_dict

# %%
fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

key_ind = 0
key = keys[key_ind]

ax = np.atleast_2d(ax)
for i, freq in enumerate(frequencies): 
    # ax.plot(rx_x, dobs_dict[key][freq]["real"].reshape((len(rx_x), len(rx_z)), order="F"), "o" );
    for j, component in enumerate(["real_x", "imag_x"]): 
        plt.colorbar(
            ax[i, j].contourf(
                rx_x, rx_z, np.log10(np.abs(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T)), 30,
                # vmin=-7, vmax=-2
                # norm=LogNorm()
            ), ax=ax[i, j]
        )
        
        ax[i, j].plot(rx_ex_re.locations[:, 0], rx_ex_re.locations[:, 2], "w.", ms=1)
        ax[i, j].set_aspect(1)
        ax[i, j].set_title(f"{freq} Hz {component}")

plt.tight_layout()

# %%
def get_amplitude_phase(real, imag):
    # real = f.real
    # imag = f.imag
    amplitude = np.sqrt(real**2 + imag**2)
    phase = 180/np.pi*np.arctan2(imag, real)
    return amplitude, phase

# %%
# fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

# key_ind = 0
# key = keys[key_ind]

# for i, freq in enumerate(frequencies): 
#     amp, phase = get_amplitude_phase(*(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T for component in ["real", "imag"]))
#     for j, plotme in enumerate([np.log10(np.abs(amp)), phase]): 
#         plt.colorbar(
#             ax[i, j].contourf(
#                 rx_x, rx_z, plotme, 30,
#                 # vmin=-7, vmax=-2
#                 # norm=LogNorm()
#                 cmap = "twilight" if j == 1 else "viridis"
#             ), ax=ax[i, j]
#         )
        
#         ax[i, j].plot(rx_e_re.locations[:, 0], rx_e_re.locations[:, 2], "w.", ms=1)
#         ax[i, j].set_aspect(1)
#         ax[i, j].set_title(f"{freq} Hz {'amplitude' if j==0 else 'phase'}")

# plt.tight_layout()

# %% [markdown]
# # set up mappings and simulation

# %%
def create_maps(key, true_inds=False, casing_t_ind=0):
    casing_b_ind = get_casing_radius_ind_by_key(key)
    indsx = (mesh.cell_centers[:, 0] < casing_b[casing_b_ind])
    if true_inds is True: 
        indsx = indsx & (mesh.cell_centers[:, 0] > casing_b[casing_b_ind] - casing_t)
    
    inds_interior = (
        indsx &
        (mesh.cell_centers[:, 2] <= 0) &
        (mesh.cell_centers[:, 2] >= -casing_l)
    )

    active_inds_sigma = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=np.log(models[key]["sigma"][~inds_interior])
    )

    active_inds_mur = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=models[key]["mur"][~inds_interior]
    )

    projection_sigma = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])
    projection_mu = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])

    exp_map = maps.ExpMap(mesh)
    mur_map = maps.MuRelative(mesh)

    sigma_map = exp_map * active_inds_sigma * projection_sigma
    mu_map = mur_map * active_inds_mur * projection_mu

    return sigma_map, mu_map

# %%
src_locations
# Out:
# array([[   0.,    0., -510.],
#        [   0.,    0., -520.]])

# %%
def create_survey(freq, components=["x"]): 
    rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
    rx_list = []
    if "x" in components: 
        rx_list.append([rx_ex_re, rx_ex_im])
    if "z" in components: 
        rx_list.append([rx_ez_re, rx_ez_im])
    src = fdem.sources.LineCurrent(list(np.hstack(rx_list)), location=src_locations, frequency=freq)
    return fdem.Survey([src])

# %%
# create the simulation
def create_simulation(key, survey, invert_mu=False, true_inds=False):
    sigma_map, mu_map = create_maps(key, true_inds)

    if invert_mu is True: 
        wires = maps.Wires(("sigma", 1), ("mu", 1))
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map * wires.sigma,
            muMap=mu_map * wires.mu 
        )
    else: 
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map
        )
    return sim

# %%
def get_casing_radius_ind_by_key(key): 
    i = np.where([key == kk for kk in keys])[0]
    return np.int64(np.floor(i/(len(mur_casing))))

def get_mur_ind_by_key(key): 
    i = np.where([key == kk for kk in keys])[0]
    return np.mod(i, len(casing_b))

# %%
i = 0
print(keys[i])
j, k = get_casing_radius_ind_by_key(keys[i]), get_mur_ind_by_key(keys[i])
print(casing_b[j], mur_casing[k])
# Out:
# casing_mur1_b2.5e-02
# [0.025] [1]

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)

data0 = {}
res0 = {}
rms0 = {}

components = ["x", "z"]

for i, key in enumerate(keys): 
    data_tmp = {}
    res_tmp = {}
    rms_tmp = {}
    
    for freq in frequencies: 
        survey = create_survey(freq, components)
    
        receivers = []
        if "x" in components: 
            receivers.append(["real_x", "imag_x"])
        if "z" in components: 
            receivers.append(["real_z", "imag_z"])
        dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])

        ii = get_casing_radius_ind_by_key(key)
        
        sim = create_simulation(key, survey, invert_mu=False)
        dpred = sim.dpred(np.log(sigdc[ii]))

        data_tmp[freq] = dpred
        res_tmp[freq] = dpred - dobsvec
        rms_tmp[freq] = np.sqrt(np.sum(res_tmp[freq]**2) / len(res_tmp[freq]))
    data0[key] = data_tmp
    res0[key] = res_tmp
    rms0[key] = rms_tmp

# %%
plot_inds = [2, 3, 4, 5, 6]

# %%
# freqs = frequencies[[7, 12, 14]]
freqs = frequencies[[0]]
fig, ax = plt.subplots(3, len(freqs), figsize=(4.5*len(freqs), 7.5), sharex=True, dpi=dpi_high)
ax=np.atleast_2d(ax).T
for j, freq in enumerate(freqs):
    plotind = 0
    for i, key in enumerate(keys): 
        if i in plot_inds:
            if i == 0:
                color = "k"
            else: 
                color = f"C{plotind}"
                plotind = plotind + 1
            dobs = dobs_dict[key][freq]["real_x"][:len(rx_x)]
            d0 = data0[key][freq][:len(rx_x)]
            ax[0, j].semilogy(rx_x, (dobs), color=color, label=f"{mur_casing[i]:1.0f}$\mu_0$")
            ax[0, j].semilogy(rx_x, (d0), f"--{color}")
            ax[1, j].semilogy(rx_x, np.abs(d0-dobs), color)
            ax[2, j].semilogy(rx_x, np.abs(d0-dobs)/np.abs(dobs)*100, color)
    
            # ax[0, j].set_title(f"{freq:1.0f} Hz\n({ascii_lowercase[j]})")
    
            # ax[0, j].set_ylim([2e-7, 5e-6])
            # ax[1, j].set_ylim([3e-10, 1e-6])
            # ax[2, j].set_ylim([5e-2, 1e2])

ax[0, 0].set_xlim([0, 400])
ax[0, 0].set_ylabel("E$_x$ real (V/m)")
ax[1, 0].set_ylabel("difference (V/m)")
ax[2, 0].set_ylabel("difference (%)")

ax[0, 0].legend(loc=1)

# ax[0, 0].set_title("(a) 2 Hz real E$_x$")
# ax[0, 1].set_title("(b) 10 Hz real E$_x$")

# ax[1, 0].set_title("(c) 2 Hz difference (cylinder - hollow)")
# ax[1, 1].set_title("(d) 10 Hz difference (cylinder - hollow)")

# ax[2, 0].set_title("(e) 2 Hz difference (%)")
# ax[2, 1].set_title("(f) 10 Hz difference (%)")

for k, a in enumerate(ax.flatten()):
    a.grid()
#     if k > 1: 
#         a.set_title(f"({ascii_lowercase[k]})")

for a in ax[2, :].flatten():
    a.set_xlabel("x (m)")

for a in ax[:, 1:].flatten():
    a.set_yticklabels("")
    

plt.tight_layout()

# %% [markdown]
# # set up inversions

# %%
class SaveInversionProgress(directives.InversionDirective):
    """
    A custom directive to save items of interest during the course of an inversion
    """
    
    results_file = None
    
    def initialize(self):
        """
        This is called when we first start running an inversion
        """
        # initialize an empty dictionary for storing results 
        self.inversion_results = {
            "iteration":[],
            "phi_d":[],
            "dpred":[],
            "logsigma":[],
            "mur":[],
            "residual":[],
            "rms":[],
        }

    def endIter(self):
        """
        This is run at the end of every iteration. So here, we just append 
        the new values to our dictionary
        """
        
        # Save the data
        self.inversion_results["iteration"].append(self.opt.iter)
        self.inversion_results["phi_d"].append(self.invProb.phi_d)
        self.inversion_results["dpred"].append(self.invProb.dpred)
        self.inversion_results["logsigma"].append(self.invProb.model[0])
        self.inversion_results["mur"].append(self.invProb.model[1])

        dobs = self.invProb._dmisfit.objfcts[0].data.dobs
        
        self.inversion_results["residual"].append((dobs - self.invProb.dpred))
        self.inversion_results["rms"].append(np.sqrt(np.sum(self.inversion_results["residual"][-1]**2)/len(dobs)))
        
        if self.results_file is not None: 
            with open(f"{self.results_file}", "wb") as fp:
                pickle.dump(self.inversion_results, fp)

# %%
def create_inversion(
    key, freq, invert_mu=False, relative_error=None, noise_floor=None,
    maxIter=10, maxIterCG=50, maxIterLS=10, true_casing_inds=False, components=["x"],
    chifact=0.5
):
    # create the simulation
    survey = create_survey(freq, components)

    receivers = []
    if "x" in components: 
        receivers.append(["real_x", "imag_x"])
    if "z" in components: 
        receivers.append(["real_z", "imag_z"])
    dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])
    dobs = data.Data(
        survey=survey, dobs=dobsvec, relative_error=relative_error, noise_floor=noise_floor
    )

    sim = create_simulation(key, survey, invert_mu, true_casing_inds)
    dmis = data_misfit.L2DataMisfit(data=dobs, simulation=sim)

    if invert_mu is True: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([2]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )
    
    else: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([1]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, #lower=np.r_[-np.inf], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )

    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=0)

    # directives
    target_misfit = directives.TargetMisfit(chifact=chifact)
    
    if true_casing_inds:
        filename_save = f"inv_{key}_{freq:1.0f}_true_casing.pkl"
    else: 
        filename_save = f"inv_{key}_{freq:1.0f}.pkl"
    inversion_progress = SaveInversionProgress(results_file=f"{directory_path}/{filename_save}")
    
    # inversion 
    inv = inversion.BaseInversion(inv_prob, [target_misfit, inversion_progress])
    
    return inv

# %% [markdown]
# # experiment 2: invert for solid cylinder conductivity, permeability

# %%
models.keys()
# Out:
# dict_keys(['casing_mur1_b2.5e-02', 'casing_mur10_b2.5e-02', 'casing_mur25_b2.5e-02', 'casing_mur50_b2.5e-02', 'casing_mur100_b2.5e-02', 'casing_mur150_b2.5e-02', 'casing_mur200_b2.5e-02', 'casing_mur1_b5.0e-02', 'casing_mur10_b5.0e-02', 'casing_mur25_b5.0e-02', 'casing_mur50_b5.0e-02', 'casing_mur100_b5.0e-02', 'casing_mur150_b5.0e-02', 'casing_mur200_b5.0e-02', 'casing_mur1_b1.0e-01', 'casing_mur10_b1.0e-01', 'casing_mur25_b1.0e-01', 'casing_mur50_b1.0e-01', 'casing_mur100_b1.0e-01', 'casing_mur150_b1.0e-01', 'casing_mur200_b1.0e-01', 'casing_mur1_b2.0e-01', 'casing_mur10_b2.0e-01', 'casing_mur25_b2.0e-01', 'casing_mur50_b2.0e-01', 'casing_mur100_b2.0e-01', 'casing_mur150_b2.0e-01', 'casing_mur200_b2.0e-01', 'casing_mur1_b4.0e-01', 'casing_mur10_b4.0e-01', 'casing_mur25_b4.0e-01', 'casing_mur50_b4.0e-01', 'casing_mur100_b4.0e-01', 'casing_mur150_b4.0e-01', 'casing_mur200_b4.0e-01'])

# %%
inv_dict = {}
relative_error = 0.005
noise_floor = 1e-8

for i, key in enumerate(keys):
    # if i == 0: 
    #     chifact = 0.5
    # else: 
    chifact = 1e-7
    if key not in inv_dict: 
        tmp = {}
        for freq in frequencies:
            
            tmp[freq] = create_inversion(
                    key, freq, invert_mu=True, relative_error=relative_error, noise_floor=noise_floor,
                    components=["x", "z"], chifact=chifact
                )
        inv_dict[key] = tmp

# %%
tmp = inv_dict[keys[0]][frequencies[0]]
np.unique(tmp.invProb.dmisfit.objfcts[0].simulation.muMap * np.r_[10, 1])
# Out:
# array([1.25663706e-06])

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)
# starting_models = {
#     True: np.r_[np.log(sigstart), 1],
#     False: np.r_[np.log(sigstart)]
# }

# %%
sigdc
# Out:
# array([3200000., 1800000.,  950000.,  487500.,  246875.])

# %%
mrec_dict = {}

for i, key in enumerate(keys):
    bi = get_casing_radius_ind_by_key(key)
    mi = get_mur_ind_by_key(key)
    
    if key not in mrec_dict: 
        tmp = {}
        for j, freq in enumerate(frequencies):
            print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
            # if i == 0: 
            
            mstart = np.r_[np.log(sigdc[bi]), 1] #mur_casing[mi]]
            # else: 
            #     mstart = mrec_dict[keys[0]][freq]
            tmp[freq] = inv_dict[key][freq].run(mstart)
            print(f"recovered conductivity: {np.exp(inv_dict[key][freq].m[0]):1.2e}, recovered permeability: {inv_dict[key][freq].m[1]:1.2f} mu0 \n")
        mrec_dict[key] = tmp
# Out:
# ------------------------ casing_mur1_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.09e-01  0.00e+00  4.09e-01    4.04e+01      0
#    1  0.00e+00  4.06e-01  1.71e-08  4.06e-01    1.09e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.7354e-03 <= tolF*(1+|f0|) = 1.4094e-01
# 1 : |xc-x_last| = 1.8505e-04 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 1.0894e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0894e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.20e+06, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur10_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.35e+01  0.00e+00  3.35e+01    1.65e+02      0
#    1  0.00e+00  3.35e+01  2.83e-07  3.35e+01    1.56e+01      0
#    2  0.00e+00  2.41e-03  9.20e+00  2.41e-03    8.96e+00      0
#    3  0.00e+00  2.22e-03  9.20e+00  2.22e-03    1.51e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.8925e-04 <= tolF*(1+|f0|) = 3.4514e+00
# 1 : |xc-x_last| = 1.7496e-03 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 1.5081e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 1.5081e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.20e+06, recovered permeability: 5.29 mu0
#
#
#
# ------------------------ casing_mur25_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.72e+02  0.00e+00  2.72e+02    4.66e+02      0
#    1  0.00e+00  2.71e+02  2.26e-06  2.71e+02    4.44e+01      0
#    2  0.00e+00  1.47e-02  7.46e+01  1.47e-02    7.28e+01      0
#    3  0.00e+00  2.22e-03  7.47e+01  2.22e-03    2.15e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2525e-02 <= tolF*(1+|f0|) = 2.7268e+01
# 1 : |xc-x_last| = 1.4738e-02 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 2.1465e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.1465e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.20e+06, recovered permeability: 13.23 mu0
#
#
#
# ------------------------ casing_mur50_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.17e+03  0.00e+00  1.17e+03    8.56e+02      0
#    1  0.00e+00  1.17e+03  7.61e-06  1.17e+03    9.23e+01      0
#    2  0.00e+00  2.39e-01  3.22e+02  2.39e-01    3.17e+02      0
#    3  0.00e+00  2.22e-03  3.24e+02  2.22e-03    1.30e-01      0   Skip BFGS
#    4  0.00e+00  2.22e-03  3.24e+02  2.22e-03    1.30e-01      2   Skip BFGS
#    5  0.00e+00  2.22e-03  3.24e+02  2.22e-03    1.29e-01      2   Skip BFGS
#    6  0.00e+00  2.22e-03  3.24e+02  2.22e-03    1.29e-01      0   Skip BFGS
#    7  0.00e+00  2.22e-03  3.24e+02  2.22e-03    1.29e-01      0   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.2240e-03 <= alp*descent     = 2.2240e-03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.20e+06, recovered permeability: 26.46 mu0
#
#
#
# ------------------------ casing_mur100_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.82e+03  0.00e+00  4.82e+03    1.21e+03      0
#    1  0.00e+00  4.82e+03  1.50e-05  4.82e+03    1.87e+02      0
#    2  0.00e+00  4.15e+00  1.33e+03  4.15e+00    1.32e+03      0
#    3  0.00e+00  2.24e-03  1.35e+03  2.24e-03    2.10e+00      0   Skip BFGS
#    4  0.00e+00  2.22e-03  1.35e+03  2.22e-03    8.76e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.1330e-05 <= tolF*(1+|f0|) = 4.8224e+02
# 1 : |xc-x_last| = 8.3709e-04 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 8.7599e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 8.7599e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.20e+06, recovered permeability: 52.95 mu0
#
#
#
# ------------------------ casing_mur150_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.08e+04  0.00e+00  1.08e+04    1.00e+03      0
#    1  0.00e+00  1.08e+04  9.69e-06  1.08e+04    2.78e+02      0
#    2  0.00e+00  2.17e+01  3.02e+03  2.17e+01    3.02e+03      0
#    3  0.00e+00  2.54e-03  3.08e+03  2.54e-03    1.11e+01      0   Skip BFGS
#    4  0.00e+00  2.22e-03  3.08e+03  2.22e-03    2.26e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.1902e-04 <= tolF*(1+|f0|) = 1.0819e+03
# 1 : |xc-x_last| = 4.4996e-03 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 2.2604e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.2604e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.21e+06, recovered permeability: 79.51 mu0
#
#
#
# ------------------------ casing_mur200_b2.5e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.90e+04  0.00e+00  1.90e+04    3.96e+02      0
#    1  0.00e+00  1.90e+04  2.35e-07  1.90e+04    3.66e+02      0
#    2  0.00e+00  6.94e+01  5.38e+03  6.94e+01    5.40e+03      0
#    3  0.00e+00  5.62e-03  5.53e+03  5.62e-03    3.64e+01      0   Skip BFGS
#    4  0.00e+00  2.22e-03  5.53e+03  2.22e-03    2.72e-04      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.3939e-03 <= tolF*(1+|f0|) = 1.8982e+03
# 1 : |xc-x_last| = 1.4147e-02 <= tolX*(1+|x0|) = 1.6012e+00
# 1 : |proj(x-g)-x|    = 2.7212e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.7212e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.21e+06, recovered permeability: 106.19 mu0
#
#
#
# ------------------------ casing_mur1_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.39e+00  0.00e+00  2.39e+00    1.24e+02      0
#    1  0.00e+00  2.30e+00  9.13e-07  2.30e+00    6.15e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.4073e-02 <= tolF*(1+|f0|) = 3.3879e-01
# 1 : |xc-x_last| = 1.3515e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 6.1509e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.1509e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur10_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.23e+01  0.00e+00  1.23e+01    1.49e+01      0
#    1  0.00e+00  1.23e+01  1.22e-09  1.23e+01    1.49e+01      0
#    2  0.00e+00  9.88e-02  1.47e+00  9.88e-02    2.06e+00      0   Skip BFGS
#    3  0.00e+00  9.88e-02  1.47e+00  9.88e-02    2.06e+00      2
#    4  0.00e+00  9.88e-02  1.47e+00  9.88e-02    2.06e+00      8   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 9.8836e-02 <= alp*descent     = 9.8836e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+06, recovered permeability: 2.71 mu0
#
#
#
# ------------------------ casing_mur25_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.39e+02  0.00e+00  1.39e+02    2.09e+02      0
#    1  0.00e+00  1.39e+02  2.44e-06  1.39e+02    4.80e+01      0
#    2  0.00e+00  1.03e-01  1.67e+01  1.03e-01    2.86e+01      0
#    3  0.00e+00  9.88e-02  1.67e+01  9.88e-02    8.50e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.5682e-03 <= tolF*(1+|f0|) = 1.3997e+01
# 1 : |xc-x_last| = 5.7091e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 8.4982e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 8.4982e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06, recovered permeability: 6.78 mu0
#
#
#
# ------------------------ casing_mur50_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.54e+02  0.00e+00  6.54e+02    5.00e+02      0
#    1  0.00e+00  6.53e+02  1.41e-05  6.53e+02    1.04e+02      0
#    2  0.00e+00  2.02e-01  7.87e+01  2.02e-01    1.35e+02      0
#    3  0.00e+00  9.88e-02  7.90e+01  9.88e-02    7.60e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.0291e-01 <= tolF*(1+|f0|) = 6.5501e+01
# 1 : |xc-x_last| = 3.0168e-02 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 7.5954e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.5954e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06, recovered permeability: 13.57 mu0
#
#
#
# ------------------------ casing_mur100_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.80e+03  0.00e+00  2.80e+03    9.15e+02      0
#    1  0.00e+00  2.80e+03  4.66e-05  2.80e+03    2.15e+02      0
#    2  0.00e+00  2.06e+00  3.38e+02  2.06e+00    5.86e+02      0
#    3  0.00e+00  9.88e-02  3.43e+02  9.88e-02    1.41e+00      0   Skip BFGS
#    4  0.00e+00  9.88e-02  3.43e+02  9.88e-02    1.41e+00      1   Skip BFGS
#    5  0.00e+00  9.88e-02  3.43e+02  9.88e-02    1.41e+00      1   Skip BFGS
#    6  0.00e+00  9.88e-02  3.43e+02  9.88e-02    1.41e+00      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 9.8818e-02 <= alp*descent     = 9.8818e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+06, recovered permeability: 27.17 mu0
#
#
#
# ------------------------ casing_mur150_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.39e+03  0.00e+00  6.39e+03    1.11e+03      0
#    1  0.00e+00  6.39e+03  6.60e-05  6.39e+03    3.24e+02      0
#    2  0.00e+00  1.06e+01  7.77e+02  1.06e+01    1.35e+03      0
#    3  0.00e+00  9.91e-02  7.94e+02  9.91e-02    7.61e+00      0   Skip BFGS
#    4  0.00e+00  9.88e-02  7.94e+02  9.88e-02    2.22e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.2522e-04 <= tolF*(1+|f0|) = 6.3937e+02
# 1 : |xc-x_last| = 1.1776e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 2.2193e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.2193e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.81e+06, recovered permeability: 40.84 mu0
#
#
#
# ------------------------ casing_mur200_b5.0e-02 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.13e+04  0.00e+00  1.13e+04    1.09e+03      0
#    1  0.00e+00  1.13e+04  5.84e-05  1.13e+04    4.30e+02      0
#    2  0.00e+00  3.45e+01  1.39e+03  3.45e+01    2.41e+03      0
#    3  0.00e+00  1.02e-01  1.44e+03  1.02e-01    2.51e+01      0   Skip BFGS
#    4  0.00e+00  9.88e-02  1.44e+03  9.88e-02    7.56e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.5829e-03 <= tolF*(1+|f0|) = 1.1343e+03
# 1 : |xc-x_last| = 3.0713e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 7.5568e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 7.5568e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.81e+06, recovered permeability: 54.60 mu0
#
#
#
# ------------------------ casing_mur1_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  8.85e+00  0.00e+00  8.85e+00    2.83e+02      0
#    1  0.00e+00  7.75e+00  3.00e-05  7.75e+00    9.33e-01      0
#    2  0.00e+00  7.75e+00  2.98e-05  7.75e+00    9.33e-01      0
# ------------------------------------------------------------------
# 0 :    ft     = 7.7521e+00 <= alp*descent     = 7.7516e+00
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 9.43e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur10_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.66e+00  0.00e+00  3.66e+00    2.20e+02      0
#    1  0.00e+00  3.00e+00  1.80e-05  3.00e+00    5.75e+00      0
#    2  0.00e+00  1.95e+00  6.75e-02  1.95e+00    1.76e-01      0
#    3  0.00e+00  1.95e+00  6.75e-02  1.95e+00    2.22e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.7175e-06 <= tolF*(1+|f0|) = 4.6559e-01
# 1 : |xc-x_last| = 2.1946e-05 <= tolX*(1+|x0|) = 1.4800e+00
# 1 : |proj(x-g)-x|    = 2.2167e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.2167e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.44e+05, recovered permeability: 1.37 mu0
#
#
#
# ------------------------ casing_mur25_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.76e+01  0.00e+00  4.76e+01    1.24e+02      0
#    1  0.00e+00  4.74e+01  5.26e-06  4.74e+01    3.76e+01      0
#    2  0.00e+00  1.95e+00  2.92e+00  1.95e+00    7.80e+00      0   Skip BFGS
#    3  0.00e+00  1.95e+00  2.92e+00  1.95e+00    2.37e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.2213e-04 <= tolF*(1+|f0|) = 4.8630e+00
# 1 : |xc-x_last| = 2.1075e-04 <= tolX*(1+|x0|) = 1.4800e+00
# 1 : |proj(x-g)-x|    = 2.3731e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3731e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.44e+05, recovered permeability: 3.42 mu0
#
#
#
# ------------------------ casing_mur50_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.66e+02  0.00e+00  2.66e+02    9.67e+01      0
#    1  0.00e+00  2.66e+02  4.18e-07  2.66e+02    9.07e+01      0
#    2  0.00e+00  1.98e+00  1.70e+01  1.98e+00    4.55e+01      0
#    3  0.00e+00  1.95e+00  1.71e+01  1.95e+00    3.12e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.8914e-02 <= tolF*(1+|f0|) = 2.6732e+01
# 1 : |xc-x_last| = 1.0847e-02 <= tolX*(1+|x0|) = 1.4800e+00
# 1 : |proj(x-g)-x|    = 3.1247e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.1247e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.44e+05, recovered permeability: 6.84 mu0
#
#
#
# ------------------------ casing_mur100_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.24e+03  0.00e+00  1.24e+03    3.40e+02      0
#    1  0.00e+00  1.24e+03  2.87e-05  1.24e+03    1.96e+02      0
#    2  0.00e+00  2.60e+00  7.98e+01  2.60e+00    2.14e+02      0
#    3  0.00e+00  1.95e+00  8.06e+01  1.95e+00    5.70e-01      0   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.9460e+00 <= alp*descent     = 1.9460e+00
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 9.46e+05, recovered permeability: 13.70 mu0
#
#
#
# ------------------------ casing_mur150_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.92e+03  0.00e+00  2.92e+03    5.33e+02      0
#    1  0.00e+00  2.91e+03  7.21e-05  2.91e+03    3.00e+02      0
#    2  0.00e+00  5.69e+00  1.88e+02  5.69e+00    5.05e+02      0
#    3  0.00e+00  1.95e+00  1.92e+02  1.95e+00    3.16e+00      0   Skip BFGS
#    4  0.00e+00  1.95e+00  1.92e+02  1.95e+00    3.16e+00      3   Skip BFGS
#    5  0.00e+00  1.95e+00  1.92e+02  1.95e+00    3.16e+00      3   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.9459e+00 <= alp*descent     = 1.9459e+00
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 9.49e+05, recovered permeability: 20.59 mu0
#
#
#
# ------------------------ casing_mur200_b1.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.26e+03  0.00e+00  5.26e+03    6.58e+02      0
#    1  0.00e+00  5.26e+03  1.01e-04  5.26e+03    4.03e+02      0
#    2  0.00e+00  1.45e+01  3.41e+02  1.45e+01    9.10e+02      0
#    3  0.00e+00  1.95e+00  3.52e+02  1.95e+00    1.06e+01      0   Skip BFGS
#    4  0.00e+00  1.95e+00  3.52e+02  1.95e+00    3.44e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.6007e-03 <= tolF*(1+|f0|) = 5.2642e+02
# 1 : |xc-x_last| = 3.0720e-04 <= tolX*(1+|x0|) = 1.4800e+00
# 1 : |proj(x-g)-x|    = 3.4387e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 3.4387e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 9.53e+05, recovered permeability: 27.55 mu0
#
#
#
# ------------------------ casing_mur1_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.72e+01  0.00e+00  4.72e+01    5.81e+02      0
#    1  0.00e+00  3.56e+01  8.01e-04  3.56e+01    1.10e+01      0
#    2  0.00e+00  3.56e+01  7.73e-04  3.56e+01    7.86e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.9084e-03 <= tolF*(1+|f0|) = 4.8230e+00
# 1 : |xc-x_last| = 7.0746e-04 <= tolX*(1+|x0|) = 1.4135e+00
# 1 : |proj(x-g)-x|    = 7.8586e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 7.8586e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.69e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur10_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.55e+01  0.00e+00  3.55e+01    5.51e+02      0
#    1  0.00e+00  2.51e+01  7.22e-04  2.51e+01    9.88e+00      0
#    2  0.00e+00  2.51e+01  6.98e-04  2.51e+01    6.82e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.1414e-03 <= tolF*(1+|f0|) = 3.6546e+00
# 1 : |xc-x_last| = 6.3513e-04 <= tolX*(1+|x0|) = 1.4135e+00
# 1 : |proj(x-g)-x|    = 6.8158e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 6.8158e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.70e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur25_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.95e+01  0.00e+00  3.95e+01    5.05e+02      0
#    1  0.00e+00  3.07e+01  6.05e-04  3.07e+01    2.12e+01      0
#    2  0.00e+00  2.37e+01  2.56e-01  2.37e+01    1.03e+00      0
#    3  0.00e+00  2.37e+01  2.56e-01  2.37e+01    4.65e-04      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.6456e-05 <= tolF*(1+|f0|) = 4.0496e+00
# 1 : |xc-x_last| = 1.6160e-04 <= tolX*(1+|x0|) = 1.4135e+00
# 1 : |proj(x-g)-x|    = 4.6523e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 4.6523e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.70e+05, recovered permeability: 1.72 mu0
#
#
#
# ------------------------ casing_mur50_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.11e+02  0.00e+00  1.11e+02    4.37e+02      0
#    1  0.00e+00  1.04e+02  4.44e-04  1.04e+02    6.68e+01      0
#    2  0.00e+00  2.37e+01  2.95e+00  2.37e+01    1.21e+01      0   Skip BFGS
#    3  0.00e+00  2.37e+01  2.95e+00  2.37e+01    8.28e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.7424e-03 <= tolF*(1+|f0|) = 1.1187e+01
# 1 : |xc-x_last| = 7.8230e-04 <= tolX*(1+|x0|) = 1.4135e+00
# 1 : |proj(x-g)-x|    = 8.2810e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.2810e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.70e+05, recovered permeability: 3.43 mu0
#
#
#
# ------------------------ casing_mur100_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.94e+02  0.00e+00  4.94e+02    3.48e+02      0
#    1  0.00e+00  4.91e+02  2.27e-04  4.91e+02    1.60e+02      0
#    2  0.00e+00  2.39e+01  1.71e+01  2.39e+01    7.06e+01      0   Skip BFGS
#    3  0.00e+00  2.37e+01  1.72e+01  2.37e+01    1.80e-01      0   Skip BFGS
#    4  0.00e+00  2.37e+01  1.72e+01  2.37e+01    1.80e-01      2   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.3716e+01 <= alp*descent     = 2.3716e+01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 4.71e+05, recovered permeability: 6.87 mu0
#
#
#
# ------------------------ casing_mur150_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.19e+03  0.00e+00  1.19e+03    3.31e+02      0
#    1  0.00e+00  1.19e+03  1.10e-04  1.19e+03    2.52e+02      0
#    2  0.00e+00  2.48e+01  4.27e+01  2.48e+01    1.76e+02      0   Skip BFGS
#    3  0.00e+00  2.37e+01  4.35e+01  2.37e+01    1.04e+00      0   Skip BFGS
#    4  0.00e+00  2.37e+01  4.35e+01  2.37e+01    1.04e+00      0   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.3714e+01 <= alp*descent     = 2.3714e+01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 4.73e+05, recovered permeability: 10.33 mu0
#
#
#
# ------------------------ casing_mur200_b2.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.20e+03  0.00e+00  2.20e+03    3.75e+02      0
#    1  0.00e+00  2.19e+03  5.31e-05  2.19e+03    3.44e+02      0
#    2  0.00e+00  2.76e+01  7.97e+01  2.76e+01    3.26e+02      0   Skip BFGS
#    3  0.00e+00  2.37e+01  8.21e+01  2.37e+01    3.59e+00      0   Skip BFGS
#    4  0.00e+00  2.37e+01  8.21e+01  2.37e+01    5.33e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.4010e-04 <= tolF*(1+|f0|) = 2.1961e+02
# 1 : |xc-x_last| = 2.4588e-04 <= tolX*(1+|x0|) = 1.4135e+00
# 1 : |proj(x-g)-x|    = 5.3309e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 5.3309e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.75e+05, recovered permeability: 13.81 mu0
#
#
#
# ------------------------ casing_mur1_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.03e+02  0.00e+00  3.03e+02    1.08e+03      0
#    1  0.00e+00  2.07e+02  1.64e-02  2.07e+02    1.16e+02      0
#    2  0.00e+00  2.06e+02  1.40e-02  2.06e+02    8.56e-01      0
#    3  0.00e+00  2.06e+02  1.39e-02  2.06e+02    4.08e-01      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.0596e+02 <= alp*descent     = 2.0596e+02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 2.09e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur10_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.89e+02  0.00e+00  2.89e+02    1.06e+03      0
#    1  0.00e+00  1.95e+02  1.60e-02  1.95e+02    1.13e+02      0
#    2  0.00e+00  1.94e+02  1.37e-02  1.94e+02    8.20e-01      0
#    3  0.00e+00  1.94e+02  1.36e-02  1.94e+02    4.20e-01      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.9386e+02 <= alp*descent     = 1.9386e+02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 2.09e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur25_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.75e+02  0.00e+00  2.75e+02    1.04e+03      0
#    1  0.00e+00  1.85e+02  1.53e-02  1.85e+02    1.07e+02      0
#    2  0.00e+00  1.84e+02  1.31e-02  1.84e+02    7.65e-01      0
#    3  0.00e+00  1.84e+02  1.31e-02  1.84e+02    4.42e-01      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.8402e+02 <= alp*descent     = 1.8402e+02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 2.10e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_mur50_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.82e+02  0.00e+00  2.82e+02    1.01e+03      0
#    1  0.00e+00  1.97e+02  1.43e-02  1.97e+02    1.06e+02      0
#    2  0.00e+00  1.84e+02  2.74e-01  1.84e+02    2.03e+00      0
#    3  0.00e+00  1.84e+02  2.74e-01  1.84e+02    2.36e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.5704e-04 <= tolF*(1+|f0|) = 2.8263e+01
# 1 : |xc-x_last| = 2.5672e-04 <= tolX*(1+|x0|) = 1.3457e+00
# 1 : |proj(x-g)-x|    = 2.3591e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.3591e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.10e+05, recovered permeability: 1.72 mu0
#
#
#
# ------------------------ casing_mur100_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.03e+02  0.00e+00  4.03e+02    9.55e+02      0
#    1  0.00e+00  3.27e+02  1.27e-02  3.27e+02    1.47e+02      0
#    2  0.00e+00  1.84e+02  2.98e+00  1.84e+02    1.91e+01      0
#    3  0.00e+00  1.84e+02  3.00e+00  1.84e+02    4.30e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.3536e-02 <= tolF*(1+|f0|) = 4.0372e+01
# 1 : |xc-x_last| = 6.4841e-03 <= tolX*(1+|x0|) = 1.3457e+00
# 1 : |proj(x-g)-x|    = 4.3012e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.3012e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.10e+05, recovered permeability: 3.44 mu0
#
#
#
# ------------------------ casing_mur150_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.66e+02  0.00e+00  6.66e+02    9.20e+02      0
#    1  0.00e+00  5.98e+02  1.14e-02  5.98e+02    2.15e+02      0
#    2  0.00e+00  1.84e+02  8.60e+00  1.84e+02    5.54e+01      0
#    3  0.00e+00  1.84e+02  8.70e+00  1.84e+02    2.47e-01      0   Skip BFGS
#    4  0.00e+00  1.84e+02  8.70e+00  1.84e+02    2.47e-01      0   Skip BFGS
#    5  0.00e+00  1.84e+02  8.70e+00  1.84e+02    2.47e-01      3
#    6  0.00e+00  1.84e+02  8.70e+00  1.84e+02    2.47e-01      0   Skip BFGS
#    7  0.00e+00  1.84e+02  8.70e+00  1.84e+02    2.47e-01      5
# ------------------------------------------------------------------
# 0 :    ft     = 1.8355e+02 <= alp*descent     = 1.8355e+02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 2.11e+05, recovered permeability: 5.17 mu0
#
#
#
# ------------------------ casing_mur200_b4.0e-01 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.07e+03  0.00e+00  1.07e+03    9.06e+02      0
#    1  0.00e+00  1.01e+03  1.05e-02  1.01e+03    2.90e+02      0
#    2  0.00e+00  1.84e+02  1.71e+01  1.84e+02    1.10e+02      0
#    3  0.00e+00  1.84e+02  1.75e+01  1.84e+02    8.87e-01      0   Skip BFGS
#    4  0.00e+00  1.84e+02  1.75e+01  1.84e+02    8.87e-01      0   Skip BFGS
#    5  0.00e+00  1.84e+02  1.75e+01  1.84e+02    8.87e-01      3
#    6  0.00e+00  1.84e+02  1.75e+01  1.84e+02    8.87e-01      1   Skip BFGS
#    7  0.00e+00  1.84e+02  1.75e+01  1.84e+02    8.87e-01      6   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.8353e+02 <= alp*descent     = 1.8353e+02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 2.12e+05, recovered permeability: 6.91 mu0

# %%
inv_results = {}

for key in keys:
    if key not in inv_results: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = inv_dict[key][freq].directiveList.dList[1].inversion_results
        inv_results[key] = tmp

# %%
tmp = inv_results[keys[0]][frequencies[0]]

# %%
tmp = inv_dict[keys[0]][frequencies[0]]

# %%
phi_d_final = {}
chifact_final = {}
phid_star = len(rx_x)*len(rx_z)*2

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            phid_tmp[i] = phid[-1]
    phi_d_final[key] = phid_tmp
    chifact_final[key] = phi_d_final[key] / phid_star

# %%
phid_min = {}
chifact_min = {}
logsig_min = {}
mur_min = {}
rms_min = {}

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    logsig_tmp = np.ones(len(frequencies)) * np.nan
    mur_tmp = np.ones(len(frequencies)) * np.nan
    rms_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            ind_min = np.argmin(phid)
            phid_tmp[i] = phid[ind_min]
            logsig_tmp[i] = inv_results[key][freq]["logsigma"][ind_min]
            mur_tmp[i] = inv_results[key][freq]["mur"][ind_min]
            rms_tmp[i] = inv_results[key][freq]["rms"][ind_min]
    phid_min[key] = phid_tmp
    logsig_min[key] = logsig_tmp
    mur_min[key] = mur_tmp
    rms_min[key] = rms_tmp

# %%
np.hstack(mur_min.values())
# Out:
# /tmp/ipykernel_3747916/364635938.py:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   np.hstack(mur_min.values())
# array([  1.        ,   5.29012724,  13.22590124,  26.45613948,
#         52.94804048,  79.51212766, 106.18701508,   1.        ,
#          2.713089  ,   6.78422463,  13.57211744,  27.17408143,
#         40.83761179,  54.59616683,   1.        ,   1.36744742,
#          3.41730255,   6.83984082,  13.69778056,  20.59287436,
#         27.54563262,   1.        ,   1.        ,   1.71502281,
#          3.42755644,   6.86963673,  10.32725179,  13.81359832,
#          1.        ,   1.        ,   1.        ,   1.72265026,
#          3.44283139,   5.16938951,   6.90586467])

# %%
keys
# Out:
# ['casing_mur1_b2.5e-02',
#  'casing_mur10_b2.5e-02',
#  'casing_mur25_b2.5e-02',
#  'casing_mur50_b2.5e-02',
#  'casing_mur100_b2.5e-02',
#  'casing_mur150_b2.5e-02',
#  'casing_mur200_b2.5e-02',
#  'casing_mur1_b5.0e-02',
#  'casing_mur10_b5.0e-02',
#  'casing_mur25_b5.0e-02',
#  'casing_mur50_b5.0e-02',
#  'casing_mur100_b5.0e-02',
#  'casing_mur150_b5.0e-02',
#  'casing_mur200_b5.0e-02',
#  'casing_mur1_b1.0e-01',
#  'casing_mur10_b1.0e-01',
#  'casing_mur25_b1.0e-01',
#  'casing_mur50_b1.0e-01',
#  'casing_mur100_b1.0e-01',
#  'casing_mur150_b1.0e-01',
#  'casing_mur200_b1.0e-01',
#  'casing_mur1_b2.0e-01',
#  'casing_mur10_b2.0e-01',
#  'casing_mur25_b2.0e-01',
#  'casing_mur50_b2.0e-01',
#  'casing_mur100_b2.0e-01',
#  'casing_mur150_b2.0e-01',
#  'casing_mur200_b2.0e-01',
#  'casing_mur1_b4.0e-01',
#  'casing_mur10_b4.0e-01',
#  'casing_mur25_b4.0e-01',
#  'casing_mur50_b4.0e-01',
#  'casing_mur100_b4.0e-01',
#  'casing_mur150_b4.0e-01',
#  'casing_mur200_b4.0e-01']

# %%
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(6, 12))

n = len(mur_casing)
mur_min_vals = np.hstack(mur_min.values())
dmis_vals = np.hstack(phid_min.values())
logsig_vals = np.hstack(logsig_min.values())

for i, b in enumerate(casing_b):
    ax[0].semilogy(mur_casing, dmis_vals[i*n:(i+1)*n], "-o", label=b)
    ax[1].semilogy(mur_casing, np.exp(logsig_vals[i*n:(i+1)*n]), "-o", label=b)
    ax[2].plot(mur_casing, mur_min_vals[i*n:(i+1)*n], "-o", label=b)

    ax[1].semilogy(mur_casing, sigdc[i]*np.ones_like(mur_casing), f"--C{i}")
# Out:
# /tmp/ipykernel_3747916/1041925283.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   mur_min_vals = np.hstack(mur_min.values())
# /tmp/ipykernel_3747916/1041925283.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   dmis_vals = np.hstack(phid_min.values())
# /tmp/ipykernel_3747916/1041925283.py:6: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   logsig_vals = np.hstack(logsig_min.values())

# %%
mur_slopes = np.zeros(len(casing_b))
mur_intercepts = np.zeros(len(casing_b))

chi_slopes = np.zeros(len(casing_b))
chi_intercepts = np.zeros(len(casing_b))


lr_mur = linear_model.LinearRegression()
lr_chi = linear_model.LinearRegression(fit_intercept=False)

for i, b in enumerate(casing_b):
    mur_b = mur_min_vals[i*n:(i+1)*n]
    
    lr_mur.fit(np.atleast_2d(mur_casing).T, mur_b)
    mur_slopes[i] = lr_mur.coef_
    mur_intercepts[i] = lr_mur.intercept_

    lr_chi.fit(np.atleast_2d(mur_casing-1).T, mur_b-1)
    chi_slopes[i] = lr_chi.coef_

# %%
casing_b
# Out:
# array([0.025, 0.05 , 0.1  , 0.2  , 0.4  ])

# %%
mur_slopes
# Out:
# array([0.52972042, 0.27123208, 0.13575129, 0.06638821, 0.0309406 ])

# %%
chi_slopes * casing_b / (casing_t)
# Out:
# array([1.31771483, 1.33690604, 1.31346673, 1.24747095, 1.11102518])

# %%
np.sqrt(np.pi)
# Out:
# 1.7724538509055159

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

for i, t in enumerate(casing_b):
    mur_t = mur_min_vals[i*n:(i+1)*n]
    ax.plot(mur_casing, mur_t, f"C{i}o", label=f"{t:1.1e}m, slope: {chi_slopes[i]:1.2f}")
    ax.plot(mur_casing, chi_slopes[i]*(mur_casing-1)+1, f":C{i}", alpha=0.5)
ax.set_xlabel("true $\mu_r$")
ax.set_ylabel("recovered $\mu_r$")
ax.set_title(f"{frequencies[freq_ind]} Hz")
ax.grid("both")
# ax.set_aspect(1)
ax.legend()
    # ax.plot()

# %%
chi_slopes * casing_b / casing_t
# Out:
# array([1.31771483, 1.33690604, 1.31346673, 1.24747095, 1.11102518])

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(casing_b, chi_slopes)

# %%
from scipy import stats

# %%
slopes2, intercepts, r, p, std_err = stats.linregress(mur_casing, mur_t)

# %%
intercepts
# Out:
# 0.522367693155056

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(casing_t, slopes[:-2], "ok")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 fig, ax = plt.subplots(1, 1)
# ----> 2 ax.plot(casing_t[:-2], slopes[:-2], "ok")
#
# TypeError: 'float' object is not subscriptable

# %%
slope, intercept, r, p, std_err = stats.linregress(mur_casing, mur_t)

# %%
casing_b
# Out:
# array([0.025, 0.05 , 0.1  , 0.2  , 0.4  ])

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression(fit_intercept=False)

# %%
mur_casing_full = np.kron(np.ones(len(casing_b)), mur_casing)
casing_b_full = np.kron(casing_b, np.ones(len(mur_casing)))

# %%
ind = len(mur_casing)*4
X = np.vstack([mur_casing_full[:ind], casing_b_full[:ind]]).T
y = mur_min_vals[:ind]
clf.fit(X, y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
clf.coef_, clf.intercept_
# Out:
# (array([  0.31133114, -88.87800725]), 0.0)

# %%
# fig, ax = plt.subplots(3, 1, figsize=(6, 12), sharex=True) 

# for key in keys: 
#     mrec = np.vstack(mrec_dict[key].values())
    
#     ax[0].semilogx(frequencies, phi_d_final[key] / phid_star, "o", label=key)
#     ax[0].semilogx(frequencies,  np.ones_like(frequencies),"--k")
#     ax[1].loglog(frequencies, np.exp(mrec[:, 0]), "o", label=key)
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
#     ax[2].semilogx(frequencies, mrec[:, 1], "o", label=key)

# ax[1].set_ylim([1e6, 1e8])
# # ax[0].legend()

# %%
# fig, ax = plt.subplots(3, 1, figsize=(6, 12), sharex=True) 

# for key in keys: 
#     ax[0].loglog(frequencies, phid_min[key], "o", label=key)
#     ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
#     ax[1].loglog(frequencies, np.exp(logsig_min[key]), "o", label=key)
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
#     ax[2].semilogx(frequencies, (mur_min[key]), "o", label=key)
# ax[0].legend()

# %%
markers = ["o", "v", "s", "D", "p", "^", "h"]

# %%
mur_casing

# %%
plotkeys = np.hstack([keys[0], keys[2:]])
plotkeys

# %%
def mur_by_skindepth(delta):
    omega = 2 * np.pi * frequencies
    return 2 / (omega * delta**2 * sigma_casing) / mu_0

# %%
mur_by_skindepth(casing_t)/mu_0

# %%
fig, ax = plt.subplots(3, 1, figsize=(6.75, 8.25), sharex=True, dpi=dpi_high) 

for i, key in enumerate(plotkeys): 
    color = "k" if i==0 else f"C{i-1}"
    label = f"{key.split('_')[-1][3:]} $\mu_0$"
    ax[0].loglog(frequencies, rms_min[key], f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    # ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
    ax[1].loglog(frequencies, np.exp(logsig_min[key]), f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
    ax[2].loglog(frequencies, (mur_min[key]), f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    
for a in ax:
    a.grid()
    
ax[0].legend(loc=2)
ax[1].set_ylim(6e4, 2e7)
ax[2].set_ylim([0.7, 500])

ax[2].text(1.1e3, 2, "$\delta\sim t/2$", alpha=0.7)
ax[2].loglog(frequencies, mur_by_skindepth(casing_t/2), ":k", alpha=0.6)

# ax[2].text(7e1, 2, "$\delta\sim t$", alpha=0.7)
# ax[2].loglog(frequencies, mur_by_skindepth(casing_t), ":k", alpha=0.2)

ax[0].set_ylabel("RMS Misfit (V/m)")
ax[1].set_ylabel("Recovered $\sigma$ (S/m)")
ax[2].set_ylabel("Recovered $\mu_r$")
ax[2].set_xlabel("frequency (Hz)")

ax[0].set_title("(a)")
ax[1].set_title("(b)")
ax[2].set_title("(c)")

plt.tight_layout()

# %%
skin_depths_casing = 500/np.sqrt(sigma_casing * frequencies) 

fig, ax = plt.subplots(1, 1) 
ax.loglog(frequencies, skin_depths_casing)
ax.loglog(frequencies, np.ones_like(frequencies)*casing_t, "--k")
ax.loglog(frequencies, np.ones_like(frequencies)*csz, ":k")

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 3))

freq_ind = 7

mur_1Hz =  np.array([mur_min[k][freq_ind] for k in plot_keys])
mur_true = np.array([np.float64(k.split('_')[-1][3:]) for k in plot_keys])

slope, intercept, r, p, std_err = stats.linregress(mur_true, mur_1Hz)

ax.plot(mur_true, mur_1Hz, "ko", label="recoverd $\mu_r$")
    
ax.plot(mur_true, slope*mur_true, ":k", alpha=0.5, label=f"slope: {slope:1.2f}")
ax.set_xlabel("true $\mu_r$")
ax.set_ylabel("recovered $\mu_r$")
ax.set_title(f"{frequencies[freq_ind]} Hz")
ax.grid("both")
# ax.set_aspect(1)
ax.legend()
    # ax.plot()

# %%
casing_t

# %%
casing_t/(casing_b)

# %%
from scipy import stats

# %%
slope

# %%
intercept

# %%
std_err
