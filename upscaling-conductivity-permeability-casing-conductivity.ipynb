# %% [markdown]
# # upscaling when the conductivity changes

# %%
import numpy as np
import os
import scipy.sparse as sp
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, LinearSegmentedColormap, Normalize
from matplotlib import cm as colormap
import time
from string import ascii_lowercase
import pickle
from multiprocessing import Pool

# SimPEG, discretize/
import discretize
from discretize import utils
from simpeg.electromagnetics import frequency_domain as fdem
from simpeg import(
    maps, Report, data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils
)
from pymatsolver import Pardiso

from utils import pad_for_casing_and_data

# %%
from matplotlib import rcParams
rcParams["font.size"] = 16

# %%
directory_path = "/t40array/lheagy/casing-upscaling-permeable-vary-conductivity"

# %%
def ensure_directory_exists(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# Example usage
ensure_directory_exists(directory_path)
# Out:
# Directory '/t40array/lheagy/casing-upscaling-permeable-vary-conductivity' already exists.

# %%
save_figures = False
fig_dir_high = "figures"
fig_dir_low = "low-rez-figures"

dpi_high=400
dpi_low=150

# %% [markdown]
# ## Simulation parameters

# %%
# # conductivities
sigma_air = 1e-4
sigma_back = 1e-1
casing_l = 500
sigma_casing = np.r_[1e4, 5e4, 1e5, 5e5, 1e6, 5e6, 1e7]
mur_casing = np.r_[1, 10, 25, 50, 100, 150, 200]

# # casing geometry
casing_b = 5e-2  
casing_t = 1e-2 #np.r_[5e-3, 7.5e-3, 10e-3, 12.5e-3, 15e-3, 20e-3]
casing_a = casing_b - casing_t

# %%
src_dz = 10
src_z = -515 #np.r_[-100, -250, -400, -495, -500, -550, -600]

# %%
# generate a mesh
hx = pad_for_casing_and_data(
   casing_outer_radius = casing_b,
    csx1 = casing_t/4, 
    csx2 = 25, 
    pfx1 = 1.3,
    pfx2 = 1.5, 
    domain_x = 1000, 
    npadx = 10
)

pfz = 1.3
npad_z = 28
csz = 1
n_core_extra = 10
ncore_z = int(np.max(np.r_[np.abs(casing_l), np.abs(src_z)]) / csz) + n_core_extra
hz = discretize.utils.unpack_widths(
    [(csz, npad_z, -pfz), (csz, ncore_z), (csz, npad_z, pfz)]
)

# %%
mesh = discretize.CylindricalMesh(
    [hx, np.r_[2*np.pi], hz], origin=np.r_[0, 0, -np.sum(hz[:npad_z + int(ncore_z)])],
)

fig, ax = plt.subplots(1, 1)
mesh.plot_grid(ax=ax)
# ax.set_xlim([0, 5])
# ax.set_ylim(-50, 10)
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
mesh.n_cells
# Out:
# 62167

# %%
def get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sigma_casing, sigma_air=1e-4, mur_casing=1):

    model = np.ones(mesh.n_cells)*sigma_air
    model[mesh.cell_centers[:, 2] < 0] = sigma_back

    mur = np.ones(mesh.n_cells)

    inds_casing_x = (
        (mesh.cell_centers[:, 0] > casing_a) & 
        (mesh.cell_centers[:, 0] < casing_b)
    )
    inds_casing_z = (
        (mesh.cell_centers[:, 2] < 0) &
        (mesh.cell_centers[:, 2] > -casing_l)
    )
    inds_casing = inds_casing_x & inds_casing_z

    model[inds_casing] = sigma_casing
    mur[inds_casing] = mur_casing

    return model, mur

# %%
models = {}
for sig in sigma_casing: 
    for mur in mur_casing:
        key = f"casing_sig{sig:1.0e}_mur{mur:1.0f}"
        sig_model, mur_model = get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sig, mur_casing=mur)
        models[key] = {
            "sigma": sig_model, 
            "mur": mur_model
        }
keys = list(models.keys())

# %%
keys
# Out:
# ['casing_sig1e+04_mur1',
#  'casing_sig1e+04_mur10',
#  'casing_sig1e+04_mur25',
#  'casing_sig1e+04_mur50',
#  'casing_sig1e+04_mur100',
#  'casing_sig1e+04_mur150',
#  'casing_sig1e+04_mur200',
#  'casing_sig5e+04_mur1',
#  'casing_sig5e+04_mur10',
#  'casing_sig5e+04_mur25',
#  'casing_sig5e+04_mur50',
#  'casing_sig5e+04_mur100',
#  'casing_sig5e+04_mur150',
#  'casing_sig5e+04_mur200',
#  'casing_sig1e+05_mur1',
#  'casing_sig1e+05_mur10',
#  'casing_sig1e+05_mur25',
#  'casing_sig1e+05_mur50',
#  'casing_sig1e+05_mur100',
#  'casing_sig1e+05_mur150',
#  'casing_sig1e+05_mur200',
#  'casing_sig5e+05_mur1',
#  'casing_sig5e+05_mur10',
#  'casing_sig5e+05_mur25',
#  'casing_sig5e+05_mur50',
#  'casing_sig5e+05_mur100',
#  'casing_sig5e+05_mur150',
#  'casing_sig5e+05_mur200',
#  'casing_sig1e+06_mur1',
#  'casing_sig1e+06_mur10',
#  'casing_sig1e+06_mur25',
#  'casing_sig1e+06_mur50',
#  'casing_sig1e+06_mur100',
#  'casing_sig1e+06_mur150',
#  'casing_sig1e+06_mur200',
#  'casing_sig5e+06_mur1',
#  'casing_sig5e+06_mur10',
#  'casing_sig5e+06_mur25',
#  'casing_sig5e+06_mur50',
#  'casing_sig5e+06_mur100',
#  'casing_sig5e+06_mur150',
#  'casing_sig5e+06_mur200',
#  'casing_sig1e+07_mur1',
#  'casing_sig1e+07_mur10',
#  'casing_sig1e+07_mur25',
#  'casing_sig1e+07_mur50',
#  'casing_sig1e+07_mur100',
#  'casing_sig1e+07_mur150',
#  'casing_sig1e+07_mur200']

# %%
def plot_casing(model, xlim=None, zlim=None, vmin=None, vmax=None, ax=None, cb_label=None, logscale=True, show_cb=False): 
    if ax is None: 
        fig, ax = plt.subplots(1, 1)
    if logscale is True: 
        pcolor_opts={"norm":LogNorm(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    else: 
        pcolor_opts={"norm":Normalize(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    out = mesh.plot_image(
        model, pcolor_opts=pcolor_opts, ax=ax, mirror=True
    )

    if show_cb is True: 
        cb = plt.colorbar(out[-1], shrink=0.5)
        cb.set_label(cb_label)

    if xlim is not None: 
        ax.set_xlim(xlim)
    if zlim is not None: 
        ax.set_ylim(zlim)

    ax.set_xlabel("x (m)")
    ax.set_ylabel("z (m)")
    return ax, out

# %%
# fig, ax = plt.subplots(1, 2, figsize=(2*4.5, 6.5), dpi=dpi_high, sharey=True)

# xlim = 0.3*np.r_[-1, 1]
# zlim = np.r_[-590, 20]
# vmin = sigma_air
# vmax = sigma_casing

# sigma_map, mu_map = create_maps(key)

# _, out = plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[0])
# _, out = plot_casing(sigma_map * np.r_[np.log(1e5)], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[1])
# # cb.set_label("conductivity (S/m)")

# for i, a in enumerate(ax): 
#     a.plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok", ms=4)
#     a.text(0.01, src_z, "10m dipole", va="center", fontsize=14)
#     for sign in np.r_[-1, 1]: 
#         if i == 0: 
#             a.arrow(
#                 0, -casing_l+120, casing_a*sign, 0, length_includes_head=True, shape="full", width=1e-2,
#                 head_length=1e-2, head_width=10, color="k"
#             ) 
#             a.text(0, -casing_l+100, f"{casing_a*1e2*2:1.0f} cm", ha="center", fontsize=10)
#             a.text(0.06, -200, "$\sigma$: 5e6 S/m \n$\mu>\mu_0$", fontsize=14)
#         else: 
#             a.text(0.06, -200, "$\sigma$: ? \n$\mu:?$", fontsize=14)
        
#         a.arrow(
#             0, -casing_l+80, casing_b*sign, 0, length_includes_head=True, shape="full", width=1e-2,
#             head_length=1e-2, head_width=10, color="k"
#         )
#         a.text(0, -casing_l+55, f"{casing_b*1e2*2:1.0f} cm", ha="center", fontsize=10)
#         a.text(-0.29, zlim.min()+10, f"{(1./sigma_back[0]):1.0f} $\Omega$m", fontsize=14)

# ax[1].set_ylabel("")

# ax[0].set_title("(a) true cased well")
# ax[1].set_title("(b) solid cylinder")

# %%
plot_keys = keys[:5]
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 0.2*np.r_[-1, 1]
zlim = np.r_[-600, 10]
vmin = sigma_air
vmax = np.max(sigma_casing)

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i])
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %%
# plot_keys = keys
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 0.2*np.r_[-1, 1]
zlim = np.r_[-600, 10]
vmin = 1
vmax = mur_casing.max()

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["mur"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i], logscale=False)
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %% [markdown]
# ## set up the simulations

# %%
frequencies = np.r_[1] #10**np.linspace(-1, 4, 36)
frequencies
# Out:
# array([1])

# %%
src_list = []
src_locations = np.array([
    [0, 0, src_z+src_dz/2.],
    [0, 0, src_z-src_dz/2.]
])
for f in frequencies: 
    src = fdem.sources.LineCurrent([], location=src_locations, frequency=f)
    src_list.append(src)

wires = maps.Wires(("sigma", mesh.n_cells), ("mur", mesh.n_cells))
permeability_map = maps.MuRelative(mesh)

survey = fdem.Survey(src_list)

sim = fdem.simulation.Simulation3DMagneticField(
    mesh=mesh, sigmaMap=wires.sigma, muMap=permeability_map * wires.mur,
    survey=survey, solver=Pardiso, #mu=mur * mu_0
#     verbose=True
)

# %%
def run_simulation(key):
    
    filename = os.path.sep.join([directory_path, key])

    t = time.time()
    print(f"starting {key}..., saving to {filename}")
    fields = sim.fields(np.r_[models[key]["sigma"], models[key]["mur"]])
    print(f" ... done. {time.time()-t:1.2e} \n")
    
    np.save(filename, fields[:, "hSolution"])

    return fields

# %%
fields = {}

# %%
for key in keys: 
    if key not in fields: 
        fields[key] = run_simulation(key)
# Out:
# starting casing_sig1e+04_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur1
#  ... done. 3.60e-01
#
# starting casing_sig1e+04_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur10
#  ... done. 2.59e-01
#
# starting casing_sig1e+04_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur25
#  ... done. 2.56e-01
#
# starting casing_sig1e+04_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur50
#  ... done. 2.62e-01
#
# starting casing_sig1e+04_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur100
#  ... done. 2.57e-01
#
# starting casing_sig1e+04_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur150
#  ... done. 2.52e-01
#
# starting casing_sig1e+04_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+04_mur200
#  ... done. 2.55e-01
#
# starting casing_sig5e+04_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur1
#  ... done. 2.54e-01
#
# starting casing_sig5e+04_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur10
#  ... done. 2.53e-01
#
# starting casing_sig5e+04_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur25
#  ... done. 2.49e-01
#
# starting casing_sig5e+04_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur50
#  ... done. 2.51e-01
#
# starting casing_sig5e+04_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur100
#  ... done. 2.49e-01
#
# starting casing_sig5e+04_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur150
#  ... done. 2.46e-01
#
# starting casing_sig5e+04_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+04_mur200
#  ... done. 2.47e-01
#
# starting casing_sig1e+05_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur1
#  ... done. 2.46e-01
#
# starting casing_sig1e+05_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur10
#  ... done. 2.48e-01
#
# starting casing_sig1e+05_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur25
#  ... done. 2.56e-01
#
# starting casing_sig1e+05_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur50
#  ... done. 2.54e-01
#
# starting casing_sig1e+05_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur100
#  ... done. 2.46e-01
#
# starting casing_sig1e+05_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur150
#  ... done. 2.46e-01
#
# starting casing_sig1e+05_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+05_mur200
#  ... done. 2.47e-01
#
# starting casing_sig5e+05_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur1
#  ... done. 2.59e-01
#
# starting casing_sig5e+05_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur10
#  ... done. 2.58e-01
#
# starting casing_sig5e+05_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur25
#  ... done. 2.41e-01
#
# starting casing_sig5e+05_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur50
#  ... done. 1.98e-01
#
# starting casing_sig5e+05_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur100
#  ... done. 1.85e-01
#
# starting casing_sig5e+05_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur150
#  ... done. 1.83e-01
#
# starting casing_sig5e+05_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+05_mur200
#  ... done. 1.84e-01
#
# starting casing_sig1e+06_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur1
#  ... done. 1.84e-01
#
# starting casing_sig1e+06_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur10
#  ... done. 1.84e-01
#
# starting casing_sig1e+06_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur25
#  ... done. 1.90e-01
#
# starting casing_sig1e+06_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur50
#  ... done. 1.86e-01
#
# starting casing_sig1e+06_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur100
#  ... done. 1.85e-01
#
# starting casing_sig1e+06_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur150
#  ... done. 1.80e-01
#
# starting casing_sig1e+06_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+06_mur200
#  ... done. 1.86e-01
#
# starting casing_sig5e+06_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur1
#  ... done. 1.85e-01
#
# starting casing_sig5e+06_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur10
#  ... done. 1.93e-01
#
# starting casing_sig5e+06_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur25
#  ... done. 1.80e-01
#
# starting casing_sig5e+06_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur50
#  ... done. 1.81e-01
#
# starting casing_sig5e+06_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur100
#  ... done. 1.80e-01
#
# starting casing_sig5e+06_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur150
#  ... done. 1.91e-01
#
# starting casing_sig5e+06_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig5e+06_mur200
#  ... done. 1.81e-01
#
# starting casing_sig1e+07_mur1..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur1
#  ... done. 1.88e-01
#
# starting casing_sig1e+07_mur10..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur10
#  ... done. 1.84e-01
#
# starting casing_sig1e+07_mur25..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur25
#  ... done. 1.87e-01
#
# starting casing_sig1e+07_mur50..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur50
#  ... done. 1.89e-01
#
# starting casing_sig1e+07_mur100..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur100
#  ... done. 1.81e-01
#
# starting casing_sig1e+07_mur150..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur150
#  ... done. 1.81e-01
#
# starting casing_sig1e+07_mur200..., saving to /t40array/lheagy/casing-upscaling-permeable-vary-conductivity/casing_sig1e+07_mur200
#  ... done. 1.86e-01

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

key = keys[0]
freq_ind = 0
xlim = 500*np.r_[-1, 1]
zlim = np.r_[-1000, 10]

field_plot = (mesh.average_face_to_cell_vector * fields[key][sim.survey.source_list[freq_ind], "e"])

for i, component in enumerate(["real", "imag"]): 
    out = mesh.plot_image(
        getattr(field_plot, component), "CCv", view="vec", 
        range_x = xlim, range_y = zlim,
        sample_grid = np.r_[10, 10],
        mirror=True, #mirror_data=field_mirror,
        ax=ax[i], 
        pcolor_opts={"norm":LogNorm(vmin=1e-7, vmax=1e-2)}
    )
    cb = plt.colorbar(out[0], ax=ax[i])
    cb.set_label("Electric Field (V/m)")
    ax[i].set_aspect(1)
    ax[i].set_title(f"{frequencies[freq_ind]} Hz, {component}")
plt.tight_layout()

# %%
rcParams["font.size"] = 12

# %%
fields.keys()
# Out:
# dict_keys(['casing_sig1e+04_mur1', 'casing_sig1e+04_mur10', 'casing_sig1e+04_mur25', 'casing_sig1e+04_mur50', 'casing_sig1e+04_mur100', 'casing_sig1e+04_mur150', 'casing_sig1e+04_mur200', 'casing_sig5e+04_mur1', 'casing_sig5e+04_mur10', 'casing_sig5e+04_mur25', 'casing_sig5e+04_mur50', 'casing_sig5e+04_mur100', 'casing_sig5e+04_mur150', 'casing_sig5e+04_mur200', 'casing_sig1e+05_mur1', 'casing_sig1e+05_mur10', 'casing_sig1e+05_mur25', 'casing_sig1e+05_mur50', 'casing_sig1e+05_mur100', 'casing_sig1e+05_mur150', 'casing_sig1e+05_mur200', 'casing_sig5e+05_mur1', 'casing_sig5e+05_mur10', 'casing_sig5e+05_mur25', 'casing_sig5e+05_mur50', 'casing_sig5e+05_mur100', 'casing_sig5e+05_mur150', 'casing_sig5e+05_mur200', 'casing_sig1e+06_mur1', 'casing_sig1e+06_mur10', 'casing_sig1e+06_mur25', 'casing_sig1e+06_mur50', 'casing_sig1e+06_mur100', 'casing_sig1e+06_mur150', 'casing_sig1e+06_mur200', 'casing_sig5e+06_mur1', 'casing_sig5e+06_mur10', 'casing_sig5e+06_mur25', 'casing_sig5e+06_mur50', 'casing_sig5e+06_mur100', 'casing_sig5e+06_mur150', 'casing_sig5e+06_mur200', 'casing_sig1e+07_mur1', 'casing_sig1e+07_mur10', 'casing_sig1e+07_mur25', 'casing_sig1e+07_mur50', 'casing_sig1e+07_mur100', 'casing_sig1e+07_mur150', 'casing_sig1e+07_mur200'])

# %%
def skin_depth(f, sigma, mur):
    return np.sqrt(2/(2*np.pi*f*sigma*mur*mu_0))

# %%
rx_x = np.linspace(25, 500, 20)
rx_z = -np.linspace(0, 600, 25) - csz/2
rx_z
# Out:
# array([-5.000e-01, -2.550e+01, -5.050e+01, -7.550e+01, -1.005e+02,
#        -1.255e+02, -1.505e+02, -1.755e+02, -2.005e+02, -2.255e+02,
#        -2.505e+02, -2.755e+02, -3.005e+02, -3.255e+02, -3.505e+02,
#        -3.755e+02, -4.005e+02, -4.255e+02, -4.505e+02, -4.755e+02,
#        -5.005e+02, -5.255e+02, -5.505e+02, -5.755e+02, -6.005e+02])

# %%
def create_receivers():
    rx_ex_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="real",
    )
    rx_ex_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="imag",
    )
    rx_ez_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="real",
    )
    rx_ez_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="imag",
    )
    return rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im

# %%
rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
Px = rx_ex_re.getP(mesh, "Fx")
Pz = rx_ez_re.getP(mesh, "Fz")

# %%
frequencies
# Out:
# array([1])

# %%
range(len(frequencies))
# Out:
# range(0, 1)

# %%
# get data_vectors
dobs_dict = {}

for k in keys:
    tmp_dict = {}
    for si in range(len(frequencies)):
        src = sim.survey.source_list[si]
        e = fields[k][src, "e"]
        edatax = (Px * e).squeeze()
        edataz = (Pz * e).squeeze()
        tmp_dict[frequencies[si]] = {
            "real_x": edatax.real,
            "imag_x": edatax.imag,
            "real_z": edataz.real,
            "imag_z": edataz.imag
        }
    dobs_dict[k] = tmp_dict

# %%
fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

key_ind = 0
key = keys[key_ind]

ax = np.atleast_2d(ax)
for i, freq in enumerate(frequencies): 
    # ax.plot(rx_x, dobs_dict[key][freq]["real"].reshape((len(rx_x), len(rx_z)), order="F"), "o" );
    for j, component in enumerate(["real_x", "imag_x"]): 
        plt.colorbar(
            ax[i, j].contourf(
                rx_x, rx_z, np.log10(np.abs(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T)), 30,
                # vmin=-7, vmax=-2
                # norm=LogNorm()
            ), ax=ax[i, j]
        )
        
        ax[i, j].plot(rx_ex_re.locations[:, 0], rx_ex_re.locations[:, 2], "w.", ms=1)
        ax[i, j].set_aspect(1)
        ax[i, j].set_title(f"{freq} Hz {component}")

plt.tight_layout()

# %%
def get_amplitude_phase(real, imag):
    # real = f.real
    # imag = f.imag
    amplitude = np.sqrt(real**2 + imag**2)
    phase = 180/np.pi*np.arctan2(imag, real)
    return amplitude, phase

# %%
# fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

# key_ind = 0
# key = keys[key_ind]

# for i, freq in enumerate(frequencies): 
#     amp, phase = get_amplitude_phase(*(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T for component in ["real", "imag"]))
#     for j, plotme in enumerate([np.log10(np.abs(amp)), phase]): 
#         plt.colorbar(
#             ax[i, j].contourf(
#                 rx_x, rx_z, plotme, 30,
#                 # vmin=-7, vmax=-2
#                 # norm=LogNorm()
#                 cmap = "twilight" if j == 1 else "viridis"
#             ), ax=ax[i, j]
#         )
        
#         ax[i, j].plot(rx_e_re.locations[:, 0], rx_e_re.locations[:, 2], "w.", ms=1)
#         ax[i, j].set_aspect(1)
#         ax[i, j].set_title(f"{freq} Hz {'amplitude' if j==0 else 'phase'}")

# plt.tight_layout()

# %% [markdown]
# # set up mappings and simulation

# %%
def create_maps(key, true_inds=False, casing_t_ind=0):
    indsx = (mesh.cell_centers[:, 0] < casing_b)
    if true_inds is True: 
        indsx = indsx & (mesh.cell_centers[:, 0] > casing_b - casing_t[casing_t_ind])
    
    inds_interior = (
        indsx &
        (mesh.cell_centers[:, 2] <= 0) &
        (mesh.cell_centers[:, 2] >= -casing_l)
    )

    active_inds_sigma = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=np.log(models[key]["sigma"][~inds_interior])
    )

    active_inds_mur = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=models[key]["mur"][~inds_interior]
    )

    projection_sigma = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])
    projection_mu = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])

    exp_map = maps.ExpMap(mesh)
    mur_map = maps.MuRelative(mesh)

    sigma_map = exp_map * active_inds_sigma * projection_sigma
    mu_map = mur_map * active_inds_mur * projection_mu

    return sigma_map, mu_map

# %%
src_locations
# Out:
# array([[   0.,    0., -510.],
#        [   0.,    0., -520.]])

# %%
def create_survey(freq, components=["x"]): 
    rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
    rx_list = []
    if "x" in components: 
        rx_list.append([rx_ex_re, rx_ex_im])
    if "z" in components: 
        rx_list.append([rx_ez_re, rx_ez_im])
    src = fdem.sources.LineCurrent(list(np.hstack(rx_list)), location=src_locations, frequency=freq)
    return fdem.Survey([src])

# %%
# create the simulation
def create_simulation(key, survey, invert_mu=False, true_inds=False):
    sigma_map, mu_map = create_maps(key, true_inds)

    if invert_mu is True: 
        wires = maps.Wires(("sigma", 1), ("mu", 1))
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map * wires.sigma,
            muMap=mu_map * wires.mu 
        )
    else: 
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map
        )
    return sim

# %%
def get_casing_conductivity_ind_by_key(key): 
    i = np.where([key == kk for kk in keys])[0]
    return np.int64(np.floor(i/(len(mur_casing))))

def get_mur_ind_by_key(key): 
    i = np.where([key == kk for kk in keys])[0]
    return np.mod(i, len(sigma_casing))

# %%
i = 18
print(keys[i])
j, k = get_casing_conductivity_ind_by_key(keys[i]), get_mur_ind_by_key(keys[i])
print(sigma_casing[j], mur_casing[k])
# Out:
# casing_sig1e+05_mur100
# [100000.] [100]

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)

data0 = {}
res0 = {}
rms0 = {}

components = ["x", "z"]

for i, key in enumerate(keys): 
    data_tmp = {}
    res_tmp = {}
    rms_tmp = {}
    
    for freq in frequencies: 
        survey = create_survey(freq, components)
    
        receivers = []
        if "x" in components: 
            receivers.append(["real_x", "imag_x"])
        if "z" in components: 
            receivers.append(["real_z", "imag_z"])
        dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])
    
        sim = create_simulation(key, survey, invert_mu=False)

        ii = get_casing_conductivity_ind_by_key(key)
        dpred = sim.dpred(np.log(sigdc[ii]))

        data_tmp[freq] = dpred
        res_tmp[freq] = dpred - dobsvec
        rms_tmp[freq] = np.sqrt(np.sum(res_tmp[freq]**2) / len(res_tmp[freq]))
    data0[key] = data_tmp
    res0[key] = res_tmp
    rms0[key] = rms_tmp

# %%
plot_inds = [2, 3, 4, 5, 6]

# %%
# freqs = frequencies[[7, 12, 14]]
freqs = frequencies[[0]]
fig, ax = plt.subplots(3, len(freqs), figsize=(4.5*len(freqs), 7.5), sharex=True, dpi=dpi_high)
ax=np.atleast_2d(ax).T
for j, freq in enumerate(freqs):
    plotind = 0
    for i, key in enumerate(keys): 
        if i in plot_inds:
            if i == 0:
                color = "k"
            else: 
                color = f"C{plotind}"
                plotind = plotind + 1
            dobs = dobs_dict[key][freq]["real_x"][:len(rx_x)]
            d0 = data0[key][freq][:len(rx_x)]
            ax[0, j].semilogy(rx_x, (dobs), color=color, label=f"{mur_casing[i]:1.0f}$\mu_0$")
            ax[0, j].semilogy(rx_x, (d0), f"--{color}")
            ax[1, j].semilogy(rx_x, np.abs(d0-dobs), color)
            ax[2, j].semilogy(rx_x, np.abs(d0-dobs)/np.abs(dobs)*100, color)
    
            # ax[0, j].set_title(f"{freq:1.0f} Hz\n({ascii_lowercase[j]})")
    
            # ax[0, j].set_ylim([2e-7, 5e-6])
            # ax[1, j].set_ylim([3e-10, 1e-6])
            # ax[2, j].set_ylim([5e-2, 1e2])

ax[0, 0].set_xlim([0, 400])
ax[0, 0].set_ylabel("E$_x$ real (V/m)")
ax[1, 0].set_ylabel("difference (V/m)")
ax[2, 0].set_ylabel("difference (%)")

ax[0, 0].legend(loc=1)

# ax[0, 0].set_title("(a) 2 Hz real E$_x$")
# ax[0, 1].set_title("(b) 10 Hz real E$_x$")

# ax[1, 0].set_title("(c) 2 Hz difference (cylinder - hollow)")
# ax[1, 1].set_title("(d) 10 Hz difference (cylinder - hollow)")

# ax[2, 0].set_title("(e) 2 Hz difference (%)")
# ax[2, 1].set_title("(f) 10 Hz difference (%)")

for k, a in enumerate(ax.flatten()):
    a.grid()
#     if k > 1: 
#         a.set_title(f"({ascii_lowercase[k]})")

for a in ax[2, :].flatten():
    a.set_xlabel("x (m)")

for a in ax[:, 1:].flatten():
    a.set_yticklabels("")
    

plt.tight_layout()

# %% [markdown]
# # set up inversions

# %%
class SaveInversionProgress(directives.InversionDirective):
    """
    A custom directive to save items of interest during the course of an inversion
    """
    
    results_file = None
    
    def initialize(self):
        """
        This is called when we first start running an inversion
        """
        # initialize an empty dictionary for storing results 
        self.inversion_results = {
            "iteration":[],
            "phi_d":[],
            "dpred":[],
            "logsigma":[],
            "mur":[],
            "residual":[],
            "rms":[],
        }

    def endIter(self):
        """
        This is run at the end of every iteration. So here, we just append 
        the new values to our dictionary
        """
        
        # Save the data
        self.inversion_results["iteration"].append(self.opt.iter)
        self.inversion_results["phi_d"].append(self.invProb.phi_d)
        self.inversion_results["dpred"].append(self.invProb.dpred)
        self.inversion_results["logsigma"].append(self.invProb.model[0])
        self.inversion_results["mur"].append(self.invProb.model[1])

        dobs = self.invProb._dmisfit.objfcts[0].data.dobs
        
        self.inversion_results["residual"].append((dobs - self.invProb.dpred))
        self.inversion_results["rms"].append(np.sqrt(np.sum(self.inversion_results["residual"][-1]**2)/len(dobs)))
        
        if self.results_file is not None: 
            with open(f"{self.results_file}", "wb") as fp:
                pickle.dump(self.inversion_results, fp)

# %%
def create_inversion(
    key, freq, invert_mu=False, relative_error=None, noise_floor=None,
    maxIter=10, maxIterCG=50, maxIterLS=10, true_casing_inds=False, components=["x"],
    chifact=0.5
):
    # create the simulation
    survey = create_survey(freq, components)

    receivers = []
    if "x" in components: 
        receivers.append(["real_x", "imag_x"])
    if "z" in components: 
        receivers.append(["real_z", "imag_z"])
    dobsvec = np.hstack([dobs_dict[key][freq][rx] for rx in np.hstack(receivers)])
    dobs = data.Data(
        survey=survey, dobs=dobsvec, relative_error=relative_error, noise_floor=noise_floor
    )

    sim = create_simulation(key, survey, invert_mu, true_casing_inds)
    dmis = data_misfit.L2DataMisfit(data=dobs, simulation=sim)

    if invert_mu is True: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([2]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )
    
    else: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([1]))
        opt = optimization.ProjectedGNCG(
            maxIter=maxIter, #lower=np.r_[-np.inf], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            # aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )

    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=0)

    # directives
    target_misfit = directives.TargetMisfit(chifact=chifact)
    
    if true_casing_inds:
        filename_save = f"inv_{key}_{freq:1.0f}_true_casing.pkl"
    else: 
        filename_save = f"inv_{key}_{freq:1.0f}.pkl"
    inversion_progress = SaveInversionProgress(results_file=f"{directory_path}/{filename_save}")
    
    # inversion 
    inv = inversion.BaseInversion(inv_prob, [target_misfit, inversion_progress])
    
    return inv

# %% [markdown]
# # experiment 2: invert for solid cylinder conductivity, permeability

# %%
keys
# Out:
# ['casing_sig1e+04_mur1',
#  'casing_sig1e+04_mur10',
#  'casing_sig1e+04_mur25',
#  'casing_sig1e+04_mur50',
#  'casing_sig1e+04_mur100',
#  'casing_sig1e+04_mur150',
#  'casing_sig1e+04_mur200',
#  'casing_sig5e+04_mur1',
#  'casing_sig5e+04_mur10',
#  'casing_sig5e+04_mur25',
#  'casing_sig5e+04_mur50',
#  'casing_sig5e+04_mur100',
#  'casing_sig5e+04_mur150',
#  'casing_sig5e+04_mur200',
#  'casing_sig1e+05_mur1',
#  'casing_sig1e+05_mur10',
#  'casing_sig1e+05_mur25',
#  'casing_sig1e+05_mur50',
#  'casing_sig1e+05_mur100',
#  'casing_sig1e+05_mur150',
#  'casing_sig1e+05_mur200',
#  'casing_sig5e+05_mur1',
#  'casing_sig5e+05_mur10',
#  'casing_sig5e+05_mur25',
#  'casing_sig5e+05_mur50',
#  'casing_sig5e+05_mur100',
#  'casing_sig5e+05_mur150',
#  'casing_sig5e+05_mur200',
#  'casing_sig1e+06_mur1',
#  'casing_sig1e+06_mur10',
#  'casing_sig1e+06_mur25',
#  'casing_sig1e+06_mur50',
#  'casing_sig1e+06_mur100',
#  'casing_sig1e+06_mur150',
#  'casing_sig1e+06_mur200',
#  'casing_sig5e+06_mur1',
#  'casing_sig5e+06_mur10',
#  'casing_sig5e+06_mur25',
#  'casing_sig5e+06_mur50',
#  'casing_sig5e+06_mur100',
#  'casing_sig5e+06_mur150',
#  'casing_sig5e+06_mur200',
#  'casing_sig1e+07_mur1',
#  'casing_sig1e+07_mur10',
#  'casing_sig1e+07_mur25',
#  'casing_sig1e+07_mur50',
#  'casing_sig1e+07_mur100',
#  'casing_sig1e+07_mur150',
#  'casing_sig1e+07_mur200']

# %%
models.keys()
# Out:
# dict_keys(['casing_sig1e+04_mur1', 'casing_sig1e+04_mur10', 'casing_sig1e+04_mur25', 'casing_sig1e+04_mur50', 'casing_sig1e+04_mur100', 'casing_sig1e+04_mur150', 'casing_sig1e+04_mur200', 'casing_sig5e+04_mur1', 'casing_sig5e+04_mur10', 'casing_sig5e+04_mur25', 'casing_sig5e+04_mur50', 'casing_sig5e+04_mur100', 'casing_sig5e+04_mur150', 'casing_sig5e+04_mur200', 'casing_sig1e+05_mur1', 'casing_sig1e+05_mur10', 'casing_sig1e+05_mur25', 'casing_sig1e+05_mur50', 'casing_sig1e+05_mur100', 'casing_sig1e+05_mur150', 'casing_sig1e+05_mur200', 'casing_sig5e+05_mur1', 'casing_sig5e+05_mur10', 'casing_sig5e+05_mur25', 'casing_sig5e+05_mur50', 'casing_sig5e+05_mur100', 'casing_sig5e+05_mur150', 'casing_sig5e+05_mur200', 'casing_sig1e+06_mur1', 'casing_sig1e+06_mur10', 'casing_sig1e+06_mur25', 'casing_sig1e+06_mur50', 'casing_sig1e+06_mur100', 'casing_sig1e+06_mur150', 'casing_sig1e+06_mur200', 'casing_sig5e+06_mur1', 'casing_sig5e+06_mur10', 'casing_sig5e+06_mur25', 'casing_sig5e+06_mur50', 'casing_sig5e+06_mur100', 'casing_sig5e+06_mur150', 'casing_sig5e+06_mur200', 'casing_sig1e+07_mur1', 'casing_sig1e+07_mur10', 'casing_sig1e+07_mur25', 'casing_sig1e+07_mur50', 'casing_sig1e+07_mur100', 'casing_sig1e+07_mur150', 'casing_sig1e+07_mur200'])

# %%
inv_dict = {}
relative_error = 0.005
noise_floor = 1e-8

for i, key in enumerate(keys):
    # if i == 0: 
    #     chifact = 0.5
    # else: 
    chifact = 1e-6
    if key not in inv_dict: 
        tmp = {}
        for freq in frequencies:
            
            tmp[freq] = create_inversion(
                    key, freq, invert_mu=True, relative_error=relative_error, noise_floor=noise_floor,
                    components=["x", "z"], chifact=chifact
                )
        inv_dict[key] = tmp

# %%
tmp = inv_dict[keys[0]][frequencies[0]]
np.unique(tmp.invProb.dmisfit.objfcts[0].simulation.muMap * np.r_[10, 1])
# Out:
# array([1.25663706e-06])

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)
# starting_models = {
#     True: np.r_[np.log(sigstart), 1],
#     False: np.r_[np.log(sigstart)]
# }

# %%
sigdc
# Out:
# array([   3600.,   18000.,   36000.,  180000.,  360000., 1800000.,
#        3600000.])

# %%
mrec_dict = {}

for i, key in enumerate(keys):
    ci = get_casing_conductivity_ind_by_key(key)
    mi = get_mur_ind_by_key(key)
    
    if key not in mrec_dict: 
        tmp = {}
        for j, freq in enumerate(frequencies):
            print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
            # if i == 0: 
            
            mstart = np.r_[np.log(sigdc[ci]), 1] #mur_casing[mi]]
            # else: 
            #     mstart = mrec_dict[keys[0]][freq]
            tmp[freq] = inv_dict[key][freq].run(mstart)
            print(f"recovered conductivity: {np.exp(inv_dict[key][freq].m[0]):1.2e}, recovered permeability: {inv_dict[key][freq].m[1]:1.2f} mu0 \n")
        mrec_dict[key] = tmp
# Out:
# ------------------------ casing_sig1e+04_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.29e-03  0.00e+00  2.29e-03    1.13e+01      0
#    1  0.00e+00  8.71e-04  3.18e-08  8.71e-04    1.77e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.4223e-03 <= tolF*(1+|f0|) = 1.0023e-01
# 1 : |xc-x_last| = 2.5208e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 1.7705e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 1.7705e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.44e-03  0.00e+00  2.44e-03    1.13e+01      0
#    1  0.00e+00  1.02e-03  3.16e-08  1.02e-03    1.78e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.4163e-03 <= tolF*(1+|f0|) = 1.0024e-01
# 1 : |xc-x_last| = 2.5156e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 1.7797e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 1.7797e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.29e-03  0.00e+00  4.29e-03    1.12e+01      0
#    1  0.00e+00  2.89e-03  3.14e-08  2.89e-03    1.89e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.4064e-03 <= tolF*(1+|f0|) = 1.0043e-01
# 1 : |xc-x_last| = 2.5068e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 1.8914e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 1.8914e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.19e-02  0.00e+00  1.19e-02    1.12e+01      0
#    1  0.00e+00  1.05e-02  3.11e-08  1.05e-02    2.32e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3900e-03 <= tolF*(1+|f0|) = 1.0119e-01
# 1 : |xc-x_last| = 2.4921e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 2.3197e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.3197e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.39e-02  0.00e+00  4.39e-02    1.10e+01      0
#    1  0.00e+00  4.26e-02  3.03e-08  4.26e-02    3.62e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3577e-03 <= tolF*(1+|f0|) = 1.0439e-01
# 1 : |xc-x_last| = 2.4630e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 3.6187e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 3.6187e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  9.85e-02  0.00e+00  9.85e-02    1.09e+01      0
#    1  0.00e+00  9.71e-02  2.96e-08  9.71e-02    5.13e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3262e-03 <= tolF*(1+|f0|) = 1.0985e-01
# 1 : |xc-x_last| = 2.4343e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 5.1282e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 5.1282e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+04_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.75e-01  0.00e+00  1.75e-01    1.08e+01      0
#    1  0.00e+00  1.74e-01  2.89e-08  1.74e-01    6.71e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2954e-03 <= tolF*(1+|f0|) = 1.1755e-01
# 1 : |xc-x_last| = 2.4058e-04 <= tolX*(1+|x0|) = 9.2495e-01
# 1 : |proj(x-g)-x|    = 6.7082e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 6.7082e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+03, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.05e-02  0.00e+00  2.05e-02    6.41e+01      0
#    1  0.00e+00  1.14e-02  4.10e-08  1.14e-02    1.20e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.1780e-03 <= tolF*(1+|f0|) = 1.0205e-01
# 1 : |xc-x_last| = 2.8644e-04 <= tolX*(1+|x0|) = 1.0849e+00
# 1 : |proj(x-g)-x|    = 1.2028e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2028e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.77e-02  0.00e+00  2.77e-02    6.35e+01      0
#    1  0.00e+00  1.87e-02  4.02e-08  1.87e-02    1.58e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.0023e-03 <= tolF*(1+|f0|) = 1.0277e-01
# 1 : |xc-x_last| = 2.8369e-04 <= tolX*(1+|x0|) = 1.0849e+00
# 1 : |proj(x-g)-x|    = 1.5798e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.5798e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.20e-01  0.00e+00  1.20e-01    6.24e+01      0
#    1  0.00e+00  1.12e-01  3.90e-08  1.12e-01    3.71e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.7162e-03 <= tolF*(1+|f0|) = 1.1204e-01
# 1 : |xc-x_last| = 2.7915e-04 <= tolX*(1+|x0|) = 1.0849e+00
# 1 : |proj(x-g)-x|    = 3.7072e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.7072e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.99e-01  0.00e+00  4.99e-01    6.08e+01      0
#    1  0.00e+00  4.91e-01  3.69e-08  4.91e-01    7.73e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.2579e-03 <= tolF*(1+|f0|) = 1.4988e-01
# 1 : |xc-x_last| = 2.7171e-04 <= tolX*(1+|x0|) = 1.0849e+00
# 1 : |proj(x-g)-x|    = 7.7295e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.7295e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.10e+00  0.00e+00  2.10e+00    5.76e+01      0
#    1  0.00e+00  2.09e+00  3.31e-08  2.09e+00    1.59e-01      0
#    2  0.00e+00  9.76e-03  3.42e+02  9.76e-03    3.25e-01      0   Skip BFGS
#    3  0.00e+00  9.76e-03  3.42e+02  9.76e-03    3.25e-01      0
#    4  0.00e+00  9.76e-03  3.42e+02  9.76e-03    3.25e-01      3
#    5  0.00e+00  9.76e-03  3.42e+02  9.76e-03    3.25e-01      8   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 9.7646e-03 <= alp*descent     = 9.7646e-03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+04, recovered permeability: 27.14 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.81e+00  0.00e+00  4.81e+00    5.45e+01      0
#    1  0.00e+00  4.81e+00  2.97e-08  4.81e+00    2.42e-01      0
#    2  0.00e+00  9.77e-03  7.88e+02  9.77e-03    7.51e-01      0   Skip BFGS
#    3  0.00e+00  9.77e-03  7.88e+02  9.77e-03    7.51e-01      1
#    4  0.00e+00  9.77e-03  7.88e+02  9.77e-03    7.51e-01      1   Skip BFGS
#    5  0.00e+00  9.77e-03  7.88e+02  9.77e-03    7.51e-01      8
# ------------------------------------------------------------------
# 0 :    ft     = 9.7660e-03 <= alp*descent     = 9.7660e-03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+04, recovered permeability: 40.71 mu0
#
#
#
# ------------------------ casing_sig5e+04_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  8.65e+00  0.00e+00  8.65e+00    5.16e+01      0
#    1  0.00e+00  8.64e+00  2.66e-08  8.64e+00    3.24e-01      0
#    2  0.00e+00  9.77e-03  1.42e+03  9.77e-03    1.35e+00      0   Skip BFGS
#    3  0.00e+00  9.77e-03  1.42e+03  9.77e-03    1.35e+00      3
#    4  0.00e+00  9.77e-03  1.42e+03  9.77e-03    1.35e+00      7
# ------------------------------------------------------------------
# 0 :    ft     = 9.7692e-03 <= alp*descent     = 9.7692e-03
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+04, recovered permeability: 54.27 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.22e-02  0.00e+00  4.22e-02    9.37e+01      0
#    1  0.00e+00  2.85e-02  4.27e-08  2.85e-02    1.88e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3684e-02 <= tolF*(1+|f0|) = 1.0422e-01
# 1 : |xc-x_last| = 2.9217e-04 <= tolX*(1+|x0|) = 1.1539e+00
# 1 : |proj(x-g)-x|    = 1.8777e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8777e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.37e-02  0.00e+00  7.37e-02    9.14e+01      0
#    1  0.00e+00  6.06e-02  4.07e-08  6.06e-02    4.92e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3037e-02 <= tolF*(1+|f0|) = 1.0737e-01
# 1 : |xc-x_last| = 2.8520e-04 <= tolX*(1+|x0|) = 1.1539e+00
# 1 : |proj(x-g)-x|    = 4.9235e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.9235e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+04, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.78e-01  0.00e+00  4.78e-01    8.77e+01      0
#    1  0.00e+00  4.66e-01  3.75e-08  4.66e-01    1.55e-01      0
#    2  0.00e+00  2.15e-02  1.67e+01  2.15e-02    8.68e-02      0   Skip BFGS
#    3  0.00e+00  2.15e-02  1.67e+01  2.15e-02    8.68e-02      2   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.3531e-10 <= tolF*(1+|f0|) = 1.4780e-01
# 1 : |xc-x_last| = 0.0000e+00 <= tolX*(1+|x0|) = 1.1539e+00
# 1 : |proj(x-g)-x|    = 8.6845e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.6845e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+04, recovered permeability: 6.79 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.13e+00  0.00e+00  2.13e+00    8.18e+01      0
#    1  0.00e+00  2.12e+00  3.25e-08  2.12e+00    3.34e-01      0
#    2  0.00e+00  2.15e-02  7.90e+01  2.15e-02    4.09e-01      0   Skip BFGS
#    3  0.00e+00  2.15e-02  7.90e+01  2.15e-02    4.09e-01      6
#    4  0.00e+00  2.15e-02  7.90e+01  2.15e-02    4.09e-01      4
# ------------------------------------------------------------------
# 0 :    ft     = 2.1524e-02 <= alp*descent     = 2.1524e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+04, recovered permeability: 13.57 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  9.10e+00  0.00e+00  9.10e+00    7.05e+01      0
#    1  0.00e+00  9.09e+00  2.42e-08  9.09e+00    6.94e-01      0
#    2  0.00e+00  2.15e-02  3.42e+02  2.15e-02    1.77e+00      0   Skip BFGS
#    3  0.00e+00  2.15e-02  3.42e+02  2.15e-02    1.77e+00      0
#    4  0.00e+00  2.15e-02  3.42e+02  2.15e-02    1.77e+00      1   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.1530e-02 <= alp*descent     = 2.1530e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+04, recovered permeability: 27.14 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.09e+01  0.00e+00  2.09e+01    6.00e+01      0
#    1  0.00e+00  2.09e+01  1.75e-08  2.09e+01    1.05e+00      0
#    2  0.00e+00  2.16e-02  7.88e+02  2.16e-02    4.08e+00      0   Skip BFGS
#    3  0.00e+00  2.16e-02  7.88e+02  2.16e-02    4.08e+00      5
# ------------------------------------------------------------------
# 0 :    ft     = 2.1552e-02 <= alp*descent     = 2.1552e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+04, recovered permeability: 40.70 mu0
#
#
#
# ------------------------ casing_sig1e+05_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.77e+01  0.00e+00  3.77e+01    5.04e+01      0
#    1  0.00e+00  3.77e+01  1.23e-08  3.77e+01    1.41e+00      0
#    2  0.00e+00  2.16e-02  1.42e+03  2.16e-02    7.36e+00      0   Skip BFGS
#    3  0.00e+00  2.16e-02  1.42e+03  2.16e-02    7.36e+00      4
#    4  0.00e+00  2.16e-02  1.42e+03  2.16e-02    7.36e+00      5   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 2.1612e-02 <= alp*descent     = 2.1612e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+04, recovered permeability: 54.27 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.44e-01  0.00e+00  2.44e-01    1.58e+02      0
#    1  0.00e+00  2.23e-01  3.37e-08  2.23e-01    1.82e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.0554e-02 <= tolF*(1+|f0|) = 1.2438e-01
# 1 : |xc-x_last| = 2.5956e-04 <= tolX*(1+|x0|) = 1.3142e+00
# 1 : |proj(x-g)-x|    = 1.8205e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8205e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  9.56e-01  0.00e+00  9.56e-01    1.23e+02      0
#    1  0.00e+00  9.43e-01  2.02e-08  9.43e-01    1.03e+00      0
#    2  0.00e+00  6.44e-02  1.47e+00  6.44e-02    3.29e-01      0   Skip BFGS
#    3  0.00e+00  6.44e-02  1.47e+00  6.44e-02    3.29e-01      6
# ------------------------------------------------------------------
# 0 :    ft     = 6.4356e-02 <= alp*descent     = 6.4356e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+05, recovered permeability: 2.71 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.01e+01  0.00e+00  1.01e+01    6.57e+01      0
# ------------------------------------------------------------------
# 0 :    ft     = 1.0080e+01 <= alp*descent     = 1.0080e+01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.73e+01  0.00e+00  4.73e+01    2.34e+01      0
# ------------------------------------------------------------------
# 0 :    ft     = 4.7324e+01 <= alp*descent     = 4.7324e+01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.04e+02  0.00e+00  2.04e+02    1.72e+02      0
#    1  0.00e+00  2.04e+02  3.92e-08  2.04e+02    1.56e+01      0
#    2  0.00e+00  6.93e-02  3.41e+02  6.93e-02    7.73e+01      0
#    3  0.00e+00  6.44e-02  3.41e+02  6.44e-02    7.41e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.9593e-03 <= tolF*(1+|f0|) = 2.0530e+01
# 1 : |xc-x_last| = 1.4416e-02 <= tolX*(1+|x0|) = 1.3142e+00
# 1 : |proj(x-g)-x|    = 7.4100e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 7.4100e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+05, recovered permeability: 27.13 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.71e+02  0.00e+00  4.71e+02    2.84e+02      0
#    1  0.00e+00  4.71e+02  1.08e-07  4.71e+02    2.37e+01      0
#    2  0.00e+00  9.08e-02  7.87e+02  9.08e-02    1.79e+02      0
#    3  0.00e+00  6.44e-02  7.88e+02  6.44e-02    1.43e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.6469e-02 <= tolF*(1+|f0|) = 4.7193e+01
# 1 : |xc-x_last| = 3.3074e-02 <= tolX*(1+|x0|) = 1.3142e+00
# 1 : |proj(x-g)-x|    = 1.4349e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4349e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+05, recovered permeability: 40.70 mu0
#
#
#
# ------------------------ casing_sig5e+05_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  8.47e+02  0.00e+00  8.47e+02    3.61e+02      0
#    1  0.00e+00  8.47e+02  1.74e-07  8.47e+02    3.18e+01      0
#    2  0.00e+00  1.50e-01  1.42e+03  1.50e-01    3.22e+02      0
#    3  0.00e+00  6.44e-02  1.42e+03  6.44e-02    1.70e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.5936e-02 <= tolF*(1+|f0|) = 8.4766e+01
# 1 : |xc-x_last| = 5.8753e-02 <= tolX*(1+|x0|) = 1.3142e+00
# 1 : |proj(x-g)-x|    = 1.6983e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6983e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+05, recovered permeability: 54.27 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.07e-01  0.00e+00  6.07e-01    1.86e+02      0
#    1  0.00e+00  5.74e-01  6.20e-08  5.74e-01    6.97e-03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.2754e-02 <= tolF*(1+|f0|) = 1.6070e-01
# 1 : |xc-x_last| = 3.5202e-04 <= tolX*(1+|x0|) = 1.3833e+00
# 1 : |proj(x-g)-x|    = 6.9746e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 6.9746e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+05, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.82e+00  0.00e+00  2.82e+00    9.84e+01      0
#    1  0.00e+00  2.81e+00  1.73e-08  2.81e+00    3.19e+00      0
#    2  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.43e-01      0   Skip BFGS
#    3  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.43e-01      0
#    4  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.43e-01      2   Skip BFGS
#    5  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.42e-01      2
#    6  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.43e-01      2   Skip BFGS
#    7  0.00e+00  8.00e-02  1.47e+00  8.00e-02    9.42e-01      3
# ------------------------------------------------------------------
# 0 :    ft     = 7.9986e-02 <= alp*descent     = 7.9986e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+05, recovered permeability: 2.71 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.12e+01  0.00e+00  3.12e+01    4.22e+01      0
#    1  0.00e+00  3.12e+01  1.14e-14  3.12e+01    4.22e+01      9
#    2  0.00e+00  8.01e-02  1.67e+01  8.01e-02    1.07e+01      0   Skip BFGS
#    3  0.00e+00  8.01e-02  1.67e+01  8.01e-02    1.07e+01      2   Skip BFGS
#    4  0.00e+00  8.01e-02  1.67e+01  8.01e-02    1.07e+01      1
# ------------------------------------------------------------------
# 0 :    ft     = 8.0096e-02 <= alp*descent     = 8.0096e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+05, recovered permeability: 6.78 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.47e+02  0.00e+00  1.47e+02    2.54e+02      0
#    1  0.00e+00  1.47e+02  1.14e-07  1.47e+02    2.34e+01      0
#    2  0.00e+00  8.25e-02  7.89e+01  8.25e-02    5.09e+01      0
#    3  0.00e+00  8.00e-02  7.90e+01  8.00e-02    9.72e-04      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.5072e-03 <= tolF*(1+|f0|) = 1.4797e+01
# 1 : |xc-x_last| = 8.0377e-03 <= tolX*(1+|x0|) = 1.3833e+00
# 1 : |proj(x-g)-x|    = 9.7173e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 9.7173e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+05, recovered permeability: 13.57 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.34e+02  0.00e+00  6.34e+02    6.05e+02      0
#    1  0.00e+00  6.34e+02  6.50e-07  6.34e+02    4.86e+01      0
#    2  0.00e+00  1.27e-01  3.41e+02  1.27e-01    2.21e+02      0
#    3  0.00e+00  8.00e-02  3.42e+02  8.00e-02    1.88e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.7109e-02 <= tolF*(1+|f0|) = 6.3516e+01
# 1 : |xc-x_last| = 3.5093e-02 <= tolX*(1+|x0|) = 1.3833e+00
# 1 : |proj(x-g)-x|    = 1.8793e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8793e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+05, recovered permeability: 27.14 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.46e+03  0.00e+00  1.46e+03    8.56e+02      0
#    1  0.00e+00  1.46e+03  1.30e-06  1.46e+03    7.36e+01      0
#    2  0.00e+00  3.32e-01  7.85e+02  3.32e-01    5.11e+02      0
#    3  0.00e+00  8.00e-02  7.88e+02  8.00e-02    6.66e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.5186e-01 <= tolF*(1+|f0|) = 1.4606e+02
# 1 : |xc-x_last| = 8.1006e-02 <= tolX*(1+|x0|) = 1.3833e+00
# 1 : |proj(x-g)-x|    = 6.6567e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.6567e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+05, recovered permeability: 40.71 mu0
#
#
#
# ------------------------ casing_sig1e+06_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.62e+03  0.00e+00  2.62e+03    1.01e+03      0
#    1  0.00e+00  2.62e+03  1.79e-06  2.62e+03    9.86e+01      0
#    2  0.00e+00  8.99e-01  1.41e+03  8.99e-01    9.22e+02      0
#    3  0.00e+00  8.00e-02  1.42e+03  8.00e-02    1.71e-01      0   Skip BFGS
#    4  0.00e+00  8.00e-02  1.42e+03  8.00e-02    1.71e-01      4   Skip BFGS
#    5  0.00e+00  8.00e-02  1.42e+03  8.00e-02    1.71e-01      8   Skip BFGS
#    6  0.00e+00  8.00e-02  1.42e+03  8.00e-02    1.71e-01      1
# ------------------------------------------------------------------
# 0 :    ft     = 8.0008e-02 <= alp*descent     = 8.0008e-02
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+05, recovered permeability: 54.28 mu0
#
#
#
# ------------------------ casing_sig5e+06_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
# ...
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.26e+02  0.00e+00  6.26e+02    4.74e+02      0
#    1  0.00e+00  6.25e+02  1.36e-05  6.25e+02    9.96e+01      0
#    2  0.00e+00  2.00e-01  7.87e+01  2.00e-01    1.30e+02      0
#    3  0.00e+00  1.01e-01  7.90e+01  1.01e-01    7.09e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.8496e-02 <= tolF*(1+|f0|) = 6.2711e+01
# 1 : |xc-x_last| = 2.9767e-02 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 7.0874e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.0874e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06, recovered permeability: 13.57 mu0
#
#
#
# ------------------------ casing_sig5e+06_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.68e+03  0.00e+00  2.68e+03    8.70e+02      0
#    1  0.00e+00  2.68e+03  4.53e-05  2.68e+03    2.06e+02      0
#    2  0.00e+00  1.97e+00  3.38e+02  1.97e+00    5.63e+02      0
#    3  0.00e+00  1.01e-01  3.43e+02  1.01e-01    1.36e+00      0   Skip BFGS
#    4  0.00e+00  1.01e-01  3.43e+02  1.01e-01    1.36e+00      0   Skip BFGS
#    5  0.00e+00  1.01e-01  3.43e+02  1.01e-01    1.36e+00      2   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.0141e-01 <= alp*descent     = 1.0141e-01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 1.80e+06, recovered permeability: 27.17 mu0
#
#
#
# ------------------------ casing_sig5e+06_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.12e+03  0.00e+00  6.12e+03    1.05e+03      0
#    1  0.00e+00  6.12e+03  6.41e-05  6.12e+03    3.10e+02      0
#    2  0.00e+00  1.02e+01  7.77e+02  1.02e+01    1.30e+03      0
#    3  0.00e+00  1.02e-01  7.94e+02  1.02e-01    7.31e+00      0   Skip BFGS
#    4  0.00e+00  1.01e-01  7.94e+02  1.01e-01    1.02e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.1163e-04 <= tolF*(1+|f0|) = 6.1243e+02
# 1 : |xc-x_last| = 1.1489e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 1.0177e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 1.0177e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.81e+06, recovered permeability: 40.84 mu0
#
#
#
# ------------------------ casing_sig5e+06_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.09e+04  0.00e+00  1.09e+04    1.03e+03      0
#    1  0.00e+00  1.09e+04  5.64e-05  1.09e+04    4.12e+02      0
#    2  0.00e+00  3.30e+01  1.39e+03  3.30e+01    2.32e+03      0
#    3  0.00e+00  1.05e-01  1.44e+03  1.05e-01    2.41e+01      0   Skip BFGS
#    4  0.00e+00  1.01e-01  1.44e+03  1.01e-01    5.42e-03      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 3.4340e-03 <= tolF*(1+|f0|) = 1.0868e+03
# 1 : |xc-x_last| = 2.9817e-03 <= tolX*(1+|x0|) = 1.5438e+00
# 1 : |proj(x-g)-x|    = 5.4233e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 5.4233e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.81e+06, recovered permeability: 54.60 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur1 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.89e+00  0.00e+00  2.89e+00    7.56e+01      0
#    1  0.00e+00  2.78e+00  3.64e-06  2.78e+00    9.03e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.0199e-01 <= tolF*(1+|f0|) = 3.8857e-01
# 1 : |xc-x_last| = 2.6984e-03 <= tolX*(1+|x0|) = 1.6130e+00
# 1 : |proj(x-g)-x|    = 9.0294e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.0294e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.59e+06, recovered permeability: 1.00 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur10 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.49e+01  0.00e+00  1.49e+01    1.87e+01      0
#    1  0.00e+00  1.49e+01  3.27e-08  1.49e+01    1.73e+01      0
#    2  0.00e+00  1.06e-01  1.47e+00  1.06e-01    2.66e+00      0
#    3  0.00e+00  1.05e-01  1.47e+00  1.05e-01    2.40e-04      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2765e-04 <= tolF*(1+|f0|) = 1.5907e+00
# 1 : |xc-x_last| = 6.5847e-04 <= tolX*(1+|x0|) = 1.6130e+00
# 1 : |proj(x-g)-x|    = 2.3975e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 2.3975e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.59e+06, recovered permeability: 2.71 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur25 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.69e+02  0.00e+00  1.69e+02    1.42e+02      0
#    1  0.00e+00  1.68e+02  1.06e-05  1.68e+02    5.83e+01      0
#    2  0.00e+00  1.22e-01  1.67e+01  1.22e-01    3.03e+01      0
#    3  0.00e+00  1.05e-01  1.67e+01  1.05e-01    1.44e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.6761e-02 <= tolF*(1+|f0|) = 1.6967e+01
# 1 : |xc-x_last| = 9.3180e-03 <= tolX*(1+|x0|) = 1.6130e+00
# 1 : |proj(x-g)-x|    = 1.4361e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4361e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.60e+06, recovered permeability: 6.79 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur50 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.92e+02  0.00e+00  7.92e+02    3.15e+02      0
#    1  0.00e+00  7.91e+02  5.29e-05  7.91e+02    1.26e+02      0
#    2  0.00e+00  4.85e-01  7.85e+01  4.85e-01    1.43e+02      0
#    3  0.00e+00  1.05e-01  7.92e+01  1.05e-01    3.21e-01      0   Skip BFGS
#    4  0.00e+00  1.05e-01  7.92e+01  1.05e-01    3.21e-01      0   Skip BFGS
#    5  0.00e+00  1.05e-01  7.92e+01  1.05e-01    3.21e-01      6   Skip BFGS
#    6  0.00e+00  1.05e-01  7.92e+01  1.05e-01    3.21e-01      6
# ------------------------------------------------------------------
# 0 :    ft     = 1.0546e-01 <= alp*descent     = 1.0546e-01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.60e+06, recovered permeability: 13.59 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur100 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.37e+03  0.00e+00  3.37e+03    5.10e+02      0
#    1  0.00e+00  3.37e+03  1.22e-04  3.37e+03    2.60e+02      0
#    2  0.00e+00  7.34e+00  3.36e+02  7.34e+00    6.07e+02      0
#    3  0.00e+00  1.06e-01  3.46e+02  1.06e-01    6.15e+00      0   Skip BFGS
#    4  0.00e+00  1.05e-01  3.46e+02  1.05e-01    5.55e-04      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.0553e-04 <= tolF*(1+|f0|) = 3.3734e+02
# 1 : |xc-x_last| = 2.4919e-04 <= tolX*(1+|x0|) = 1.6130e+00
# 1 : |proj(x-g)-x|    = 5.5453e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 5.5453e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.62e+06, recovered permeability: 27.30 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur150 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.61e+03  0.00e+00  7.61e+03    5.35e+02      0
#    1  0.00e+00  7.61e+03  8.57e-05  7.61e+03    3.89e+02      0
#    2  0.00e+00  3.86e+01  7.66e+02  3.86e+01    1.35e+03      0
#    3  0.00e+00  1.28e-01  8.11e+02  1.28e-01    3.33e+01      0   Skip BFGS
#    4  0.00e+00  1.05e-01  8.11e+02  1.05e-01    2.19e-02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.2431e-02 <= tolF*(1+|f0|) = 7.6146e+02
# 1 : |xc-x_last| = 8.1896e-03 <= tolX*(1+|x0|) = 1.6130e+00
# 1 : |proj(x-g)-x|    = 2.1941e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.1941e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.66e+06, recovered permeability: 41.28 mu0
#
#
#
# ------------------------ casing_sig1e+07_mur200 : 1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# =============================== Projected GNCG ===============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.33e+04  0.00e+00  1.33e+04    5.18e+02      0
#    1  0.00e+00  1.33e+04  4.23e-06  1.33e+04    5.12e+02      0
#    2  0.00e+00  1.22e+02  1.36e+03  1.22e+02    2.30e+03      0
#    3  0.00e+00  3.73e-01  1.49e+03  3.73e-01    1.06e+02      0   Skip BFGS
#    4  0.00e+00  1.05e-01  1.50e+03  1.05e-01    2.91e-01      0   Skip BFGS
#    5  0.00e+00  1.05e-01  1.50e+03  1.05e-01    2.91e-01      0   Skip BFGS
#    6  0.00e+00  1.05e-01  1.50e+03  1.05e-01    2.91e-01      3   Skip BFGS
# ------------------------------------------------------------------
# 0 :    ft     = 1.0531e-01 <= alp*descent     = 1.0531e-01
# 1 : maxIterLS =      10    <= iterLS          =     10
# ------------------------- End Linesearch -------------------------
# The linesearch got broken. Boo.
# recovered conductivity: 3.72e+06, recovered permeability: 55.72 mu0

# %%
inv_results = {}

for key in keys:
    if key not in inv_results: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = inv_dict[key][freq].directiveList.dList[1].inversion_results
        inv_results[key] = tmp

# %%
tmp = inv_results[keys[0]][frequencies[0]]

# %%
tmp = inv_dict[keys[0]][frequencies[0]]

# %%
phi_d_final = {}
chifact_final = {}
phid_star = len(rx_x)*len(rx_z)*2

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            phid_tmp[i] = phid[-1]
    phi_d_final[key] = phid_tmp
    chifact_final[key] = phi_d_final[key] / phid_star

# %%
phid_min = {}
chifact_min = {}
logsig_min = {}
mur_min = {}
rms_min = {}

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    logsig_tmp = np.ones(len(frequencies)) * np.nan
    mur_tmp = np.ones(len(frequencies)) * np.nan
    rms_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            ind_min = np.argmin(phid)
            phid_tmp[i] = phid[ind_min]
            logsig_tmp[i] = inv_results[key][freq]["logsigma"][ind_min]
            mur_tmp[i] = inv_results[key][freq]["mur"][ind_min]
            rms_tmp[i] = inv_results[key][freq]["rms"][ind_min]
    phid_min[key] = phid_tmp
    logsig_min[key] = logsig_tmp
    mur_min[key] = mur_tmp
    rms_min[key] = rms_tmp

# %%
np.hstack(mur_min.values())
# Out:
# /tmp/ipykernel_155415/364635938.py:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   np.hstack(mur_min.values())
# array([ 1.        ,  1.00000252,  1.00000251,  1.00000249,  1.00000246,
#         1.00000243,  1.00000241,  1.        ,  1.00000284,  1.00000279,
#         1.00000272, 27.13987206, 40.70684906, 54.27339126,  1.        ,
#         1.00000285,  6.78735363, 13.57095375, 27.13737237, 40.70276032,
#        54.26718428,  1.        ,  2.71348582,         nan,         nan,
#        27.13417264, 40.70193462, 54.27060416,  1.        ,  2.71332301,
#         6.78221094, 13.56717543, 27.13548955, 40.70623068, 54.2805304 ,
#         1.        ,  2.71353567,  6.78423592, 13.5721276 , 27.17414598,
#        40.83760646, 54.59613973,  1.        ,  2.71365973,  6.78610602,
#        13.58710831, 27.29769227, 41.27667345, 55.72090849])

# %%
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(6, 12))

n = len(sigma_casing)
mur_min_vals = np.hstack(mur_min.values())
dmis_vals = np.hstack(phid_min.values())
logsig_vals = np.hstack(logsig_min.values())
for i, sig in enumerate(sigma_casing):

    ax[0].semilogy(mur_casing, dmis_vals[i*n:(i+1)*n], "-o", label=sig)
    ax[1].semilogy(mur_casing, np.exp(logsig_vals[i*n:(i+1)*n]), "-o", label=sig)
    ax[2].plot(mur_casing, mur_min_vals[i*n:(i+1)*n], "-o", label=sig)
ax[0].legend()
# Out:
# /tmp/ipykernel_155415/543180079.py:4: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   mur_min_vals = np.hstack(mur_min.values())
# /tmp/ipykernel_155415/543180079.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   dmis_vals = np.hstack(phid_min.values())
# /tmp/ipykernel_155415/543180079.py:6: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   logsig_vals = np.hstack(logsig_min.values())

# %%
# fig, ax = plt.subplots(3, 1, figsize=(6, 12), sharex=True) 

# for key in keys: 
#     mrec = np.vstack(mrec_dict[key].values())
    
#     ax[0].semilogx(frequencies, phi_d_final[key] / phid_star, "o", label=key)
#     ax[0].semilogx(frequencies,  np.ones_like(frequencies),"--k")
#     ax[1].loglog(frequencies, np.exp(mrec[:, 0]), "o", label=key)
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
#     ax[2].semilogx(frequencies, mrec[:, 1], "o", label=key)

# ax[1].set_ylim([1e6, 1e8])
# # ax[0].legend()

# %%
# fig, ax = plt.subplots(3, 1, figsize=(6, 12), sharex=True) 

# for key in keys: 
#     ax[0].loglog(frequencies, phid_min[key], "o", label=key)
#     ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
#     ax[1].loglog(frequencies, np.exp(logsig_min[key]), "o", label=key)
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
#     ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
#     ax[2].semilogx(frequencies, (mur_min[key]), "o", label=key)
# ax[0].legend()

# %%
markers = ["o", "v", "s", "D", "p", "^", "h"]

# %%
mur_casing
# Out:
# array([  1,  10,  25,  50, 100, 150, 200])

# %%
plotkeys = np.hstack([keys[0], keys[2:]])
plotkeys
# Out:
# array(['casing_sig1e+04_mur1', 'casing_sig1e+04_mur25',
#        'casing_sig1e+04_mur50', 'casing_sig1e+04_mur100',
#        'casing_sig1e+04_mur150', 'casing_sig1e+04_mur200',
#        'casing_sig5e+04_mur1', 'casing_sig5e+04_mur10',
#        'casing_sig5e+04_mur25', 'casing_sig5e+04_mur50',
#        'casing_sig5e+04_mur100', 'casing_sig5e+04_mur150',
#        'casing_sig5e+04_mur200', 'casing_sig1e+05_mur1',
#        'casing_sig1e+05_mur10', 'casing_sig1e+05_mur25',
#        'casing_sig1e+05_mur50', 'casing_sig1e+05_mur100',
#        'casing_sig1e+05_mur150', 'casing_sig1e+05_mur200',
#        'casing_sig5e+05_mur1', 'casing_sig5e+05_mur10',
#        'casing_sig5e+05_mur25', 'casing_sig5e+05_mur50',
#        'casing_sig5e+05_mur100', 'casing_sig5e+05_mur150',
#        'casing_sig5e+05_mur200', 'casing_sig1e+06_mur1',
#        'casing_sig1e+06_mur10', 'casing_sig1e+06_mur25',
#        'casing_sig1e+06_mur50', 'casing_sig1e+06_mur100',
#        'casing_sig1e+06_mur150', 'casing_sig1e+06_mur200',
#        'casing_sig5e+06_mur1', 'casing_sig5e+06_mur10',
#        'casing_sig5e+06_mur25', 'casing_sig5e+06_mur50',
#        'casing_sig5e+06_mur100', 'casing_sig5e+06_mur150',
#        'casing_sig5e+06_mur200', 'casing_sig1e+07_mur1',
#        'casing_sig1e+07_mur10', 'casing_sig1e+07_mur25',
#        'casing_sig1e+07_mur50', 'casing_sig1e+07_mur100',
#        'casing_sig1e+07_mur150', 'casing_sig1e+07_mur200'], dtype='<U22')

# %%
def mur_by_skindepth(delta):
    omega = 2 * np.pi * frequencies
    return 2 / (omega * delta**2 * sigma_casing) / mu_0

# %%
mur_by_skindepth(casing_t)/mu_0
# Out:
# array([2.0157209e+11, 4.0314418e+10, 2.0157209e+10, 4.0314418e+09,
#        2.0157209e+09, 4.0314418e+08, 2.0157209e+08])

# %%
fig, ax = plt.subplots(3, 1, figsize=(6.75, 8.25), sharex=True, dpi=dpi_high) 

for i, key in enumerate(plotkeys): 
    color = "k" if i==0 else f"C{i-1}"
    label = f"{key.split('_')[-1][3:]} $\mu_0$"
    ax[0].loglog(frequencies, rms_min[key], f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    # ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
    ax[1].loglog(frequencies, np.exp(logsig_min[key]), f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
    # ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
    ax[2].loglog(frequencies, (mur_min[key]), f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
    
for a in ax:
    a.grid()
    
ax[0].legend(loc=2)
ax[1].set_ylim(6e4, 2e7)
ax[2].set_ylim([0.7, 500])

ax[2].text(1.1e3, 2, "$\delta\sim t/2$", alpha=0.7)
ax[2].loglog(frequencies, mur_by_skindepth(casing_t/2), ":k", alpha=0.6)

ax[2].text(7e1, 2, "$\delta\sim t$", alpha=0.7)
ax[2].loglog(frequencies, mur_by_skindepth(casing_t), ":k", alpha=0.2)

ax[0].set_ylabel("RMS Misfit (V/m)")
ax[1].set_ylabel("Recovered $\sigma$ (S/m)")
ax[2].set_ylabel("Recovered $\mu_r$")
ax[2].set_xlabel("frequency (Hz)")

ax[0].set_title("(a)")
ax[1].set_title("(b)")
ax[2].set_title("(c)")

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[183], line 6
#       4 color = "k" if i==0 else f"C{i-1}"
#       5 label = f"{key.split('_')[-1][3:]} $\mu_0$"
# ----> 6 ax[0].loglog(frequencies, rms_min[key], f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
#       7 # ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
#       8 ax[1].loglog(frequencies, np.exp(logsig_min[key]), f"-{markers[i]}", color=color, lw=0.75, ms=4, label=label)
#
# IndexError: list index out of range

# %%
skin_depths_casing = 500/np.sqrt(sigma_casing * frequencies) 

fig, ax = plt.subplots(1, 1) 
ax.loglog(frequencies, skin_depths_casing)
ax.loglog(frequencies, np.ones_like(frequencies)*casing_t, "--k")
ax.loglog(frequencies, np.ones_like(frequencies)*csz, ":k")

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 3))

freq_ind = 7

mur_1Hz =  np.array([mur_min[k][freq_ind] for k in plot_keys])
mur_true = np.array([np.float64(k.split('_')[-1][3:]) for k in plot_keys])

slope, intercept, r, p, std_err = stats.linregress(mur_true, mur_1Hz)

ax.plot(mur_true, mur_1Hz, "ko", label="recoverd $\mu_r$")
    
ax.plot(mur_true, slope*mur_true, ":k", alpha=0.5, label=f"slope: {slope:1.2f}")
ax.set_xlabel("true $\mu_r$")
ax.set_ylabel("recovered $\mu_r$")
ax.set_title(f"{frequencies[freq_ind]} Hz")
ax.grid("both")
# ax.set_aspect(1)
ax.legend()
    # ax.plot()

# %%
casing_t
# Out:
# 0.01

# %%
casing_t/(casing_b)
# Out:
# 0.19999999999999998

# %%
from scipy import stats

# %%
slope
# Out:
# 0.272951675092747

# %%
intercept
# Out:
# -0.059192644810966755

# %%
std_err
# Out:
# 0.00033198123344744504
