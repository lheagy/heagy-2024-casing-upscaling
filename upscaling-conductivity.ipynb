# %% [markdown]
# # EM casing response dipole source

# %%
import numpy as np
import os
import scipy.sparse as sp
import pandas as pd
from scipy.constants import mu_0
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, LinearSegmentedColormap, Normalize
from matplotlib import cm as colormap
import time
from string import ascii_lowercase
import pickle
from multiprocessing import Pool

# SimPEG, discretize/
import discretize
from discretize import utils
from simpeg.electromagnetics import frequency_domain as fdem
from simpeg import(
    maps, Report, data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils
)
from pymatsolver import Pardiso

from utils import pad_for_casing_and_data

# %%
from matplotlib import rcParams
rcParams["font.size"] = 16

# %%
directory_path = "/t40array/lheagy/casing-upscaling"

# %%
def ensure_directory_exists(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# Example usage
ensure_directory_exists(directory_path)
# Out:
# Directory '/t40array/lheagy/casing-upscaling' already exists.

# %%
save_figures = False
fig_dir_high = "figures"
fig_dir_low = "low-rez-figures"

dpi_high=400
dpi_low=150

# %% [markdown]
# ## Simulation parameters

# %%
# # conductivities
sigma_air = 1e-4
sigma_back = np.r_[1e-2, 3e-2, 1e-1, 3e-1, 1]
casing_l = 500
sigma_casing = 5e6
mur_casing = np.r_[1]

# # casing geometry
casing_b = 5e-2  
casing_t = 1e-2 #np.r_[5e-3, 7.5e-3, 10e-3, 12.5e-3, 15e-3, 20e-3]
casing_a = casing_b - casing_t

# %%
src_dz = 10
src_z = -515 #np.r_[-100, -250, -400, -495, -500, -550, -600]

# %%
# generate a mesh
hx = pad_for_casing_and_data(
   casing_outer_radius = casing_b,
    csx1 = casing_t/8, 
    csx2 = 25, 
    pfx1 = 1.3,
    pfx2 = 1.5, 
    domain_x = 1000, 
    npadx = 10
)

pfz = 1.3
npad_z = 28
csz = 1
n_core_extra = 10
ncore_z = int(np.max(np.r_[np.abs(casing_l), np.abs(src_z)]) / csz) + n_core_extra
hz = discretize.utils.unpack_widths(
    [(csz, npad_z, -pfz), (csz, ncore_z), (csz, npad_z, pfz)]
)

# %%
mesh = discretize.CylindricalMesh(
    [hx, np.r_[2*np.pi], hz], origin=np.r_[0, 0, -np.sum(hz[:npad_z + int(ncore_z)])],
)

fig, ax = plt.subplots(1, 1)
mesh.plot_grid(ax=ax)
# ax.set_xlim([0, 5])
# ax.set_ylim(-50, 10)
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
mesh.n_cells
# Out:
# 74949

# %%
def get_physical_property_model(mesh, casing_a, casing_b, casing_l, sigma_back, sigma_casing, sigma_air=1e-4, mur_casing=1):

    model = np.ones(mesh.n_cells)*sigma_air
    model[mesh.cell_centers[:, 2] < 0] = sigma_back

    mur = np.ones(mesh.n_cells)

    inds_casing_x = (
        (mesh.cell_centers[:, 0] > casing_a) & 
        (mesh.cell_centers[:, 0] < casing_b)
    )
    inds_casing_z = (
        (mesh.cell_centers[:, 2] < 0) &
        (mesh.cell_centers[:, 2] > -casing_l)
    )
    inds_casing = inds_casing_x & inds_casing_z

    model[inds_casing] = sigma_casing
    mur[inds_casing] = mur_casing

    return model, mur

# %%
sigma_back
# Out:
# array([0.01, 0.03, 0.1 , 0.3 , 1.  ])

# %%
models = {}
for sig in sigma_back:
    for mur in mur_casing:
        key = f"casing_sig{sig:1.0e}_mur{mur:1.0f}"
        sig_model, mur_model = get_physical_property_model(mesh, casing_a, casing_b, casing_l, sig, sigma_casing)
        models[key] = {
            "sigma": sig_model, 
            "mur": mur_model
        }
keys = list(models.keys())

# %%
keys
# Out:
# ['casing_sig1e-02_mur1',
#  'casing_sig3e-02_mur1',
#  'casing_sig1e-01_mur1',
#  'casing_sig3e-01_mur1',
#  'casing_sig1e+00_mur1']

# %%
def plot_casing(model, xlim=None, zlim=None, vmin=None, vmax=None, ax=None, cb_label=None): 
    if ax is None: 
        fig, ax = plt.subplots(1, 1)
    pcolor_opts={"norm":LogNorm(vmin=vmin, vmax=vmax), "cmap":"Spectral_r"}
    out = mesh.plot_image(
        model, pcolor_opts=pcolor_opts, ax=ax, mirror=True
    )

    cb = plt.colorbar(out[-1])
    cb.set_label(cb_label)

    if xlim is not None: 
        ax.set_xlim(xlim)
    if zlim is not None: 
        ax.set_ylim(zlim)

    ax.set_xlabel("x (m)")
    ax.set_ylabel("z (m)")
    return ax

# %%
plot_keys = keys
fig, ax = plt.subplots(1, len(plot_keys), figsize=(5*len(plot_keys), 7))

xlim = 0.2*np.r_[-1, 1]
zlim = np.r_[-600, -400] #10]
vmin = sigma_air
vmax = sigma_casing

for i, key in enumerate(plot_keys):
    plot_casing(models[key]["sigma"], xlim=xlim, zlim=zlim, vmin=vmin, vmax=vmax, ax=ax[i])
    ax[i].set_title(key)
    ax[i].plot(np.r_[0, 0], src_z + src_dz/2 * np.r_[-1, 1], "-ok")

plt.tight_layout()
# for loc in src_z:
#     ax.plot(np.r_[0, 0], loc + src_dz/2*np.r_[-1, 1], "-k", lw=4, alpha=0.5)

# %% [markdown]
# ## set up the simulations

# %%
frequencies = 10**np.linspace(-1, 4, 36)
frequencies
# Out:
# array([1.00000000e-01, 1.38949549e-01, 1.93069773e-01, 2.68269580e-01,
#        3.72759372e-01, 5.17947468e-01, 7.19685673e-01, 1.00000000e+00,
#        1.38949549e+00, 1.93069773e+00, 2.68269580e+00, 3.72759372e+00,
#        5.17947468e+00, 7.19685673e+00, 1.00000000e+01, 1.38949549e+01,
#        1.93069773e+01, 2.68269580e+01, 3.72759372e+01, 5.17947468e+01,
#        7.19685673e+01, 1.00000000e+02, 1.38949549e+02, 1.93069773e+02,
#        2.68269580e+02, 3.72759372e+02, 5.17947468e+02, 7.19685673e+02,
#        1.00000000e+03, 1.38949549e+03, 1.93069773e+03, 2.68269580e+03,
#        3.72759372e+03, 5.17947468e+03, 7.19685673e+03, 1.00000000e+04])

# %%
src_list = []
src_locations = np.array([
    [0, 0, src_z+src_dz/2.],
    [0, 0, src_z-src_dz/2.]
])
for f in frequencies: 
    src = fdem.sources.LineCurrent([], location=src_locations, frequency=f)
    src_list.append(src)
    
survey = fdem.Survey(src_list)
sim = fdem.simulation.Simulation3DMagneticField(
    mesh=mesh, sigmaMap=maps.IdentityMap(mesh),
    survey=survey, solver=Pardiso, #mu=mur * mu_0
#     verbose=True
)

# %%
def run_simulation(key):
    
    filename = os.path.sep.join([directory_path, key])

    t = time.time()
    print(f"starting {key}..., saving to {filename}")
    fields = sim.fields(models[key]["sigma"])
    print(f" ... done. {time.time()-t:1.2e} \n")
    
    np.save(filename, fields[:, "hSolution"])

    return fields

# %%
fields = {}

# %%
for key in keys: 
    if key not in fields: 
        fields[key] = run_simulation(key)
# Out:
# starting casing_sig1e-02_mur1..., saving to /t40array/lheagy/casing-upscaling/casing_sig1e-02_mur1
#  ... done. 2.17e+01
#
# starting casing_sig3e-02_mur1..., saving to /t40array/lheagy/casing-upscaling/casing_sig3e-02_mur1
#  ... done. 1.39e+01
#
# starting casing_sig1e-01_mur1..., saving to /t40array/lheagy/casing-upscaling/casing_sig1e-01_mur1
#  ... done. 1.14e+01
#
# starting casing_sig3e-01_mur1..., saving to /t40array/lheagy/casing-upscaling/casing_sig3e-01_mur1
#  ... done. 1.08e+01
#
# starting casing_sig1e+00_mur1..., saving to /t40array/lheagy/casing-upscaling/casing_sig1e+00_mur1
#  ... done. 1.03e+01

# %%
fields
# Out:
# {'casing_sig1e-02_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7efd23364450>,
#  'casing_sig3e-02_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7efd2329e5d0>,
#  'casing_sig1e-01_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7efd21368950>,
#  'casing_sig3e-01_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7efd23778090>,
#  'casing_sig1e+00_mur1': <simpeg.electromagnetics.frequency_domain.fields.Fields3DMagneticField at 0x7efd212b8910>}

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

key = keys[0]
freq_ind = 0
xlim = 500*np.r_[-1, 1]
zlim = np.r_[-1000, 10]

field_plot = (mesh.average_face_to_cell_vector * fields[key][sim.survey.source_list[freq_ind], "e"])

for i, component in enumerate(["real", "imag"]): 
    out = mesh.plot_image(
        getattr(field_plot, component), "CCv", view="vec", 
        range_x = xlim, range_y = zlim,
        sample_grid = np.r_[10, 10],
        mirror=True, #mirror_data=field_mirror,
        ax=ax[i], 
        pcolor_opts={"norm":LogNorm(vmin=1e-7, vmax=1e-2)}
    )
    cb = plt.colorbar(out[0], ax=ax[i])
    cb.set_label("Electric Field (V/m)")
    ax[i].set_aspect(1)
    ax[i].set_title(f"{frequencies[freq_ind]} Hz, {component}")
plt.tight_layout()

# %%
# def load_fields(name, conductivity, mur):
#     solution = np.load(f"{directory}/fields_{name}.npy")
#     sim = generate_simulation(mur)
#     sim.model = conductivity
#     f = sim.fieldsPair(sim)
#     f[:, sim._solutionType] = solution
#     return f

# %% [markdown]
# # choose models to focus on

# %%
len(frequencies)
# Out:
# 36

# %%
# casing_t_inv = np.r_[5e-3]
# mur_inv = np.r_[1, 50, 100, 150, 200]
# freq_inds_inv = np.arange(0, 31, 1)
# src_ind_inv = 5

# inv_keys = []
# for t in casing_t_inv:
#     for mur in mur_inv:
#         inv_keys.append(f"casing_{mur}_{t:1.2e}")
# inv_keys

# %%
# frequencies[freq_inds_inv]

# %%
# fields = {}
# for key in inv_keys:
#     # if key not in fields.keys():
#     fields[key] = load_fields(key, models[key]["sigma"], models[key]["mur"])

# %%
rcParams["font.size"] = 13

# %%
fields.keys()
# Out:
# dict_keys(['casing_sig1e-02_mur1', 'casing_sig3e-02_mur1', 'casing_sig1e-01_mur1', 'casing_sig3e-01_mur1', 'casing_sig1e+00_mur1'])

# %%
def skin_depth(f, sigma, mur):
    return np.sqrt(2/(2*np.pi*f*sigma*mur*mu_0))

# %%
rx_x = np.linspace(25, 500, 20)
rx_z = -np.linspace(0, 600, 31
                   ) - csz/2
rx_x
# Out:
# array([ 25.,  50.,  75., 100., 125., 150., 175., 200., 225., 250., 275.,
#        300., 325., 350., 375., 400., 425., 450., 475., 500.])

# %%
def create_receivers():
    rx_ex_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="real",
    )
    rx_ex_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="x",
        component="imag",
    )
    rx_ez_re = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="real",
    )
    rx_ez_im = fdem.receivers.PointElectricField(
        locations=discretize.utils.ndgrid(rx_x, np.r_[0], rx_z),
        orientation="z",
        component="imag",
    )
    return rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im

# %%
rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
Px = rx_ex_re.getP(mesh, "Fx")
Pz = rx_ez_re.getP(mesh, "Fz")

# %%
frequencies
# Out:
# array([1.00000000e-01, 1.38949549e-01, 1.93069773e-01, 2.68269580e-01,
#        3.72759372e-01, 5.17947468e-01, 7.19685673e-01, 1.00000000e+00,
#        1.38949549e+00, 1.93069773e+00, 2.68269580e+00, 3.72759372e+00,
#        5.17947468e+00, 7.19685673e+00, 1.00000000e+01, 1.38949549e+01,
#        1.93069773e+01, 2.68269580e+01, 3.72759372e+01, 5.17947468e+01,
#        7.19685673e+01, 1.00000000e+02, 1.38949549e+02, 1.93069773e+02,
#        2.68269580e+02, 3.72759372e+02, 5.17947468e+02, 7.19685673e+02,
#        1.00000000e+03, 1.38949549e+03, 1.93069773e+03, 2.68269580e+03,
#        3.72759372e+03, 5.17947468e+03, 7.19685673e+03, 1.00000000e+04])

# %%
range(len(frequencies))
# Out:
# range(0, 36)

# %%
# get data_vectors
dobs_dict = {}

for k in keys:
    tmp_dict = {}
    for si in range(len(frequencies)):
        src = sim.survey.source_list[si]
        e = fields[k][src, "e"]
        edatax = (Px * e).squeeze()
        edataz = (Pz * e).squeeze()
        tmp_dict[frequencies[si]] = {
            "real_x": edatax.real,
            "imag_x": edatax.imag,
            "real_z": edataz.real,
            "imag_z": edataz.imag
        }
    dobs_dict[k] = tmp_dict

# %%
fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

key_ind = 0
key = keys[key_ind]

for i, freq in enumerate(frequencies): 
    # ax.plot(rx_x, dobs_dict[key][freq]["real"].reshape((len(rx_x), len(rx_z)), order="F"), "o" );
    for j, component in enumerate(["real_z", "imag_z"]): 
        plt.colorbar(
            ax[i, j].contourf(
                rx_x, rx_z, np.log10(np.abs(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T)), 30,
                # vmin=-7, vmax=-2
                # norm=LogNorm()
            ), ax=ax[i, j]
        )
        
        ax[i, j].plot(rx_e_re.locations[:, 0], rx_e_re.locations[:, 2], "w.", ms=1)
        ax[i, j].set_aspect(1)
        ax[i, j].set_title(f"{freq} Hz {component}")

plt.tight_layout()

# %%
def get_amplitude_phase(real, imag):
    # real = f.real
    # imag = f.imag
    amplitude = np.sqrt(real**2 + imag**2)
    phase = 180/np.pi*np.arctan2(imag, real)
    return amplitude, phase

# %%
# fig, ax = plt.subplots(len(frequencies), 2, figsize=(10, len(frequencies)*3), sharex=True)

# key_ind = 0
# key = keys[key_ind]

# for i, freq in enumerate(frequencies): 
#     amp, phase = get_amplitude_phase(*(dobs_dict[key][freq][component].reshape((len(rx_x), len(rx_z)), order="F").T for component in ["real", "imag"]))
#     for j, plotme in enumerate([np.log10(np.abs(amp)), phase]): 
#         plt.colorbar(
#             ax[i, j].contourf(
#                 rx_x, rx_z, plotme, 30,
#                 # vmin=-7, vmax=-2
#                 # norm=LogNorm()
#                 cmap = "twilight" if j == 1 else "viridis"
#             ), ax=ax[i, j]
#         )
        
#         ax[i, j].plot(rx_e_re.locations[:, 0], rx_e_re.locations[:, 2], "w.", ms=1)
#         ax[i, j].set_aspect(1)
#         ax[i, j].set_title(f"{freq} Hz {'amplitude' if j==0 else 'phase'}")

# plt.tight_layout()

# %% [markdown]
# # set up mappings and simulation

# %%
def create_maps(key, true_inds=False, casing_t_ind=0):
    indsx = (mesh.cell_centers[:, 0] < casing_b)
    if true_inds is True: 
        indsx = indsx & (mesh.cell_centers[:, 0] > casing_b - casing_t[casing_t_ind])
    
    inds_interior = (
        indsx &
        (mesh.cell_centers[:, 2] <= 0) &
        (mesh.cell_centers[:, 2] >= -casing_l)
    )

    active_inds_sigma = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=np.log(models[key]["sigma"][~inds_interior])
    )

    active_inds_mur = maps.InjectActiveCells(
        mesh, indActive=inds_interior, 
        valInactive=models[key]["mur"][~inds_interior]
    )

    projection_sigma = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])
    projection_mu = maps.SurjectUnits(indices=[np.ones(inds_interior.sum(), dtype=bool)])

    exp_map = maps.ExpMap(mesh)
    mur_map = maps.MuRelative(mesh)

    sigma_map = exp_map * active_inds_sigma * projection_sigma
    mu_map = mur_map * active_inds_mur * projection_mu

    return sigma_map, mu_map

# %%
src_locations
# Out:
# array([[   0.,    0., -510.],
#        [   0.,    0., -520.]])

# %%
def create_survey(freq): 
    rx_ex_re, rx_ex_im, rx_ez_re, rx_ez_im = create_receivers()
    src = fdem.sources.LineCurrent([rx_e_re, rx_e_im, rx_ez_re, rx_ez_im], location=src_locations, frequency=freq)
    return fdem.Survey([src])

# %%
# create the simulation
def create_simulation(key, survey, invert_mu=False, true_inds=False):
    sigma_map, mu_map = create_maps(key, true_inds)

    if invert_mu is True: 
        wires = maps.Wires(("sigma", 1), ("mu", 1))
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map * wires.sigma,
            muMap=mu_map * wires.mu 
        )
    else: 
        sim = fdem.simulation.Simulation3DMagneticField(
            mesh, survey=survey, solver=Pardiso, 
            sigmaMap=sigma_map
        )
    return sim

# %% [markdown]
# # set up inversions

# %%
class SaveInversionProgress(directives.InversionDirective):
    """
    A custom directive to save items of interest during the course of an inversion
    """
    
    results_file = None
    
    def initialize(self):
        """
        This is called when we first start running an inversion
        """
        # initialize an empty dictionary for storing results 
        self.inversion_results = {
            "iteration":[],
            "phi_d":[],
            "dpred":[],
            "logsigma":[],
            # "mur":[]
        }

    def endIter(self):
        """
        This is run at the end of every iteration. So here, we just append 
        the new values to our dictionary
        """
        
        # Save the data
        self.inversion_results["iteration"].append(self.opt.iter)
        self.inversion_results["phi_d"].append(self.invProb.phi_d)
        self.inversion_results["dpred"].append(self.invProb.dpred)
        self.inversion_results["logsigma"].append(self.invProb.model[0])
        # self.inversion_results["mur"].append(self.invProb.model[0])
        
        if self.results_file is not None: 
            with open(f"{self.results_file}", "wb") as fp:
                pickle.dump(self.inversion_results, fp)

# %%
def create_inversion(
    key, freq, invert_mu=False, relative_error=None, noise_floor=None,
    maxIter=10, maxIterCG=50, maxIterLS=10, true_casing_inds=False, 
):
    # create the simulation
    survey = create_survey(freq)
    dobsvec = np.hstack(list(dobs_dict[key][freq].values()))
    dobs = data.Data(
        survey=survey, dobs=dobsvec, relative_error=relative_error, noise_floor=noise_floor
    )

    sim = create_simulation(key, survey, invert_mu, true_casing_inds)
    dmis = data_misfit.L2DataMisfit(data=dobs, simulation=sim)

    if invert_mu is True: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([2]))
        # opt = optimization.ProjectedGNCG(
        #     maxIter=maxIter, lower=np.r_[-np.inf, 1], 
        #     maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        #     aggressive_stepping=True
        #     # tolF=1e-3, tolX=1e-3,
        # )
        opt = optimization.InexactGaussNewton(
            maxIter=maxIter, #lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )
    else: 
        reg = regularization.Smallness(mesh=discretize.TensorMesh([1]))
        # opt = optimization.ProjectedGNCG(
        #     maxIter=maxIter, lower=np.r_[-np.inf], 
        #     maxIterCG=maxIterCG, maxIterLS=maxIterLS,
        #     aggressive_stepping=True
        #     # tolF=1e-3, tolX=1e-3,
        # )
        opt = optimization.InexactGaussNewton(
            maxIter=maxIter, #lower=np.r_[-np.inf, 1], 
            maxIterCG=maxIterCG, maxIterLS=maxIterLS,
            aggressive_stepping=True
            # tolF=1e-3, tolX=1e-3,
        )

    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=0)

    # directives
    target_misfit = directives.TargetMisfit(chifact=1)
    
    if true_casing_inds:
        filename_save = f"inv_{key}_{freq:1.0f}_true_casing.pkl"
    else: 
        filename_save = f"inv_{key}_{freq:1.0f}.pkl"
    inversion_progress = SaveInversionProgress(results_file=f"{directory_path}/{filename_save}")
    
    # inversion 
    inv = inversion.BaseInversion(inv_prob, [target_misfit, inversion_progress])
    
    return inv

# %% [markdown]
# # experiment 2: invert for solid cylinder conductivity, permeability

# %%
keys
# Out:
# ['casing_sig1e-02_mur1',
#  'casing_sig3e-02_mur1',
#  'casing_sig1e-01_mur1',
#  'casing_sig3e-01_mur1',
#  'casing_sig1e+00_mur1']

# %%
models.keys()
# Out:
# dict_keys(['casing_sig1e-02_mur1', 'casing_sig3e-02_mur1', 'casing_sig1e-01_mur1', 'casing_sig3e-01_mur1', 'casing_sig1e+00_mur1'])

# %%
inv_dict = {}
relative_error = 0.005
noise_floor = 1e-8

for key in keys:
    if key not in inv_dict: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = create_inversion(
                    key, freq, invert_mu=False, relative_error=relative_error, noise_floor=noise_floor,
                )
        inv_dict[key] = tmp

# %%
t = casing_t
sigdc = sigma_casing * (1-(casing_b-t)**2/casing_b**2)
# starting_models = {
#     True: np.r_[np.log(sigstart), 1],
#     False: np.r_[np.log(sigstart)]
# }

# %%
mrec_dict = {}

for key in keys:
    if key not in mrec_dict: 
        tmp = {}
        for freq in frequencies:
            print(f"\n\n------------------------ {key} : {freq} Hz -------------------------- \n")
            tmp[freq] = inv_dict[key][freq].run(np.log(sigdc)) 
            print(f"recovered conductivity: {np.exp(inv_dict[key][freq].m[0]):1.2e} \n")
        mrec_dict[key] = tmp
# Out:
# ------------------------ casing_sig1e-02_mur1 : 0.1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.81e+00  0.00e+00  1.81e+00    2.81e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.8118e-01
# 1 : |xc-x_last| = 5.9745e-03 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 2
Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.01e+04  0.00e+00  2.01e+04    3.81e+04      0
#    1  0.00e+00  2.66e+03  8.60e-01  2.66e+03    5.05e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0088e+03
# 1 : |xc-x_last| = 3.0612e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 5.0493e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.0493e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# recovered conductivity: 6.18e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 719.6856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.54e+04  0.00e+00  1.54e+04    3.33e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.5438e+03
# 1 : |xc-x_last| = 8.9486e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 3.3325e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.3325e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.40e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 1000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.08e+04  0.00e+00  1.08e+04    2.43e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0834e+03
# 1 : |xc-x_last| = 8.8574e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 2.4274e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4274e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.36e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 1389.4954943731361 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.23e+03  0.00e+00  7.23e+03    1.68e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.2280e+02
# 1 : |xc-x_last| = 8.5727e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.6850e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6850e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.24e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 1930.6977288832495 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.45e+03  0.00e+00  4.45e+03    1.09e+04      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.4557e+02
# 1 : |xc-x_last| = 8.1519e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.0923e+04 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0923e+04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.07e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 2682.695795279722 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.92e+03  0.00e+00  2.92e+03    7.47e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.9178e+02
# 1 : |xc-x_last| = 7.7979e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 7.4704e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.4704e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.93e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 3727.593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.58e+03  0.00e+00  2.58e+03    6.79e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5784e+02
# 1 : |xc-x_last| = 7.5828e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 6.7900e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.7900e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.84e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 5179.474679231213 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.04e+03  0.00e+00  1.04e+03    2.68e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0412e+02
# 1 : |xc-x_last| = 7.7454e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 2.6845e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6845e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.91e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 7196.856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.92e+02  0.00e+00  5.92e+02    1.52e+03      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.9324e+01
# 1 : |xc-x_last| = 7.7860e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.5207e+03 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.5207e+03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.92e+06
#
#
#
# ------------------------ casing_sig1e-02_mur1 : 10000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.51e+02  0.00e+00  3.51e+02    9.09e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.5203e+01
# 1 : |xc-x_last| = 7.7165e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 9.0865e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.0865e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.89e+06
#
#
#
# ------------------------ casing_sig3e-02_mur1 : 0.1 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# ...
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6269e+00
# 1 : |xc-x_last| = 1.5103e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 2.9246e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9246e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.09e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 193.06977288832496 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.08e+01  0.00e+00  2.08e+01    2.45e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.1785e+00
# 1 : |xc-x_last| = 3.1459e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 2.4486e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4486e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 2.47e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 268.26957952797244 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.44e+01  0.00e+00  1.44e+01    1.97e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.5418e+00
# 1 : |xc-x_last| = 5.9171e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.9671e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9671e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.25e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 372.7593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  7.96e+00  0.00e+00  7.96e+00    1.40e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.9637e-01
# 1 : |xc-x_last| = 8.2535e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.4029e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4029e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.11e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 517.9474679231207 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  4.32e+00  0.00e+00  4.32e+00    8.86e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.3210e-01
# 1 : |xc-x_last| = 8.9279e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 8.8642e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.8642e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.40e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 719.6856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.16e+00  0.00e+00  2.16e+00    4.65e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.1622e-01
# 1 : |xc-x_last| = 9.0852e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 4.6542e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.6542e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.47e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 1000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  6.47e-01  0.00e+00  6.47e-01    1.45e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6466e-01
# 1 : |xc-x_last| = 8.8326e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.4546e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4546e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.35e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 1389.4954943731361 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.24e-01  0.00e+00  2.24e-01    5.33e-01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2242e-01
# 1 : |xc-x_last| = 8.4130e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 5.3277e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.3277e-01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 4.17e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 1930.6977288832495 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  5.91e-02  0.00e+00  5.91e-02    1.49e-01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0591e-01
# 1 : |xc-x_last| = 7.8869e-01 <= tolX*(1+|x0|) = 1.5403e+00
# 0 : |proj(x-g)-x|    = 1.4940e-01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.4940e-01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 3.96e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 2682.695795279722 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  1.30e-02  0.00e+00  1.30e-02    3.44e-02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0130e-01
# 1 : |xc-x_last| = 0.0000e+00 <= tolX*(1+|x0|) = 1.5403e+00
# 1 : |proj(x-g)-x|    = 3.4408e-02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4408e-02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 3727.593720314938 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.35e-03  0.00e+00  2.35e-03    6.33e-03      0
# ------------------------- STOP! -------------------------
# 0 : |fc-fOld| = 1.0000e+00 <= tolF*(1+|f0|) = 0.0000e+00
# 0 : |xc-x_last| = 1.0000e+00 <= tolX*(1+|x0|) = 0.0000e+00
# 1 : |proj(x-g)-x|    = 6.3325e-03 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 6.3325e-03 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      0
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 5179.474679231213 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.31e-04  0.00e+00  3.31e-04    8.96e-04      0
# ------------------------- STOP! -------------------------
# 0 : |fc-fOld| = 1.0000e+00 <= tolF*(1+|f0|) = 0.0000e+00
# 0 : |xc-x_last| = 1.0000e+00 <= tolX*(1+|x0|) = 0.0000e+00
# 1 : |proj(x-g)-x|    = 8.9627e-04 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 8.9627e-04 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      0
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 7196.856730011514 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  3.41e-05  0.00e+00  3.41e-05    8.55e-05      0
# ------------------------- STOP! -------------------------
# 0 : |fc-fOld| = 1.0000e+00 <= tolF*(1+|f0|) = 0.0000e+00
# 0 : |xc-x_last| = 1.0000e+00 <= tolX*(1+|x0|) = 0.0000e+00
# 1 : |proj(x-g)-x|    = 8.5503e-05 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 8.5503e-05 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      0
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06
#
#
#
# ------------------------ casing_sig1e+00_mur1 : 10000.0 Hz --------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DMagneticField problem***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  0.00e+00  2.25e-06  0.00e+00  2.25e-06    5.86e-06      0
# ------------------------- STOP! -------------------------
# 0 : |fc-fOld| = 1.0000e+00 <= tolF*(1+|f0|) = 0.0000e+00
# 0 : |xc-x_last| = 1.0000e+00 <= tolX*(1+|x0|) = 0.0000e+00
# 1 : |proj(x-g)-x|    = 5.8639e-06 <= tolG          = 1.0000e-01
# 1 : |proj(x-g)-x|    = 5.8639e-06 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      0
# ------------------------- DONE! -------------------------
# recovered conductivity: 1.80e+06

# %%
inv_results = {}

for key in keys:
    if key not in inv_results: 
        tmp = {}
        for freq in frequencies:
            tmp[freq] = inv_dict[key][freq].directiveList.dList[1].inversion_results
        inv_results[key] = tmp

# %%
tmp = inv_results[keys[0]][frequencies[0]]

# %%
tmp = inv_dict[keys[0]][frequencies[0]]

# %%
phi_d_final = {}
chifact_final = {}
phid_star = len(rx_x)*len(rx_z)*2

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            phid_tmp[i] = phid[-1]
    phi_d_final[key] = phid_tmp
    chifact_final[key] = phi_d_final[key] / phid_star

# %%
phid_min = {}
chifact_min = {}
mrec_min = {}

for key in keys:
    phid_tmp = np.ones(len(frequencies)) * np.nan
    mrec_tmp = np.ones(len(frequencies)) * np.nan
    for i, freq in enumerate(frequencies): 
        phid = inv_results[key][freq]["phi_d"]
        if len(phid) > 0: 
            ind_min = np.argmin(phid)
            phid_tmp[i] = phid[ind_min]
            mrec_tmp[i] = inv_results[key][freq]["logsigma"][ind_min]
    phid_min[key] = phid_tmp
    mrec_min[key] = mrec_tmp

# %%
fig, ax = plt.subplots(2, 1, figsize=(6, 8), sharex=True) 

for key in keys: 
    ax[0].loglog(frequencies, phi_d_final[key], "o", label=key)
    ax[0].semilogx(frequencies, phid_star * np.ones_like(frequencies),"--k")
    ax[1].loglog(frequencies, np.exp(np.hstack(mrec_dict[key].values())), "o", label=key)
    ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
    ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
ax[1].legend()
# Out:
# /tmp/ipykernel_3133344/2370284708.py:6: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   ax[1].loglog(frequencies, np.exp(np.hstack(mrec_dict[key].values())), "o", label=key)

# %% [markdown]
# <!-- ![image.png](attachment:ed16e814-577d-4508-b493-db3d23be7ee1.png) -->

# %%
markers = ["o", "v", "s", "^", "p", "D", "h"]

# %%
fig, ax = plt.subplots(2, 1, figsize=(6, 8), sharex=True) 

for i, key in enumerate(keys): 
    ax[0].semilogx(frequencies, phid_min[key]/phid_star, markers[i], ms=6, label=key)
    ax[0].semilogx(frequencies, np.ones_like(frequencies),"--k")
    ax[1].loglog(frequencies, np.exp(mrec_min[key]), markers[i], ms=6, label=key)
    ax[1].loglog(frequencies, np.ones_like(frequencies)*sigma_casing, "--k")
    ax[1].loglog(frequencies, np.ones_like(frequencies)*sigdc, "--k")
ax[0].legend()

ax[1].set_xlabel("frequency (Hz)")
ax[1].set_ylim(9e5, 7e6)
for a in ax:
    a.grid()

# %% [markdown]
# <!-- ![image.png](attachment:63ca319b-3e3c-49be-b9e0-c265ed4a4f3e.png) -->

# %%
500/np.sqrt(sigma_casing * 2)
# Out:
# 0.15811388300841897

# %%
casing_t
# Out:
# 0.01

# %%
skin_depths_casing = 500/np.sqrt(sigma_casing * frequencies) 

fig, ax = plt.subplots(1, 1) 
ax.loglog(frequencies, skin_depths_casing)
ax.loglog(frequencies, np.ones_like(frequencies)*casing_t, "--k")
ax.loglog(frequencies, np.ones_like(frequencies)*csz, ":k")

# %%
# fig, ax = plt.subplots(1,1) 

# for i, key in enumerate(mrec_dict.keys()):
#     for f, val in mrec_dict[key].items():
#         ax.loglog(
#             f, np.exp(val[False]), f"C{i}o", 
#             label=f"{key.split('-')[1]} $\mu_0$" if f==frequencies[freq_inds_inv[0]] else None
#         )

# %%
# key = "casing_1_1.00e-02"
# freq = frequencies[freq_inds_inv[0]]

# plot_obs_pred(key, freq, False);
